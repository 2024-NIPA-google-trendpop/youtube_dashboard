# %%
import tkinter as tk
import pandas as pd

filename = 'new_sampled_train_set_seg2_3.csv'
df = pd.read_csv(filename)

# %%
class LabelingApp:
    def __init__(self, root, df, csv_file):
        self.root = root
        self.root.title("감정 레이블링 도구")
        
        # 창 크기 설정
        self.root.geometry("1800x1000")  # 창 크기를 가로 1800, 세로 1000으로 설정
        
        self.df = df
        self.csv_file = csv_file  # csv_file 인자를 사용하여 파일 경로 저장
        self.index = 0
        
        # sentiment 열이 비어있는 행부터 시작
        self.index = self.find_first_empty_sentiment()
        
        # Group, Title, 댓글을 보여주는 라벨
        self.group_label = tk.Label(self.root, text="", font=("Arial", 30, "bold"), fg="gray")
        self.group_label.pack(pady=(5, 0))  # 줄 간격 줄이기
        
        self.title_label = tk.Label(self.root, text="", font=("Arial", 30, "bold"), fg="gray")
        self.title_label.pack(pady=(0, 5))  # 줄 간격 줄이기
        
        self.comment_label = tk.Label(self.root, text="", wraplength=600, height=5, font=("Arial", 30))
        self.comment_label.pack(pady=(0, 10))  # 줄 간격 줄이기
        
        # sentiment를 보여주는 라벨
        self.sentiment_info = tk.Label(self.root, text="Sentiment: ", font=("Arial", 30))
        self.sentiment_info.pack(pady=10)
        
        # 레이블링 현황을 보여주는 라벨
        self.count_label = tk.Label(self.root, text="", font=("Arial", 20))
        self.count_label.pack(pady=10)
        
        # list 버튼 추가
        self.list_button = tk.Button(self.root, text="List", command=self.show_list, font=("Arial", 20))
        self.list_button.pack(pady=10)

        # 종료 버튼 추가
        self.quit_button = tk.Button(self.root, text="종료", command=self.quit_program, font=("Arial", 20))
        self.quit_button.pack(pady=10)
        
        # Listbox 추가
        self.listbox = tk.Listbox(self.root, height=15, width=80, font=("Arial", 20))
        self.listbox.pack(pady=10)
        self.listbox.bind("<<ListboxSelect>>", self.on_select)

        # 키 바인딩
        self.root.bind("<Down>", self.sentiment_as_neutral)   # Neutral (1)
        self.root.bind("<Right>", self.sentiment_as_positive)  # Positive (2)
        self.root.bind("<Left>", self.sentiment_as_negative) # Negative (0)
        self.root.bind("<Shift-Left>", self.prev_comment)     # Shift + Left: 이전 댓글
        self.root.bind("<Shift-Right>", self.next_comment)    # Shift + Right: 다음 댓글
        
        # 처음 댓글 표시
        self.display_comment()

        # count_label 업데이트 (초기값)
        self.update_count_label()

    # sentiment가 비어있는 첫 번째 인덱스를 찾는 함수
    def find_first_empty_sentiment(self):
        for i, sentiment in enumerate(self.df['sentiment']):
            if pd.isna(sentiment) or sentiment == "":
                return i
        return 0  # 모든 sentiment가 채워져 있다면 첫 번째 행부터 시작

    def display_comment(self):
        group = self.df.loc[self.index, 'Group']
        title = self.df.loc[self.index, 'Title']
        comment = self.df.loc[self.index, 'comment']
        
        # Group, Title, 댓글 정보 표시
        self.group_label.config(text=f"Group: {group}")
        self.title_label.config(text=f"Title: {title}")
        self.comment_label.config(text=comment)
        
        # 감정 레이블 표시
        if 'sentiment' in self.df.columns and not pd.isna(self.df.loc[self.index, 'sentiment']):
            current_sentiment = self.df.loc[self.index, 'sentiment']
            self.sentiment_info.config(text=f"Sentiment: {current_sentiment}")
        else:
            self.sentiment_info.config(text="Sentiment: ")
        
        # 리스트 갱신
        self.update_listbox()

    def sentiment_as_neutral(self, event):
        self.save_sentiment("1")
        
    def sentiment_as_positive(self, event):
        self.save_sentiment("2")
        
    def sentiment_as_negative(self, event):
        self.save_sentiment("0")
        
    def save_sentiment(self, sentiment):
        self.df.loc[self.index, 'sentiment'] = str(sentiment)  # 타입을 str로 설정
        self.save_to_csv()  # CSV 저장
        self.next_comment(None)
        
    def prev_comment(self, event):
        if self.index > 0:
            self.index -= 1
        self.display_comment()
        
    def next_comment(self, event):
        if self.index < len(self.df) - 1:
            self.index += 1
        self.display_comment()

    def quit_program(self):
        self.root.quit()
        self.root.destroy()

    # CSV로 저장하는 함수
    def save_to_csv(self):
        self.df.to_csv(self.csv_file, index=False)  # self.filepath 대신 self.csv_file 사용
        print(f"CSV 저장 완료: {self.csv_file}")
        # 레이블링 현황 업데이트
        self.update_count_label()

    # count_label 업데이트 함수
    def update_count_label(self):
        count = f"{len(self.df) - sum(self.df['sentiment'].isna())} / {len(self.df)}"
        self.count_label.config(text=f"Labeled: {count}")
        print(count)

    # List 버튼 눌렀을 때 10개씩 댓글을 보여줌
    def show_list(self):
        self.update_listbox()

    # Listbox 업데이트 (앞뒤로 10개씩 보여줌)
    def update_listbox(self):
        self.listbox.delete(0, tk.END)
        start = max(0, self.index - 10)
        end = min(len(self.df), self.index + 10)
        
        for i in range(start, end):
            comment = self.df.loc[i, 'comment']
            sentiment = self.df.loc[i, 'sentiment']
            if i == self.index:
                self.listbox.insert(tk.END, f"→ {comment}")  # 현재 댓글을 화살표로 강조
                self.listbox.itemconfig(tk.END, {'bg': 'gray'})  # 현재 댓글의 배경색을 회색으로 설정
            else:
                self.listbox.insert(tk.END, comment)
                # sentiment가 비어있지 않으면 옅은 회색 배경 적용
                if pd.notna(sentiment) and sentiment != "":
                    self.listbox.itemconfig(tk.END, {'bg': '#d3d3d3'})  # 옅은 회색 배경

    # Listbox에서 댓글 선택 시
    def on_select(self, event):
        try:
            selection = event.widget.curselection()
            if selection:
                self.index = selection[0] + max(0, self.index - 10)  # Listbox에서 선택한 인덱스를 반영
                self.display_comment()
        except Exception as e:
            pass


# GUI 실행
root = tk.Tk()
app = LabelingApp(root, df, filename)
root.mainloop()
# Out:
# 0 / 120
# /var/folders/hw/9m3g7fvn4_l3rp2y473km9sm0000gn/T/ipykernel_73321/2575272723.py:97: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   self.df.loc[self.index, 'sentiment'] = str(sentiment)  # 타입을 str로 설정
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 1 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 2 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 3 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 4 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 5 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 6 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 7 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 8 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 9 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 10 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 11 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 12 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 13 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 13 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 14 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 15 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 15 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 16 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 17 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 17 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 18 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 19 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 20 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 21 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 22 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 23 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 24 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 25 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 26 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 27 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 27 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 28 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 29 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 30 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 31 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 32 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 33 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 34 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 34 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 34 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 34 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 35 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 36 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 37 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 38 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 39 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 40 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 41 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 42 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 43 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 44 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 45 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 45 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 45 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 45 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 46 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 47 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 48 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 49 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 50 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 51 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 51 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 52 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 53 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 54 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 55 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 56 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 57 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 58 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 59 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 60 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 61 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 62 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 63 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 64 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 65 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 66 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 67 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 68 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 69 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 70 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 71 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 72 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 73 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 74 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 75 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 76 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 77 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 78 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 79 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 80 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 81 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 82 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 83 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 84 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 85 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 85 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 86 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 87 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 88 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 89 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 90 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 91 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 92 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 93 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 94 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 95 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 95 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 96 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 97 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 98 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 99 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 100 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 101 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 102 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 103 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 104 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 105 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 106 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 107 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 108 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 109 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 109 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 110 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 111 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 112 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 113 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 114 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 115 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 116 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 117 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 117 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 118 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 119 / 120
# CSV 저장 완료: new_sampled_train_set_seg2_3.csv
# 120 / 120

# %%
df2 = pd.read_csv(filename)
df2[-30:]
# Out:
#       Index        Group                               Title  Unnamed: 0  \
# 90   541775     NewJeans                      Ditto (side A)        2130
# 91     2390        NMIXX                별별별 (See that)       16595
# 92   167005          IVE                          After LIKE      174276
# 93   108879         ITZY            마.피.아. In the morning      246077
# 94    79167  FIFTY FIFTY                               Cupid         506
# 95   142194         ITZY                             WANNABE      266192
# 96    62900  FIFTY FIFTY                        Starry Night        6479
# 97   484236     NewJeans                                 OMG       39115
# 98   526997     NewJeans                                 OMG       98557
# 99   388898        aespa                              Savage      202152
# 100  357809     NewJeans                          Bubble Gum       90826
# 101  590597          IVE                         해야 (HEYA)       13830
# 102  285048     NewJeans                           How Sweet       10837
# 103   60711  FIFTY FIFTY                        Starry Night        3021
# 104  213098  LE SSERAFIM                               CRAZY        6050
# 105  448083     NewJeans                           Super Shy       28881
# 106  614423          IVE                         해야 (HEYA)      105308
# 107  247933     NewJeans                                Zero       10337
# 108  123866         ITZY             달라달라(DALLA DALLA)      129682
# 109   61469  FIFTY FIFTY                        Starry Night        4119
# 110  436519        aespa                         Black Mamba      443788
# 111  145558          IVE                          After LIKE        6565
# 112   23443        NMIXX                                 O.O      126490
# 113  225813  LE SSERAFIM                       Perfect Night        7321
# 114   26350     NewJeans  Hype Boy' Official MV (MINJI ver.)        2445
# 115  320721     NewJeans                          Bubble Gum       14608
# 116  554800          IVE                          Either Way       35332
# 117  258096     NewJeans               Supernatural (Part.1)        5709
# 118  646941        STAYC                                ASAP       28453
# 119  140799         ITZY                             WANNABE      236632
#
#     comment_type              comment_id_key               parent_id_key  \
# 90         reply                         NaN  UgzKMY8mZgSy_yb51NZ4AaABAg
# 91          node  UgwWzFb0iBUqRtfiXeV4AaABAg                         NaN
# 92          node  UgxHSf8DTvWPIT_8OPZ4AaABAg                         NaN
# 93          node  UgwfeintvHrgPPYFppR4AaABAg                         NaN
# 94          node  UgyJFNU8yllxR3jrbkl4AaABAg                         NaN
# 95         reply                         NaN  Ugwoodp2sqQpQo_YYfN4AaABAg
# 96         reply                         NaN  UgxydMJAesG2NOaSWY94AaABAg
# 97          node  UgyBhPMllUFHE_WraZF4AaABAg                         NaN
# 98         reply                         NaN  UgwJLiEMvibLDeXjJOR4AaABAg
# 99          node  Ugy1IHzpUF5Ac8zZO714AaABAg                         NaN
# 100         node  UgwdBtxzA0kMps8uqNN4AaABAg                         NaN
# 101        reply                         NaN  UgzJ7yutGHxNTDsshHx4AaABAg
# 102         node  Ugzz9K9lO9zWYe61Ce54AaABAg                         NaN
# 103         node  UgwW4OYCf1aRMiUC0O14AaABAg                         NaN
# 104         node  UgzcI67W3hHvu9J5BvV4AaABAg                         NaN
# 105         node  UgzyyNDjeS0L1yud9CB4AaABAg                         NaN
# 106         node  UgyMP71I0oKHbgmy8t14AaABAg                         NaN
# 107         node  UgxghTvp7w07bMVdegh4AaABAg                         NaN
# 108         node  UgyBMM3b1Db9ggsVF6p4AaABAg                         NaN
# 109        reply                         NaN  UgyBJunDDAVlqubnoYl4AaABAg
# 110         node  UgxDSCrMd17TFEaqHrt4AaABAg                         NaN
# 111         node  Ugz6-4G1xFhto9VHmMB4AaABAg                         NaN
# 112         node  UgwxQa4dxTE0wksI7RF4AaABAg                         NaN
# 113         node  Ugxl5-7aob-mCrhH_Ch4AaABAg                         NaN
# 114         node  UgxIVOgJ4bTwhq4gjiB4AaABAg                         NaN
# 115         node  UgxQ3SBCvIhdBtmUcIh4AaABAg                         NaN
# 116         node  UgzHT2X54IGKYsjlh-t4AaABAg                         NaN
# 117         node  UgxTNGJsy7cbFaybag94AaABAg                         NaN
# 118         node  UgwdpzrRi08ntbVvcwh4AaABAg                         NaN
# 119         node  UgzMC2TXqVNw670Rf4N4AaABAg                         NaN
#
#                                                comment  \
# 90                                 반희수 = 버니즈 = 뉴진스 팬덤명
# 91                                     오렌지 먹은지 얼마나 오렌지
# 92                         솔직히 이 노래는 보컬없는 inst가 찐이다...
# 93                             솔직히 존나 박진영이 너무했잖아 이게뭐냐고
# 94               첫소절 부르는 친구 음색 진짜 너무 아깝다.....너무 좋은데 에휴
# 95                                      헐 진저님 안녕하세요!!!
# 96                                        함께 달려봅시다.~~️
# 97              여러분 구글 gemini(제미나이)에 식인의 연관성 쳐보면 알려주네요
# 98   제발 생각이란걸 하고 살아.... 뇌피셜밖에 없는 내용을 오피셜인 기사로 어캐 씀;;;;
# 99                                                 어스파
# 100                                        행복해라 뉴진스!!!
# 101  근데 정말 궁금해서 그러는데 여기서 귀엽게 칭얼거리는 중국인들은 이런 뮤직비디오 조...
# 102  뉴진스 공식채널에서 올린음원이 하이브 공식 뮤비 보다 조회수 높은게 말이되나 이정도...
# 103                              이왕 이렇게 된거 1500만 가자!!!
# 104                                               사랑해!
# 105         갠적으로 뮤비는 좀 별로다 뉴진스 아이브 다좋아하는데 아이엠보다 이거보니 영
# 106                                  이서 앞머리가 너무 잘 어울린다
# 107  역대급으로 스케일이 큰 무비인 것 같다. 뉴진스는 언제나 완벽️ 코카콜라 나오는 것...
# 108                                나만 선미 안무랑 비슷하다고 느낌?
# 109                                큐피드는 전홍준이 고른거다. ㅋㅋㅋ
# 110                                       윈터 닝닝 너무이쁘다!
# 111                                         ㅡ5랏ㄷㅅㅎㄷ혼ㄹㅎ
# 112  멤버들 호감인데 과유불급 같다.. 마피아 때도 느꼈지만 랩 디렉팅과 믹싱이 잘못된 ...
# 113                                           은채가 대박이네
# 114                         얘들은 미국에서 태어났어도 가수나 모델 했겠다.
# 115                                    매일 힐링하러 들어옴....
# 116       선우정아님 가사 너무 감동적이에요 그걸 살려준 아이브 멤버분들도 감동입니다 ㅠㅠ
# 117                                      뉴진스럽다 사랑스럽다 ️
# 118  약간 예전 sm감성인듯..... sm이 실험적으로 변하면서 잃었던 약간은 전형적인(...
# 119                               아니 왤케 좋냐 특히 류진 파트 첨에
#
#                      author                  date  likes  sentiment
# 90                 @박진엽-b6g  2024-04-30T16:34:32Z      0          1
# 91              @오렌지먹은지얼마나오  2024-08-19T13:50:27Z      1          1
# 92                 @Geugler  2022-08-22T09:24:18Z      1          1
# 93                  @치즈크로스토  2021-05-05T11:07:44Z      0          0
# 94         @user-nn3zr9rb8s  2024-09-22T16:33:23Z      3          0
# 95             @kellylee421  2020-03-09T15:06:21Z      0          1
# 96                    @내가빅팬  2024-09-06T22:38:35Z      1          2
# 97              @Dole-fn9lx  2024-04-29T08:56:06Z     11          1
# 98                  @Doggut  2024-04-28T05:42:23Z      0          0
# 99   @blueberrysmoothie6063  2021-10-06T15:50:12Z      0          1
# 100             @bibibi7415  2024-04-26T15:22:45Z      0          2
# 101                @unkle.k  2024-05-21T20:46:43Z      0          0
# 102                  @현-h1m  2024-06-04T07:05:16Z    580          0
# 103                  @혁신의시대  2024-09-10T20:04:19Z     26          2
# 104                  @하루1치킨  2024-09-11T14:22:14Z     14          2
# 105               @초코몽셀-h7u  2023-07-11T10:28:37Z      1          0
# 106          @songhajae8008  2024-04-29T09:06:44Z      0          2
# 107  @KimYihyun_TheYoutuber  2023-04-04T11:53:05Z      1          2
# 108                @강민서-s1w  2019-02-28T11:57:02Z      0          0
# 109              @katon-o1i  2024-09-09T00:07:49Z     16          2
# 110           @yetmusic2707  2020-11-18T02:57:18Z      1          2
# 111               @올탁구나-t2y  2023-07-29T05:20:35Z      0          1
# 112               @inThezOo  2022-02-23T07:39:53Z      2          0
# 113            @그녀석의눈동자-p5c  2023-11-30T10:09:46Z      3          2
# 114        @jongchanshin341  2022-12-22T14:43:09Z      2          2
# 115                  @빠밤빠바밤  2024-05-12T14:25:11Z     12          2
# 116                @홍정오-q8f  2023-09-25T09:19:18Z      0          2
# 117        @user-yb5js1et6d  2024-07-01T12:16:06Z      7          2
# 118                  @얌-x8p  2021-04-11T16:12:05Z      2          2
# 119                 @곤듀-g5k  2020-03-11T04:27:33Z      7          2

# %%
import pandas as pd

df1 = pd.read_csv('12000/learning_set_4000(1).csv')
df2 = pd.read_csv('12000/learning_set_4000(2).csv')
df3 = pd.read_csv('12000/learning_set_4000(3).csv')

df_full = pd.concat([df1, df2, df3], axis=0)

# %%
# 0, 3, 12, 13 열 드랍 (순서로)
print(df_full.columns[[0,3,12,13]])
df_full_clean = df_full.drop(df_full.columns[[0, 3, 12, 13]], axis=1)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 12', 'Index'], dtype='object')

# %%
df_full_clean.to_csv('12000/learning_set_12000.csv', encoding='utf-8-sig', index=False)

# %%
from sklearn.model_selection import train_test_split

# 10000개 샘플 추출
df_full_clean_train, remaining_df = train_test_split(df_full_clean, train_size=10000, random_state=42)

# 나머지 데이터프레임에서 1000개 샘플 추출
df_full_clean_valid, df_full_clean_test = train_test_split(remaining_df, train_size=1000, random_state=42)

print(len(df_full_clean_train))
print(len(df_full_clean_valid))
print(len(df_full_clean_test))

df_full_clean_train.to_csv('12000/learning_set_train_10000.csv', encoding='utf-8-sig', index=False)
df_full_clean_train.to_csv('12000/learning_set_valid_1000.csv', encoding='utf-8-sig', index=False)
df_full_clean_train.to_csv('12000/learning_set_test_1000.csv', encoding='utf-8-sig', index=False)
# Out:
# 10000
# 1000
# 1000

# %%
df_full_clean_train['sentiment'].value_counts()
# Out:
# sentiment
# 2    5778
# 0    2395
# 1    1827
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.utils import resample

# 예시 데이터프레임 (sentiment 레이블과 그 외 feature들로 구성된 데이터프레임)
# df = pd.read_csv('your_data.csv') 또는 적절한 데이터 로드 방식 사용

# 'sentiment'가 0, 1인 데이터프레임 필터링
df_0 = df_full_clean_train[df_full_clean_train['sentiment'] == 0]
df_1 = df_full_clean_train[df_full_clean_train['sentiment'] == 1]
df_2 = df_full_clean_train[df_full_clean_train['sentiment'] == 2]  # 클래스 2는 이미 6963개이므로 그대로 사용

# 각 클래스를 6963개로 맞추기 위해 오버샘플링
df_0_oversampled = resample(df_0, replace=True, n_samples=len(df_2), random_state=42)
df_1_oversampled = resample(df_1, replace=True, n_samples=len(df_2), random_state=42)

# 오버샘플링된 데이터와 기존 클래스 2 데이터를 합침
df_balanced = pd.concat([df_0_oversampled, df_1_oversampled, df_2])

# 데이터프레임을 섞어줌 (optional)
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)
df_balanced = df_balanced.sample(n=17000, random_state=42)

# 결과 확인
print(df_balanced['sentiment'].value_counts())
# Out:
# sentiment
# 2    5677
# 1    5674
# 0    5649
# Name: count, dtype: int64

# %%
df_balanced.to_csv('12000/learning_set_train_17000_oversampled.csv', encoding='utf-8-sig', index=False)
