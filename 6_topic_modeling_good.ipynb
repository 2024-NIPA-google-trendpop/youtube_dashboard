# %%
import os
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation


import time
import tqdm
import jpype
import ast

# %%
# 전처리, 명사추출, 키워드추출, 불용어후처리, 닉네임추출까지 마친 데이터

import pandas as pd

folder_path = '/Users/jaesolshin/Documents/GitHub/youtube_dashboard'
file_path = os.path.join(folder_path, 'KPOP_comments_merged_preprocessed_after_cleaning_nickname.csv')
comments_df = pd.read_csv(file_path)
sample_df = comments_df.copy()

# 특정 그룹에 대해 분석 수행
sample_df = sample_df[sample_df['Group']=='NMIXX']

# csv 파일로 저장되면서 문자열로 변형된 word_list 컬럼을 다시 리스트로 변환
sample_df['word_list'] = sample_df['word_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
sample_df['word_list'] = sample_df['word_list'].apply(lambda x: " ".join(x))
print(len(sample_df))

# word_list가 빈 문자열인 행 제거
sample_df = sample_df[sample_df['word_list'] != '']  # 빈 문자열인 행 제거
print(len(sample_df))

#  members 컬럼을 다시 리스트로 변환
sample_df['members'] = sample_df['members'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
# Out:
# 23511
# 20160

# %%
# TF-IDF 벡터화 (전체 데이터에 대해 벡터화 수행)
tfidf_vectorizer = TfidfVectorizer(max_features=1000)  # 최대 1000개의 단어만 사용
tfidf_matrix = tfidf_vectorizer.fit_transform(sample_df['word_list'])

# LDA 모델 학습 (전체 데이터에 대해 학습)
n_topics = n_top_words = 20  # 원하는 토픽 수 설정
lda = LatentDirichletAllocation(n_components=n_topics, 
                                max_iter=5,
                                topic_word_prior=0.1,
                                doc_topic_prior=1.0,
                                learning_method='online',
                                n_jobs=-1,
                                random_state=42)

lda.fit(tfidf_matrix)

# 각 댓글에 대해 토픽 분포 추출 (댓글별로 토픽 분포 계산)
topic_distributions = lda.transform(tfidf_matrix)

# 'topic_distribution' 열에 토픽 분포 저장
sample_df['topic_distribution'] = list(topic_distributions)

def print_top_words(model, feature_names, n_top_words=n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"\n===== 토픽 {topic_idx + 1} =====")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))

tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
print_top_words(lda, tfidf_feature_names, n_top_words)
# Out:
# ===== 토픽 1 =====
# 별로 노래 무대 시간 엔믹스 음방 나라 리듬 디스 후렴 뮤비 홍콩 콘서트 거슬러 노랜 응원 컨셉 굳이 드뎌 나중
#
# ===== 토픽 2 =====
# 음악 노래 엔믹스 실망 신인 권모술수 하루 가수 반응 신경 호불호 대중 올해 표절 매번 평가 오해원 가창력 사랑해 미래
#
# ===== 토픽 3 =====
# 엔믹스 노래 라이브 이해 응원 친구 수준 가즈아 혼란 구리 실력 사랑해 리스닝 체인지 밴드 주식 컴백 완성 도전 구림
#
# ===== 토픽 4 =====
# 정신 노래 목소리 지우 엔믹스 도입 해원 뮤비 영어 사랑해 해외 하이라이트 멤버 릴리 수고 표정 살짝 설윤 실력 국내
#
# ===== 토픽 5 =====
# 중독 엔믹스 자꾸 얼마나 별별별 케이팝 이상 노래 거지 주년 버전 오오 무조건 재생 뭐임 최근 후렴구 안티 구나 컨셉
#
# ===== 토픽 6 =====
# 엔믹스 파트 재능 노래 핑크 릴리 퀄리티 컴백 왤케 찰떡 상큼 웅장 정체 구성 체인지업 그녀 소속사 제왑 기대 띵곡
#
# ===== 토픽 7 =====
# 지니 노래 한국어 박진영 엔믹스 음원 파이팅 작곡 대형 엔깅이들 자막 고생 기획사 준비 썸네일 여러 안무가 멜론 세대 감성
#
# ===== 토픽 8 =====
# 장르 엔믹스 선공 노래 머리 윤아 도대체 컴백 뮤비 제왑 사랑해 언제 음색 배진솔 대쉬 본부 스타 노력 테마 킬링
#
# ===== 토픽 9 =====
# 분위기 타이틀곡 타이틀 수록곡 아이돌 마음 약간 댄스 최고 코디 엔믹스 노래 장규진 원더걸스 오해원 커버 걱정 이곡 홍보 게뭐
#
# ===== 토픽 10 =====
# 컨셉 트와이스 노래 소름 해원 엔믹스 문제 갑자기 기분 개성 포기 가요 작곡가 뮤비 장면 관심 멤버 이미지 꽃길 외국인
#
# ===== 토픽 11 =====
# 역대 노래 여름 다이스 실험 엔믹스 벌써 티저 화이팅 몇번 금발 아아 옛날 무엇 겨울 설윤 성적 대기업 갈수록 론데
#
# ===== 토픽 12 =====
# 노래 화이팅 엔믹스 에스파 여자 설윤 언니 명곡 헤메 제목 극락 외국 사운드 활동 스키 센터 가사도 매일 심장 일링
#
# ===== 토픽 13 =====
# 노래 가사 사랑해 쩐다 뮤비 엔믹스 진심 차트 당황 제왑 타이틀 전혀 히트 세번 기대 기존 애기 어케 권모술수 컨셉
#
# ===== 토픽 14 =====
# 노래 안무 엔믹스 한국 멜로디 개인 제대로 롤러코스터 힙합 외모 고음 동요 세대 안녕 팬덤 냄새 개별 영화 순간 릴리
#
# ===== 토픽 15 =====
# 데뷔 노래 엔믹스 소녀 한국인 얼굴 장난 컨셉 런가 최악 아쉬움 인기 컴백 콜라 존예 릴리 지원 뮤비 얼마 생일
#
# ===== 토픽 16 =====
# 노래 스타일 비주얼 엔믹스 레전드 중간 색깔 의상 회사 뮤비 탱크 일본 세대 멤버 실력 베이 스트리밍 방법 릴리 난해
#
# ===== 토픽 17 =====
# 보컬 엔믹스 조회수 노래 와우 취향 미모 뮤직비디오 아이브 대체 초반 사랑해 실력 인정 파이팅 구려 프로 인생 비디오 벨벳
#
# ===== 토픽 18 =====
# 신곡 사랑해 노래 걸그룹 대중성 뉴진스 엔믹스 최애 중소 왜케 퍼포먼스 귀가 김지우 성공 배경 시도 아기 진심 이제야 릴리
#
# ===== 토픽 19 =====
# 노래 규진 엔믹스 매력 최선 컴백 활동 누나 이노 입덕 비쥬 광고 뮤비 전체적 릴리 중국 정상 발음 더더 홧팅
#
# ===== 토픽 20 =====
# 노래 듣기 비트 충격 세계관 반복 제왚 유행 능력 응원 청량 앨범 엔믹스 르세라핌 달라 포인트 나이 기획 사랑해 파워

# %%
# Title별로 토픽 분포의 평균 계산
title_topic_distribution = sample_df.groupby('Title')['topic_distribution'].apply(lambda x: sum(x) / len(x))

# 정의된 토픽이름(결과 보고 이름붙임)
topic_names = {
    1: "무대 연출과 스타일",
    2: "음악 평가와 반응",
    3: "실력과 라이브 퍼포먼스",
    4: "멤버와 팬 감정",
    5: "중독성 있는 케이팝",
    6: "퀄리티와 개인 파트",
    7: "음원 성적과 대중 반응",
    8: "장르와 뮤직비디오 분석",
    9: "타이틀곡과 댄스 퍼포먼스",
    10: "컨셉과 비주얼 매력",
    11: "성과와 활동 평가",
    12: "명곡과 인기 요소",
    13: "진심과 감정 표현",
    14: "안무와 외모 평가",
    15: "데뷔와 인기 상승",
    16: "비주얼과 스타일링",
    17: "보컬 능력과 조회수",
    18: "걸그룹과 퍼포먼스 성공",
    19: "매력과 컴백 활동",
    20: "세계관과 충격 요소"
}


# Title별 상위 세 개의 토픽 분포 출력
for title, topic_dist in title_topic_distribution.items():
    print(f"\n===== {title} 그룹의 상위 3개 토픽 분포 =====")
    
    # 토픽 분포를 (토픽 번호, 확률) 형식으로 정렬
    sorted_topic_dist = sorted(enumerate(topic_dist, 1), key=lambda x: x[1], reverse=True)
    
    # 상위 3개 토픽만 출력
    for i, prob in sorted_topic_dist[:3]:
        print(f"{topic_names[i]}: {prob:.4f}")


# 첫 번째 샘플의 topic_distribution에서 최대값의 인덱스를 찾기
def get_topic_name(value):
    # 토픽 분포 중 최대값의 인덱스를 찾고, 그에 해당하는 토픽 이름 반환
    idx = np.argmax(value) + 1  # 1을 더해서 topic_names에 맞는 인덱스로 변환
    return topic_names[idx]

# 댓글의 topic_distribution에서 상위 3개의 토픽 이름을 얻기
def get_topic_names(value):
    # 토픽 분포를 내림차순으로 정렬한 후 상위 3개의 인덱스를 찾고, 그에 해당하는 토픽 이름을 반환
    top_indices = np.argsort(value)[-3:][::-1]  # 상위 3개 인덱스 (내림차순으로 정렬)
    top_topics = [topic_names[idx + 1] for idx in top_indices]  # 1을 더해서 topic_names에 맞는 인덱스로 변환
    return top_topics


sample_df['topic_distribution'] = sample_df['topic_distribution'].apply(get_topic_name)
# Out:
# ===== DASH 그룹의 상위 3개 토픽 분포 =====
# 장르와 뮤직비디오 분석: 0.0506
# 진심과 감정 표현: 0.0506
# 퀄리티와 개인 파트: 0.0506
#
# ===== DICE 그룹의 상위 3개 토픽 분포 =====
# 보컬 능력과 조회수: 0.0508
# 음원 성적과 대중 반응: 0.0505
# 안무와 외모 평가: 0.0503
#
# ===== Funky Glitter Christmas 그룹의 상위 3개 토픽 분포 =====
# 음원 성적과 대중 반응: 0.0516
# 음악 평가와 반응: 0.0513
# 퀄리티와 개인 파트: 0.0512
#
# ===== Love Me Like This 그룹의 상위 3개 토픽 분포 =====
# 무대 연출과 스타일: 0.0510
# 중독성 있는 케이팝: 0.0506
# 타이틀곡과 댄스 퍼포먼스: 0.0505
#
# ===== O.O 그룹의 상위 3개 토픽 분포 =====
# 데뷔와 인기 상승: 0.0520
# 진심과 감정 표현: 0.0507
# 명곡과 인기 요소: 0.0504
#
# ===== Party O’Clock 그룹의 상위 3개 토픽 분포 =====
# 성과와 활동 평가: 0.0512
# 명곡과 인기 요소: 0.0508
# 컨셉과 비주얼 매력: 0.0506
#
# ===== Roller Coaster 그룹의 상위 3개 토픽 분포 =====
# 성과와 활동 평가: 0.0515
# 세계관과 충격 요소: 0.0508
# 퀄리티와 개인 파트: 0.0506
#
# ===== Soñar (Breaker) 그룹의 상위 3개 토픽 분포 =====
# 장르와 뮤직비디오 분석: 0.0508
# 음악 평가와 반응: 0.0507
# 퀄리티와 개인 파트: 0.0507
#
# ===== Young, Dumb, Stupid 그룹의 상위 3개 토픽 분포 =====
# 멤버와 팬 감정: 0.0516
# 안무와 외모 평가: 0.0516
# 타이틀곡과 댄스 퍼포먼스: 0.0512
#
# ===== 별별별 (See that) 그룹의 상위 3개 토픽 분포 =====
# 걸그룹과 퍼포먼스 성공: 0.0508
# 중독성 있는 케이팝: 0.0505
# 타이틀곡과 댄스 퍼포먼스: 0.0505
#
# ===== 蜚蜚 (FEIFEI) 그룹의 상위 3개 토픽 분포 =====
# 무대 연출과 스타일: 0.0593
# 매력과 컴백 활동: 0.0518
# 중독성 있는 케이팝: 0.0509

# %%
# 출력 옵션 설정: 모든 열을 출력
pd.set_option('display.max_columns', None)  # 모든 열 출력
pd.set_option('display.max_rows', None)     # 모든 행 출력

sample_df[['comment','topic_distribution']].head(200)
# Out:
#                                                comment topic_distribution
# 0                     엔믹스 노래 중독성 있고 좋은데 왜 안뜨는지 진심 의문..         중독성 있는 케이팝
# 1    대쉬랑 비슷한것 같기도하고 이젠 좀 다른 대중성있는 노래로갔으면하는 아쉬움이있네요 ...          안무와 외모 평가
# 2    4본부장아 피씨로 엘범 클릭하면 별별별 뮤비로 연결 안되고 수정별인가 그 장면 있는...          안무와 외모 평가
# 3                                         이야 노래 종나 멋있네          진심과 감정 표현
# 4    외모췍을 필두로 더더더더 빵빵뜨길...리더로서 해원이 얼마나 노력했을까...멤버들 ...          데뷔와 인기 상승
# 5                          노래는 좋은데 ㅋㅋ 가사는 개짜치는 별별별ㅋㅋㅋㅋ         중독성 있는 케이팝
# 6             해원이 외모체크 이후로 찐팬됨 멤버 모두 너무 착하고 예쁨 실력도 탑이네          안무와 외모 평가
# 7    와 진짜 설윤이랑 지우랑 비주얼 폭발하는 노래 하나 타이틀로 내자 정말 엔믹 요즘 ...          성과와 활동 평가
# 8                       [timecode] 이어폰 까고 들으니까 무슨 연극같음          명곡과 인기 요소
# 9                                                  ㅈ구림       실력과 라이브 퍼포먼스
# 10                    이 노래가 37위 라고?1위에서3위 안에 들어갈줄 알았는데          진심과 감정 표현
# 11   노래가 먼이따구냐 대형기획사에서 낸 뮤비 조회수가 중소 걸그룹보다 못하네 걍 예능활...       음원 성적과 대중 반응
# 12                                                사랑해요       걸그룹과 퍼포먼스 성공
# 13                                 규진이 교정웃음 왜이리이쁘지? ㄷㄷ          매력과 컴백 활동
# 14          아니 중간에 엔믹스~ 하고 나오는 부분좀 그만했으면 좋겠어 맥끊겨......          비주얼과 스타일링
# 15                     소녀감성 다 필요없어.....평생 힙합해줘........         무대 연출과 스타일
# 16   K팝 아티스트 최초 빌보드 라틴 뮤직 위크 참석 (유튜브로 직접 검색) 언제나 반전...         보컬 능력과 조회수
# 17                                     진짜 규진 설윤 너무 이쁘당          매력과 컴백 활동
# 18                              솔직히 실력으로는 앤믹스가 원탑 아니냐?       실력과 라이브 퍼포먼스
# 20                                              베이스 미침          비주얼과 스타일링
# 22   항상 엔믹스의 노래는 최고였는데 이번 별별별 노래도 정말 좋은것 같아요! 노래 실력...       실력과 라이브 퍼포먼스
# 23        역시 엔믹스 믿고 있었어 좀 별나고 특이하면 어때 엔믹스는 존재자체로 별인데⭐️          성과와 활동 평가
# 26                                         와 오해원 음색 쩐다          진심과 감정 표현
# 27         와.. 엔믹스 이 노래로 좀 알게 됬는데... 이 노래에 빠짐.. 팬아저..!          진심과 감정 표현
# 28                                와앙...이번 노래 최고당....ㄷㄷ          진심과 감정 표현
# 29                                   [timecode] 김쮸 기여워          비주얼과 스타일링
# 30                        [timecode] 릴리 뭐 먹는 거 왜케 귀엽냐ㅋ       걸그룹과 퍼포먼스 성공
# 31   ㄹㅇ 이번곡 취직이네 전멤버가 노래를 잘해서 합창화음 잘뽑을수 있는게 노래를 업그레...          비주얼과 스타일링
# 32                                                 사랑해       걸그룹과 퍼포먼스 성공
# 33   NSWER NMIXX에 또 다른 WIN을 줄 기회가 있습니다. 비디오를 대량으로 전...         세계관과 충격 요소
# 34   목소리 너무 좋고..이번 컴백 너무 좋다...공부하고 있었는데 머리 속에서 이 노래...           멤버와 팬 감정
# 35                  정말 간만에 찍어보는 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ10 out of 10         무대 연출과 스타일
# 36   개인적으로 슈퍼노바 이딴 노래보다 이런 노래가 더 좋다 엔믹스 노래 넘 좋다 멤버들...          안무와 외모 평가
# 37                           너무 귀여워 우! 아 사랑해 나의 작은 공주들          비주얼과 스타일링
# 38                  지우 너무 예븥다.....엔믹스가 너무 조하 기여미 지우...          비주얼과 스타일링
# 39                                          아오 소름 돋아..         컨셉과 비주얼 매력
# 40   NSWER NMIXX에 또 다른 WIN을 줄 기회가 있습니다. 비디오를 대량으로 전...         세계관과 충격 요소
# 41   Nswer에게 NMIXX에 또 다른 승리를 줄 수 있습니까? 모금하고 승리할 수 있...          비주얼과 스타일링
# 42                            아 노래 개좋은데 왜 팬들은 아쉬워하는거같지          진심과 감정 표현
# 43                                 [timecode] 여기 극락 파트          명곡과 인기 요소
# 44                                           노래 레전드...          비주얼과 스타일링
# 45                               이거 1.25배속 하면 겁나 좋아...         무대 연출과 스타일
# 46                                     규진이 처피뱅 ㄹㅇ 갸귀여움          매력과 컴백 활동
# 47   엔믹스 구독했음 엔믹스 화이팅 독도 노래 불렀다고 일본 우익들이 지랄하던데 신경쓰지...          음악 평가와 반응
# 48   노래도 노래지만 엔믹스 모든 총체적인 비주얼 발전도 놀랍고 멋있다! 각각 멤버의 생...       장르와 뮤직비디오 분석
# 49                                                 애국자         무대 연출과 스타일
# 50   아이브 작곡가 섭외해서 노래 만들어봐 대기업이 중소기업 작곡가보다 못한 노래만 들고...          성과와 활동 평가
# 51           마지막에 설윤이 “으-으음~음..” 이러는거 전화그거에 해원에 그거 아닌가          성과와 활동 평가
# 52                                    실력도 넘사벽…노래도 넘사벽…       실력과 라이브 퍼포먼스
# 54                       잉머지… 별별별 좀 웃기긴한데 노래 존나 좋네… ㅜㅜ       장르와 뮤직비디오 분석
# 56                                              안동역에서드         무대 연출과 스타일
# 57       노래 진짜 잘뽑혔는데 별별..뭐..?… 워딩이 너무 튄다… 노래ㅡ진짜 개개개좋은데          진심과 감정 표현
# 58   제왑아... 아직도 헛발질 하고 있구나 원걸 투펨 부터 제왑 팬이였는데 그땐 박진영...          명곡과 인기 요소
# 59   쯧쯧 음악에 취미가 없나봐. Nmixx를 좋아한다면 Nmixx는 놀라운 음악을 만들...       실력과 라이브 퍼포먼스
# 60                                   뇌세포드립 어휴 . 상대안할란다         무대 연출과 스타일
# 61                                          엔믹스 볼 맛 난다         퀄리티와 개인 파트
# 62                            헐 전화로 스포했던거 가사랑 뮤비에 다 있어          성과와 활동 평가
# 63   1.25배속으로 나왔으면 더 떴을 것 같음 유산소하는데 노래가 묘하게 느려서 신이 안나ㅜ      타이틀곡과 댄스 퍼포먼스
# 64                  배이 완전 커트 한번 했으면 좋겠음 완전 보이시하고 멋있을 듯         무대 연출과 스타일
# 65                                                 잘하넴         무대 연출과 스타일
# 66    별별별에 별은 월레 노랑빛이 나는데 지우 금발로 염색 한거 너무 이쁘다 음색도 잘어울림          성과와 활동 평가
# 67   그저께 처음 들었어요오... 처음엔 이게 뭔 노래야 별노래가 다 있네~ 했는데 어제...         보컬 능력과 조회수
# 68            @@Metropolis000굳이 뮤비까지 찾아와서 악플을 써야하니 븅아?         무대 연출과 스타일
# 69   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 70   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 71   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 72   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 73   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 74                             엔믹스 전담 프로듀서는 엔믹스를 싫어한다.      타이틀곡과 댄스 퍼포먼스
# 75                                    코디 진짜 이번에 완전 찰떡임      타이틀곡과 댄스 퍼포먼스
# 76   처음 들었을땐 대중적인 노래로 들고올줄알았는데 여전히 믹스팝이네 하는 약간의 아쉬움...          데뷔와 인기 상승
# 77                지우라는 멤버가 보물같다 개잘함 이 멤버가 부르면 전부 킬링파트임       장르와 뮤직비디오 분석
# 78   혹시 얼마전에 회사에 매니저 많이 들어왔나요? 인적사항 가족사항 다 확인 잘 하시고...      타이틀곡과 댄스 퍼포먼스
# 79   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 80   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 81   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 83                                        와 노래 진짜 잘뽑았다          진심과 감정 표현
# 84                                          노래 너무 좋아요!          진심과 감정 표현
# 85   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 86   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 87   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 88   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 90   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 91                     곡에 밀당과 다채로움이 부족해 더 굴러라 4본부 직원들아         세계관과 충격 요소
# 92   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 93   @@haewon.polarbear 번역기가 잘못 번역한 거 같아요. 내 얘기는 님이...          안무와 외모 평가
# 94   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 95   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 96   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 97   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 98   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 99   활동 끝났으니 할 얘기 좀 해야겠다. 앨범도 매번 사고 스트리밍은 나보다 많이 한 ...       걸그룹과 퍼포먼스 성공
# 100  인도 힙합노래 영상 좋아서 듣다가 앤믹스 신곡이랑 비슷하다는 댓글보고 찾아왔는데 비...          안무와 외모 평가
# 101                     엔믹스 너네가 어둠의 자식들이냐 믹스팝 좀 키고 살아라         퀄리티와 개인 파트
# 102                     엔믹스 참 좋아하는데... 노래는 참 나올때마다 별루네          진심과 감정 표현
# 103          그래도 실력이 있으니까 결국은 엔믹스의 천하가 오긴 오는는구나! 대단하다.       실력과 라이브 퍼포먼스
# 105                                     오 뭔가 스키즈 느낌 난다          명곡과 인기 요소
# 106  결론은 문제가 뭐냐면 엔믹스는 영어도 못하면서 저렇게 어메리칸팝스럽게 음악을 하면 ...       걸그룹과 퍼포먼스 성공
# 107  내가 생각하기에는 엔믹스 음악은 제이와이피가 의도한건지는 모르겠지만 케이팝하고는 거...         컨셉과 비주얼 매력
# 108                                   ？？니 뇌피셜은 그렇구나ㅋㅋㅋ         무대 연출과 스타일
# 109                                            사랑해요 해원         컨셉과 비주얼 매력
# 110                      엔믹스 멤버들 하나하나 다 빛난다 이번 노래 조아용ㅇ           멤버와 팬 감정
# 111                                             역주행 가자          명곡과 인기 요소
# 112  이번 엔믹스 노래 합격 중독성 있고 머리에 멤돌먼서 흥얼거리는 길가다가 계속 들을것...       걸그룹과 퍼포먼스 성공
# 114                                            엔믹스 쪼아요         퀄리티와 개인 파트
# 115                     엔믹스 적자 메꾸려고 일루미나티한테 돈받았나 ㅋㅋㅋㅋㅋ         퀄리티와 개인 파트
# 116                  아니ㅁㅊ지우뭐야 ㅓ어ㅏㅣㅣ.!??“.개이뻐ㅜㅠㅠㅠㅜㅜㅡㅡㅡㅡ           멤버와 팬 감정
# 117          뮤비 하늘 나는 부분 찐으로 멋있달까?진짜로 난건 아니지만 엔믹스 외모쵴!          안무와 외모 평가
# 118                                           내 취향은 아님         보컬 능력과 조회수
# 119             와 곡 너무 좋다 나온지도 몰랐었네!!!! 마케팅좀 팍팍 해주라!!!         무대 연출과 스타일
# 120                              규진이 왜케 귀엽지 갈수록 귀여워지네.       걸그룹과 퍼포먼스 성공
# 121  엔믹스는 팬 아니라도 컴백하면 꼭 찾아듣게 됨. 줏대있게 색 잃지말고 끝까지 줏대있...          안무와 외모 평가
# 122                   노래가 안질려 ㅋㅋㅋㅋㅋㅋㅋ 엔믹스 너무 잘한다 진짜 ..          진심과 감정 표현
# 123                                             노래 개별로          안무와 외모 평가
# 124                  다음 컨셉은 쳥량한 트와이스 느낌나게 컴백 해주면 좋겠다 ㅠ         컨셉과 비주얼 매력
# 125                                   와 존나 멋있다 소름돋았어..         컨셉과 비주얼 매력
# 126                                  [timecode] 내 최애파트       걸그룹과 퍼포먼스 성공
# 127                  릴리 이렇게 잘하는데 분량 조금만 늘려줘라 이 소속가 자식아         퀄리티와 개인 파트
# 129               하이라이트 부분이 왜이렇게 쇼미더머니에 나왔던 ‘패’랑 비슷하지?           멤버와 팬 감정
# 130                                         아 노래 진쨔 조타          진심과 감정 표현
# 131                             요자는 별뵬뵬!@~!?~?@!~?~???         무대 연출과 스타일
# 132                             진짜 이번 수록곡도 좋고 별별별 넘 좋음      타이틀곡과 댄스 퍼포먼스
# 133                    확실한건 존나 멋있다는거야. 엔믹스가 걸그룹에서 젤 탑임       걸그룹과 퍼포먼스 성공
# 134      그 무슨 팬이냐.. 미친팬들.. 사생? 걔네때메 서터레서 받지망. 우리가 더 세!         무대 연출과 스타일
# 137                       규진이 너무 예쁜고 멋져 보여 최고 보면 진짜 최고          매력과 컴백 활동
# 139                   청개구리 두더쥐.. 여돌은 대중성인데 노래 가사가.. ㅠㅠ          매력과 컴백 활동
# 140                   다음 곡은 제발 개쩌는거 들고와서 터트려주세요 제왚님들..         무대 연출과 스타일
# 141                                          어 너만 불만이야         무대 연출과 스타일
# 142                                         뉴진스보다 훨씬낫다          데뷔와 인기 상승
# 143                                                 망돌         무대 연출과 스타일
# 144                                             염소돌 ㅎㅇ         무대 연출과 스타일
# 145                               처음에는 이상했는데 자꾸 손이가요..         컨셉과 비주얼 매력
# 146                                         엔믹스 넘후 살앙해         퀄리티와 개인 파트
# 147                                             오해원 존예          데뷔와 인기 상승
# 148                                           노래 좋네요 응          진심과 감정 표현
# 149                          나는 이 노래를 좋아한다 나는 그것을 좋아한다          진심과 감정 표현
# 150                             우리는 당신을 사랑하고 당신을 지원합니다          데뷔와 인기 상승
# 151                                          라이브로 듣고싶다       실력과 라이브 퍼포먼스
# 153                                         릴리야 너무 에쁘다         퀄리티와 개인 파트
# 154                               태양을 얻지 못한자 지배할 수 없다.         무대 연출과 스타일
# 155                                          도입부 찢었는데?           멤버와 팬 감정
# 156         프로미스나인 라이벌로 딱 b급 그룹 수문장 어케 케플러보다 조회수가 안나오냐         보컬 능력과 조회수
# 157  나는 이 노래가 호불호가 갈리는다는걸 댓글보고 알음 듣자마자 난 너무너무 좋다고 생...          음악 평가와 반응
# 158                                              노래개좋네          진심과 감정 표현
# 159                               0:38배이 파트 진짜 내 최애 파트       걸그룹과 퍼포먼스 성공
# 160                                          렌즈값 물어주세요         무대 연출과 스타일
# 161                                          릴리 파트 지리누          성과와 활동 평가
# 163                            진짜 우리 엔믹스 너무 멋져 항상 응원해!       실력과 라이브 퍼포먼스
# 164                             배진솔 미쳤다 금발단발 너무 너무 까리함          진심과 감정 표현
# 165                               다 너무 예쁘시고 노래 너무 잘하세요          진심과 감정 표현
# 166                                    엔믹스 만세! JYP 만세!         퀄리티와 개인 파트
# 167  유향과 대세에서도 밀리지 않고 자기 스타일대로 자신의 길을 가는 엔믹스 멋지따! 엔...       음원 성적과 대중 반응
# 168                                                터죳냐         무대 연출과 스타일
# 169  엔믹스!! 뮤비를 몇번보는지 모르겠다..ㄷㄷ 노래도 너무 좋고!! 항상 열심히 활동...          성과와 활동 평가
# 170     코첼라로 떡락한 르세라핌도 못 이길거 같은 노래네; 얘네 노래는 이런게 한계인가..         무대 연출과 스타일
# 172                    @@lovelorn66 귀구멍 막힌 놈이라 어쩔 수 없음         무대 연출과 스타일
# 174  엔믹스 노래 아예 안들어본 사람은 있겠지만 한번들어본 사람은 없다ㅠ오해원 사랑해!!...      타이틀곡과 댄스 퍼포먼스
# 175                    헤메코 개쩐다.................너무 아름다움          명곡과 인기 요소
# 176              애들 다 이쁘고 노래도 좋은데 뮤비가 너무 음.... 너무 정신없네           멤버와 팬 감정
# 177                         [timecode] 신발 정보 아시는 분...?       걸그룹과 퍼포먼스 성공
# 179                딸래미들 팬되브려따 모두들 이쁘고 잘해서 좋아 사랑혀 ㅋㅋㅋㅋㅋ         무대 연출과 스타일
# 180                앤믹스 유퀴즈온더블럭 놀면뭐하니 런닝맨 핑계고 틈만나면 좋겠어요         무대 연출과 스타일
# 181  너무 아쉬운게 라이브논란에 학생 비하논란에 친일 논란까지있던 르세라핌이 9일만에 약...          매력과 컴백 활동
# 182                    ??? 7명이였다가 6명이 된거입니다. 4명인적이 없어요      타이틀곡과 댄스 퍼포먼스
# 183                                                 감사         세계관과 충격 요소
# 185                      우리 윤아 외삼촌이 항상 응원한다 추석에 보자~~^^       장르와 뮤직비디오 분석
# 186  댓글보는데 자꾸 까는 애들이 있네 그냥 좀 봐라 여기까지 와서 댓글로 분탕짓 하지말...           멤버와 팬 감정
# 187                         어머 규진이 교정기 머야 피어싱같아 왜 잘어울령          매력과 컴백 활동
# 188  근데 이번 MV에서 [timecode] 규진이 파트에 규진 진짜 이뿌당~~ [tim...          매력과 컴백 활동
# 189  처음엔 하늘 별만 말하는줄 알았는데 듣다보니까 하여튼간 이런저런 별별일이 다 있다 ...          안무와 외모 평가
# 190                     하늘의 뜬별 별의별일 별의 별사람 다 있다 이런뜻맞아요          안무와 외모 평가
# 191                                     비주얼 아름답다 진심...          비주얼과 스타일링
# 192                워 ~ 조회수 대박 ~ ㅋㅋㅋ 정서주 도 언젠가는 ... ㅋㅋㅋ         보컬 능력과 조회수
# 194                                 곡 개찰떡 엔믹스 요즘 팬 늘은듯         퀄리티와 개인 파트
# 195  달라서 더 좋은데 누구네처럼 유행에 쫓겨 맞지도 않는 컨셉 밀고 가는것보다 그룹색이...         세계관과 충격 요소
# 197                                            와 서태지같다          음악 평가와 반응
# 198                                                 릴리         퀄리티와 개인 파트
# 199                설련 너무 사랑해 너의 제일 팬이야 널 위해 세상을 불태울 거야       걸그룹과 퍼포먼스 성공
# 201  럽미라잌이후로 컨셉이 고정된 느낌. 도입은 너무 좋은데... 힙합이 하고 싶으면 차...          안무와 외모 평가
# 202  이번 노래 너무 좋은데 타팬인데 계속 머리속에서 흐으음~하여튼간 별별별 이게 계속 ...         무대 연출과 스타일
# 203      결국 살아남는건 엔믹스처럼 라이브가능한 아이돌뿐일거다. 하이브애들아 보고있지? ㅋ          성과와 활동 평가
# 205                                     응 음방 3관왕 함~ ㅅㄱ           멤버와 팬 감정
# 206                                            뻔뻔한 일본인      타이틀곡과 댄스 퍼포먼스
# 207                                   서태지 컴백홈 하여가 비트같음      타이틀곡과 댄스 퍼포먼스
# 209  음악이 예상대로 흘러가지 않을 때 느껴지는 전율.... 이 맛에 엔믹스 듣지 데이식...       음원 성적과 대중 반응
# 210                   슈퍼노바느낌을 내고싶었던것같은데 훅이 너무 약함.. 아쉽다         무대 연출과 스타일
# 211                                  느낌이 전혀 다르고만 슈퍼노바랑          진심과 감정 표현
# 212                                  다른데 이도저도안된것같아 아쉬움         무대 연출과 스타일
# 214  JYP 아티스트는 전부 좋아하지만 엔믹스는 K-POP때 보았던 릴리M의 펜이기에 엔...          안무와 외모 평가
# 215  릴리 M건강하게 JYP를 빛내주는 엔믹스 오해원설윤아릴리 M김지우장규진배진솔.JYP...         퀄리티와 개인 파트
# 216  와 이거 노래 진짜 좋은데? 아이돌 감성 이해 잘 못 해서 따로 안 찾아보는데 이 ...          안무와 외모 평가
# 217  엔믹스 노래를 O.O 부터 눈여겨봤는데 점점 자기만의 색채를 찾아서 좋은듯 ㅇㅇ 노...          진심과 감정 표현
# 218                            엔믹스 노래였구나 굉장히 힙하다 생각했는데       실력과 라이브 퍼포먼스
# 219                                         노래가 너무 좋아요          진심과 감정 표현
# 220  ​@@水無月-c8s 지진 얘기를 꺼낸 건 선 넘은 거 맞아. 그런말을 한건 잘못이 ...         무대 연출과 스타일
# 221        @@user-hr8pj4se3s먼저 공격? 그렇다면 그 노래는 친일 노래입니다         무대 연출과 스타일
# 222                                  그냥 노래가 너무 좋아서 댓글담          진심과 감정 표현
# 223  엔믹스가 뮤비 조회수 손해 보는 이유가 라이브 무대가 음원보다 훨씬 좋으니 그걸 많...         세계관과 충격 요소
# 224                      컨텐츠들이 넘 쏟아지는 느낌? 볼게 많다고 할까요?ㅋ         무대 연출과 스타일
# 225               맞어ㅋㅋㅋㅋㅋ 실력이 너무 좋아서 라이브 하는 거 보면 쾌감 느낌           멤버와 팬 감정

# %%
import gensim
from gensim import corpora

# 문서 토큰화 (예시)
documents = sample_df['word_list'].apply(lambda x: x.split())  # 'word_list'는 단어들이 공백으로 구분된 문자열로 가정

# 단어 사전(dictionary) 생성
dictionary = corpora.Dictionary(documents)

# 문서를 Bag of Words 형태로 변환 (단어: 빈도수)
corpus = [dictionary.doc2bow(doc) for doc in documents]

# LDA 모델 학습
NUM_TOPICS = 20  # 20개의 토픽 설정
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, passes=15)

# 각 토픽의 상위 단어 출력
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.184*"중독" + 0.125*"비주얼" + 0.114*"가사" + 0.044*"무대"')
# (1, '0.362*"엔믹스" + 0.094*"실력" + 0.044*"대중성" + 0.036*"세대"')
# (2, '0.078*"이해" + 0.051*"능력" + 0.043*"일본" + 0.038*"문제"')
# (3, '0.151*"컴백" + 0.086*"엔믹스" + 0.044*"파이팅" + 0.042*"테마"')
# (4, '0.153*"릴리" + 0.132*"걸그룹" + 0.086*"보컬" + 0.035*"오해원"')
# (5, '0.061*"정신" + 0.044*"소녀" + 0.035*"대체" + 0.033*"뉴진스"')
# (6, '0.076*"대중" + 0.055*"에스파" + 0.021*"세계관" + 0.019*"영어"')
# (7, '0.577*"노래" + 0.088*"뮤비" + 0.073*"엔믹스" + 0.022*"멤버"')
# (8, '0.136*"안무" + 0.055*"충격" + 0.042*"스타" + 0.032*"비쥬"')
# (9, '0.197*"컨셉" + 0.082*"음악" + 0.058*"진심" + 0.053*"역대"')
# (10, '0.087*"장난" + 0.076*"얼마나" + 0.058*"도대체" + 0.049*"거지"')
# (11, '0.089*"제대로" + 0.057*"약간" + 0.052*"도입" + 0.029*"하루"')
# (12, '0.108*"멤버" + 0.086*"설윤" + 0.058*"신곡" + 0.055*"매력"')
# (13, '0.140*"제왑" + 0.134*"별로" + 0.047*"한국인" + 0.028*"올해"')
# (14, '0.148*"노래" + 0.084*"분위기" + 0.079*"장르" + 0.046*"아이돌"')
# (15, '0.304*"데뷔" + 0.078*"트와이스" + 0.047*"기대" + 0.036*"걸그룹"')
# (16, '0.158*"화이팅" + 0.117*"엔믹스" + 0.040*"댄스" + 0.028*"머리"')
# (17, '0.282*"응원" + 0.066*"활동" + 0.030*"언제" + 0.023*"가창력"')
# (18, '0.085*"규진" + 0.083*"지우" + 0.074*"파트" + 0.063*"해원"')
# (19, '0.324*"사랑해" + 0.139*"엔믹스" + 0.074*"지니" + 0.032*"자꾸"')
