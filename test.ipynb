# %%
import pandas as pd

# %%
m_th = pd.read_csv('/Users/jaesolshin/Downloads/member_thumbnail.csv')
temp = m_th['thumbnail'].apply(len)
max(temp)

# %%
comments = pd.read_csv('/Users/jaesolshin/Library/CloudStorage/GoogleDrive-ysys143@gmail.com/내 드라이브/2024-NIPA-google-trendpop/가사 데이터/final_output/KPOP_comments_keyword_and_labels.csv')
temp = comments['comment'].apply(len)
max(temp)
# Out:
# 4343

# %%
comments = pd.read_csv('/Users/jaesolshin/Library/CloudStorage/GoogleDrive-ysys143@gmail.com/내 드라이브/2024-NIPA-google-trendpop/가사 데이터/final_output/KPOP_comments_keyword_and_labels.csv')
temp = comments['members'].str.len().dropna()
max(temp)
# Out:
# 159.0
