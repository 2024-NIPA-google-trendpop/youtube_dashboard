# %% [markdown]
# 환경설정

# %%
import os
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
import time
import tqdm
import jpype
import ast

# %%
# 전처리, 명사추출, 키워드추출, 불용어후처리까지 마친 데이터
folder_path = '/Users/jaesolshin/Documents/GitHub/youtube_dashboard'
file_path = os.path.join(folder_path, 'keyword_list_after_cleaning.csv')
comments_df = pd.read_csv(file_path)

# csv 파일로 저장되면서 문자열로 변형된 word_list 컬럼을 다시 리스트로 변환
sample_df = comments_df.copy()
sample_df['word_list'] = sample_df['word_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %% [markdown]
# # 키워드 추출

# %%
import time
from collections import defaultdict

def extract_keywords_frequency(series_word_list, top_n=30, min_df=1, existing_keywords=None):
    # 시작시간 확인
    start_time = time.time()

    # 기존 키워드가 없으면 빈 리스트로 초기화
    if existing_keywords is None:
        existing_keywords = []

    # 단어별 문서 빈도를 저장할 딕셔너리 (각 단어가 등장한 문서 수)
    doc_frequency = defaultdict(int)

    # 각 문서에서 등장한 단어 추출 및 빈도 계산
    for word_list in series_word_list:
        unique_words_in_doc = list(set(word_list))  # 문서 내에서 중복된 단어는 한 번만 카운트
        for word in unique_words_in_doc:
            doc_frequency[word] += 1

    # min_df 조건을 충족하는 단어들의 빈도를 저장할 딕셔너리
    word_frequencies = defaultdict(int)

    # 각 문서의 단어 빈도 카운트 (min_df 조건에 맞는 단어만 빈도 계산)
    for word_list in series_word_list:
        for word in word_list:
            if doc_frequency[word] >= min_df:
                word_frequencies[word] += 1

    # 상위 빈도 단어 추출
    sorted_words = sorted(word_frequencies.items(), key=lambda item: item[1], reverse=True)

    # 기존 키워드 제외하고 새로운 키워드만 추출
    new_keywords_with_weights = [(word, count) for word, count in sorted_words if word not in existing_keywords]
    
    # 상위 n개 키워드만 추출 (중복 제외 후)
    top_keywords_with_weights = new_keywords_with_weights[:top_n]

    # 키워드만 추출
    top_keywords = [word for word, _ in top_keywords_with_weights]

    # 가중치를 전체 합으로 표준화
    total_count = sum(count for _, count in top_keywords_with_weights)
    if total_count > 0:
        keywords_with_weights = [(word, count / total_count) for word, count in top_keywords_with_weights]
    else:
        keywords_with_weights = [(word, 0) for word, count in top_keywords_with_weights]

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %%
# TF-IDF 기반 키워드 및 상대적 비중 추출 함수
def extract_keywords_tfidf(series_word_list, top_n=100, min_df=1):

    # 시작시간 확인
    start_time = time.time()

    # 리스트 시리즈를 문자열 시리즈로 변형
    word_list_str = series_word_list.apply(lambda words: ' '.join(words))

    # TF-IDF 벡터화 (min_df를 설정해 빈도수가 적은 단어 제거)
    vectorizer = TfidfVectorizer(max_features=1000, min_df=min_df)
    tfidf_matrix = vectorizer.fit_transform(word_list_str)

    # 각 단어의 TF-IDF 점수를 추출
    feature_names = vectorizer.get_feature_names_out()
    tfidf_scores = np.mean(tfidf_matrix.toarray(), axis=0)  # 전체 문서에서 평균 TF-IDF 추출

    # TF-IDF 점수를 기준으로 상위 키워드 추출
    top_n_indices = tfidf_scores.argsort()[-top_n:][::-1]
    top_keywords = [feature_names[idx] for idx in top_n_indices]

    # 각 단어의 TF-IDF 점수 추출
    weights = [tfidf_scores[idx] for idx in top_n_indices]

    # 가중치를 전체 합으로 표준화
    weights = weights / np.sum(weights)

    # 키워드와 가중치를 묶어서 반환
    keywords_with_weights = list(zip(top_keywords, weights))

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %%
from rank_bm25 import BM25Okapi
import time
import numpy as np
import pandas as pd
from collections import defaultdict

# BM25 기반 키워드 및 상대적 비중 추출 함수 (min_df 추가)
def extract_keywords_bm25(series_word_list, top_n=100, min_df=1):
    # 시작시간 확인
    start_time = time.time()

    # 시리즈의 각 리스트를 문서로 간주하여 BM25 모델 생성
    tokenized_corpus = series_word_list.tolist()
    bm25 = BM25Okapi(tokenized_corpus)

    # 각 단어의 출현 빈도를 저장할 딕셔너리
    doc_frequency = defaultdict(int)

    # 문서 내 각 단어의 출현 빈도 계산
    for doc in tokenized_corpus:
        unique_words_in_doc = set(doc)
        for word in unique_words_in_doc:
            doc_frequency[word] += 1

    # 각 단어의 BM25 점수를 저장할 딕셔너리
    word_scores = defaultdict(float)
    total_docs = len(tokenized_corpus)

    # 각 문서에서의 BM25 점수를 계산하여 해당 단어에 대한 점수를 합산
    for doc in tokenized_corpus:
        scores = bm25.get_scores(doc)
        for word, score in zip(doc, scores):
            # 단어의 출현 빈도가 min_df 이상인 경우에만 점수 계산
            if doc_frequency[word] >= min_df:
                word_scores[word] += score

    # 문서 전체에 대한 평균 BM25 점수로 변환
    word_scores = {word: score / total_docs for word, score in word_scores.items()}

    # 상위 BM25 점수를 기준으로 키워드 추출
    sorted_words = sorted(word_scores.items(), key=lambda item: item[1], reverse=True)
    top_keywords = sorted_words[:top_n]

    # 가중치를 전체 합으로 표준화
    total_weight = sum(score for _, score in top_keywords)
    keywords_with_weights = [(word, score / total_weight) for word, score in top_keywords]

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %% [markdown]
# # 각 레벨 별로 키워드 추출

# %%
## keyword_list 초기화 및 설정
keyword_list = pd.DataFrame(columns=['Group', 'Title', 'keyword'])

## 모든 댓글에 대한 키워드 추가
#sample_df['word_list'] = sample_df['word_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# 단순 빈도 기반 키워드 추출
keywords, weights = extract_keywords_frequency(sample_df['word_list'], top_n=30, min_df=5)
keyword_list['keyword'] = keywords
keyword_list['weights'] = weights
keyword_list['Group'] = 'All'
keyword_list['Title'] = 'All'
## 각 그룹에 대한 추가키워드 발견
# Group 열에 속한 그룹들의 리스트
groups = sample_df['Group'].unique()

# 기존 keyword_list에서 추출된 키워드와 중복되지 않도록 새로운 키워드 추출
# existing_keywords = keyword_list['keyword'].tolist()

# 그룹별로 새로운 키워드 추출
for group in groups:
    word_list = sample_df[sample_df['Group'] == group]['word_list']
    keywords, weights = extract_keywords_frequency(word_list, top_n=30, min_df=5)
    
    # 새로운 키워드를 기존 리스트에 추가
    frac = pd.DataFrame()
    frac['keyword'] = keywords
    frac['weights'] = weights
    frac['Group'] = group
    frac['Title'] = 'All'
    
    keyword_list = pd.concat([keyword_list, frac])
    keyword_list.drop_duplicates(subset='keyword', keep='first')

## 각 뮤비에 대한 키워드 추출
# Title 열에 속한 그룹들의 리스트
titles = sample_df['Title'].unique()

# MV별로 새로운 키워드 추출
for title in titles:
    group = sample_df[sample_df['Title'] == title]['Group'].iloc[0] # 해당 타이틀에 속한 그룹 조회
    word_list = sample_df[sample_df['Title'] == title]['word_list'] # 댓글 시리즈 가져오기
    keywords, weights = extract_keywords_frequency(word_list, top_n=30, min_df=3)
    
    # 새로운 키워드를 기존 리스트에 추가
    frac = pd.DataFrame()
    frac['keyword'] = keywords
    frac['weights'] = weights
    frac['Group'] = group
    frac['Title'] = title
    
    keyword_list = pd.concat([keyword_list, frac])
    keyword_list.drop_duplicates(subset='keyword', keep='first')

# 인덱스 초기화
keyword_list = keyword_list.reset_index(drop=True)
# Out:
# 648060개 댓글 키워드 추출에 걸린 시간: 0.9479749202728271 초
#
# 23511개 댓글 키워드 추출에 걸린 시간: 0.02622079849243164 초
#
# 50699개 댓글 키워드 추출에 걸린 시간: 0.056355953216552734 초
#
# 249967개 댓글 키워드 추출에 걸린 시간: 0.4786069393157959 초
#
# 45376개 댓글 키워드 추출에 걸린 시간: 0.05791211128234863 초
#
# 7425개 댓글 키워드 추출에 걸린 시간: 0.0075719356536865234 초
#
# 136993개 댓글 키워드 추출에 걸린 시간: 0.13891816139221191 초
#
# 33181개 댓글 키워드 추출에 걸린 시간: 0.03650403022766113 초
#
# 7846개 댓글 키워드 추출에 걸린 시간: 0.00917196273803711 초
#
# 69125개 댓글 키워드 추출에 걸린 시간: 0.07907819747924805 초
#
# 23937개 댓글 키워드 추출에 걸린 시간: 0.023941993713378906 초
#
# 4339개 댓글 키워드 추출에 걸린 시간: 0.005378007888793945 초
#
# 2622개 댓글 키워드 추출에 걸린 시간: 0.0028009414672851562 초
#
# 551개 댓글 키워드 추출에 걸린 시간: 0.0005419254302978516 초
#
# 1442개 댓글 키워드 추출에 걸린 시간: 0.0016677379608154297 초
#
# 1406개 댓글 키워드 추출에 걸린 시간: 0.0013339519500732422 초
#
# 1416개 댓글 키워드 추출에 걸린 시간: 0.0014011859893798828 초
#
# 1916개 댓글 키워드 추출에 걸린 시간: 0.0019330978393554688 초
#
# 1608개 댓글 키워드 추출에 걸린 시간: 0.0015621185302734375 초
#
# 570개 댓글 키워드 추출에 걸린 시간: 0.0005812644958496094 초
#
# 3550개 댓글 키워드 추출에 걸린 시간: 0.004380941390991211 초
#
# 1895개 댓글 키워드 추출에 걸린 시간: 0.001977205276489258 초
#
# 3602개 댓글 키워드 추출에 걸린 시간: 0.0036361217498779297 초
#
# 1068개 댓글 키워드 추출에 걸린 시간: 0.0012001991271972656 초
#
# 1984개 댓글 키워드 추출에 걸린 시간: 0.002452850341796875 초
#
# 1451개 댓글 키워드 추출에 걸린 시간: 0.0017418861389160156 초
#
# 2487개 댓글 키워드 추출에 걸린 시간: 0.002789020538330078 초
#
# 677개 댓글 키워드 추출에 걸린 시간: 0.0008299350738525391 초
#
# 3766개 댓글 키워드 추출에 걸린 시간: 0.005368947982788086 초
#
# 6162개 댓글 키워드 추출에 걸린 시간: 0.007956981658935547 초
#
# 1499개 댓글 키워드 추출에 걸린 시간: 0.0017442703247070312 초
#
# 12484개 댓글 키워드 추출에 걸린 시간: 0.016397714614868164 초
#
# 1616개 댓글 키워드 추출에 걸린 시간: 0.0019450187683105469 초
#
# 885개 댓글 키워드 추출에 걸린 시간: 0.0007607936859130859 초
#
# 17909개 댓글 키워드 추출에 걸린 시간: 0.021586179733276367 초
#
# 1521개 댓글 키워드 추출에 걸린 시간: 0.0014879703521728516 초
#
# 655개 댓글 키워드 추출에 걸린 시간: 0.0005848407745361328 초
#
# 11868개 댓글 키워드 추출에 걸린 시간: 0.0178072452545166 초
#
# 174개 댓글 키워드 추출에 걸린 시간: 0.00017905235290527344 초
#
# 3328개 댓글 키워드 추출에 걸린 시간: 0.003000974655151367 초
#
# 281개 댓글 키워드 추출에 걸린 시간: 0.0002810955047607422 초
#
# 28개 댓글 키워드 추출에 걸린 시간: 4.792213439941406e-05 초
#
# 102개 댓글 키워드 추출에 걸린 시간: 0.00013709068298339844 초
#
# 451개 댓글 키워드 추출에 걸린 시간: 0.0004429817199707031 초
#
# 638개 댓글 키워드 추출에 걸린 시간: 0.0005331039428710938 초
#
# 3244개 댓글 키워드 추출에 걸린 시간: 0.002949953079223633 초
#
# 2823개 댓글 키워드 추출에 걸린 시간: 0.0026159286499023438 초
#
# 802개 댓글 키워드 추출에 걸린 시간: 0.0007259845733642578 초
#
# 749개 댓글 키워드 추출에 걸린 시간: 0.0006639957427978516 초
#
# 900개 댓글 키워드 추출에 걸린 시간: 0.0008630752563476562 초
#
# 1185개 댓글 키워드 추출에 걸린 시간: 0.0011372566223144531 초
#
# 1278개 댓글 키워드 추출에 걸린 시간: 0.0013229846954345703 초
#
# 5531개 댓글 키워드 추출에 걸린 시간: 0.004974842071533203 초
#
# 2212개 댓글 키워드 추출에 걸린 시간: 0.002148866653442383 초
#
# 777개 댓글 키워드 추출에 걸린 시간: 0.0007052421569824219 초
#
# 1200개 댓글 키워드 추출에 걸린 시간: 0.0012149810791015625 초
#
# 3832개 댓글 키워드 추출에 걸린 시간: 0.005294084548950195 초
#
# 11114개 댓글 키워드 추출에 걸린 시간: 0.010133028030395508 초
#
# 5739개 댓글 키워드 추출에 걸린 시간: 0.0050661563873291016 초
#
# 7269개 댓글 키워드 추출에 걸린 시간: 0.006738185882568359 초
#
# 24683개 댓글 키워드 추출에 걸린 시간: 0.022640228271484375 초
#
# 10514개 댓글 키워드 추출에 걸린 시간: 0.008164167404174805 초
#
# 8939개 댓글 키워드 추출에 걸린 시간: 0.007624149322509766 초
#
# 23094개 댓글 키워드 추출에 걸린 시간: 0.018741130828857422 초
#
# 7809개 댓글 키워드 추출에 걸린 시간: 0.008410930633544922 초
#
# 1494개 댓글 키워드 추출에 걸린 시간: 0.0017328262329101562 초
#
# 3775개 댓글 키워드 추출에 걸린 시간: 0.0047550201416015625 초
#
# 2572개 댓글 키워드 추출에 걸린 시간: 0.0025300979614257812 초
#
# 2973개 댓글 키워드 추출에 걸린 시간: 0.004997968673706055 초
#
# 4106개 댓글 키워드 추출에 걸린 시간: 0.00521087646484375 초
#
# 4625개 댓글 키워드 추출에 걸린 시간: 0.004591941833496094 초
#
# 4402개 댓글 키워드 추출에 걸린 시간: 0.005470991134643555 초
#
# 1359개 댓글 키워드 추출에 걸린 시간: 0.0014157295227050781 초
#
# 989개 댓글 키워드 추출에 걸린 시간: 0.001180887222290039 초
#
# 5572개 댓글 키워드 추출에 걸린 시간: 0.005173683166503906 초
#
# 4446개 댓글 키워드 추출에 걸린 시간: 0.007328987121582031 초
#
# 15153개 댓글 키워드 추출에 걸린 시간: 0.021815061569213867 초
#
# 9556개 댓글 키워드 추출에 걸린 시간: 0.013401985168457031 초
#
# 33707개 댓글 키워드 추출에 걸린 시간: 0.048413991928100586 초
#
# 45641개 댓글 키워드 추출에 걸린 시간: 0.06648921966552734 초
#
# 3508개 댓글 키워드 추출에 걸린 시간: 0.005048036575317383 초
#
# 6748개 댓글 키워드 추출에 걸린 시간: 0.010304689407348633 초
#
# 9605개 댓글 키워드 추출에 걸린 시간: 0.010060787200927734 초
#
# 3835개 댓글 키워드 추출에 걸린 시간: 0.0041620731353759766 초
#
# 10466개 댓글 키워드 추출에 걸린 시간: 0.010427236557006836 초
#
# 5489개 댓글 키워드 추출에 걸린 시간: 0.0049381256103515625 초
#
# 1114개 댓글 키워드 추출에 걸린 시간: 0.0010089874267578125 초
#
# 4381개 댓글 키워드 추출에 걸린 시간: 0.004504680633544922 초
#
# 1576개 댓글 키워드 추출에 걸린 시간: 0.001374959945678711 초
#
# 7685개 댓글 키워드 추출에 걸린 시간: 0.008708000183105469 초
#
# 11309개 댓글 키워드 추출에 걸린 시간: 0.011999130249023438 초
#
# 3678개 댓글 키워드 추출에 걸린 시간: 0.0038900375366210938 초
#
# 910개 댓글 키워드 추출에 걸린 시간: 0.0009410381317138672 초
#
# 9077개 댓글 키워드 추출에 걸린 시간: 0.008428096771240234 초
#
# 2949개 댓글 키워드 추출에 걸린 시간: 0.004358053207397461 초
#
# 1917개 댓글 키워드 추출에 걸린 시간: 0.002724885940551758 초
#
# 7332개 댓글 키워드 추출에 걸린 시간: 0.009048700332641602 초
#
# 3901개 댓글 키워드 추출에 걸린 시간: 0.004191875457763672 초
#
# 81707개 댓글 키워드 추출에 걸린 시간: 0.21403121948242188 초
#
# 3707개 댓글 키워드 추출에 걸린 시간: 0.006220102310180664 초
#
# 6528개 댓글 키워드 추출에 걸린 시간: 0.00962376594543457 초
#
# 8220개 댓글 키워드 추출에 걸린 시간: 0.006579875946044922 초
#
# 10022개 댓글 키워드 추출에 걸린 시간: 0.009350061416625977 초
#
# 5879개 댓글 키워드 추출에 걸린 시간: 0.004308938980102539 초
#
# 10473개 댓글 키워드 추출에 걸린 시간: 0.008691072463989258 초
#
# 5813개 댓글 키워드 추출에 걸린 시간: 0.004439115524291992 초
#
# 27447개 댓글 키워드 추출에 걸린 시간: 0.04161500930786133 초
#
# 1909개 댓글 키워드 추출에 걸린 시간: 0.0016818046569824219 초
#
# 1425개 댓글 키워드 추출에 걸린 시간: 0.0014448165893554688 초
#
# 29435개 댓글 키워드 추출에 걸린 시간: 0.030949115753173828 초

# %%
# 출력 옵션 설정: 모든 열을 출력
pd.set_option('display.max_columns', None)  # 모든 열 출력
pd.set_option('display.max_rows', None)     # 모든 행 출력

#keyword_list

# %%
# 전체 키워드에서 드랍할 키워드 목록
keywords_to_drop = ['뉴진스', '아이브', '하이브', '민희진', '단월드', '에스파', '사이비', '르세라핌', '방시혁', '리즈', '혜인', '하니', '다니엘', '아일릿', 
                    '여자친구', '민지', '레이', '엔믹스', '유진', '원영', '가을', '피프티', '박지원', '스테이씨', '버니즈', '어도어', '이브', '카리나', 
                    '마고', '이서', '윈터', '정신병원', '해린', '류진', '마그네틱', '장원영', '다이브', '단군신화', '침착맨', '디토', '방탄소년단', '오엠지', 
                    '안유진', '지젤', '닝닝', '혜진', '예지', '리아', '수가']


# 'Group'이 'All'이고 'Keyword'가 keywords_to_drop에 포함된 행 드랍
keyword_list = keyword_list[~((keyword_list['Group'] == 'All') & (keyword_list['keyword'].isin(keywords_to_drop)))]
keyword_list.to_csv('keyword_list.csv')

# %%
# 'Group'과 'Title'로 그룹화한 후, Keyword를 와이드 포맷으로 변환
keyword_list['Keyword_Index'] = keyword_list.groupby(['Group', 'Title']).cumcount() + 1

# 'Keyword_Index'를 열로 피봇하여 와이드 포맷으로 변환
df_wide_format = keyword_list.pivot(index=['Group', 'Title'], columns='Keyword_Index', values='keyword')

# 결과 출력
df_wide_format.to_csv('keyword_list_wide_format.csv')
df_wide_format
# Out:
# Keyword_Index                                                1     2      3   \
# Group       Title
# All         All                                              노래    뮤비     사랑
# FIFTY FIFTY All                                              노래   피프티     대표
#             Cupid                                            노래    대표    피프티
#             Higher                                           노래    음색    피프티
#             Lovin' Me                                        노래   피프티     뮤비
#             SOS                                              노래   피프티     응원
#             Starry Night                                     노래   피프티     응원
# ITZY        All                                              노래    사랑     류진
#             BET ON ME                                        노래    사랑     류진
#             BORN TO BE                                       노래    사랑     리아
#             Boys Like You                                    노래    사랑     리아
#             CAKE                                             노래    사랑    케이크
#             Cheshire                                         노래    사랑     체셔
#             ICY                                              노래   한국인     사랑
#             LOCO                                             노래    사랑     예지
#             Mr. Vampire                                      노래    리아     사랑
#             None of My Business                              노래    사랑     류진
#             Not Shy                                          노래    사랑     류진
#             SNEAKERS                                         노래    사랑   스니커즈
#             SWIPE                                            노래   타이틀     뮤비
#             UNTOUCHABLE                                      노래    사랑     컴백
#             Voltage                                          노래    사랑     일본
#             WANNABE                                          노래    류진     사랑
#             달라달라(DALLA DALLA)                          노래    채령    한국인
#             마.피.아. In the morning                         노래   마피아     가사
# IVE         Accendio                                       아센디오   아이브     뮤비
#             After LIKE                                      아이브    노래     사랑
#             All                                             아이브    노래     사랑
#             All Night (Feat. Saweetie)                      아이브    노래     사랑
#             Baddie                                          아이브    노래     사랑
#             ELEVEN                                          아이브    노래     사랑
#             Either Way                                      아이브    노래     사랑
#             I AM                                            아이브    노래     사랑
#             Kitsch                                           리즈    노래    아이브
#             LOVE DIVE                                       아이브    노래    다이브
#             Off The Record                                  아이브    노래     사랑
#             해야 (HEYA)                                      중국    한국    아이브
# Kep1er      All                                              노래   케플러     사랑
#             Giddy                                            노래   케플러     사랑
#             Grand Prix                                      케플러    사랑     노래
#             I do! Do you                                     노래   케플러     한국
#             Straight Line                                   케플러    노래     사랑
#             Sugar Rush                                      케플러    노래    NaN
#             Up!                                              노래   케플러     사랑
#             WA DA DA                                         노래   케플러     사랑
#             We Fresh                                        케플러    노래     사랑
#             Wing Wing                                        노래   케플러     일본
# LE SSERAFIM ANTIFRAGILE                                      노래  르세라핌     중독
#             All                                              노래  르세라핌     뮤비
#             CRAZY                                            노래  르세라핌    뉴진스
#             EASY                                             노래  르세라핌     뮤비
#             FEARLESS                                         가람    노래     채원
#             Impurities                                       노래  르세라핌     뮤비
#             Perfect Night                                    노래  르세라핌     워치
#             Smart                                            노래  르세라핌     뮤비
#             UNFORGIVEN (feat. Nile Rodgers)                르세라핌    노래     뮤비
#             이브, 프시케 그리고 푸른 수염의 아내           노래  르세라핌     뮤비
# NMIXX       All                                              노래   엔믹스     사랑
#             DASH                                             노래   엔믹스     뮤비
#             DICE                                             노래   엔믹스     컨셉
#             Funky Glitter Christmas                          노래   엔믹스  크리스마스
#             Love Me Like This                                노래   엔믹스     사랑
#             O.O                                              노래   엔믹스     데뷔
#             Party O’Clock                                    노래   엔믹스     사랑
#             Roller Coaster                                   노래   엔믹스     사랑
#             Soñar (Breaker)                                 노래   엔믹스   권모술수
#             Young, Dumb, Stupid                              노래   엔믹스     지우
#             별별별 (See that)                            엔믹스    노래     뮤비
#             蜚蜚 (FEIFEI)                                     엔믹스    노래     시간
# NewJeans    'Cool With You' & 'Get Up' (side B)             양조위   뉴진스     뮤비
#             'Cool With You' (side A)                        뉴진스    뮤비     노래
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)    노래   뉴진스     해린
#             'Hype Boy' Official MV (HANNI ver.)              노래    하니    민희진
#             'Hype Boy' Official MV (HYEIN ver.)              혜인    뮤비     사랑
#             'Hype Boy' Official MV (MINJI ver.)              노래    민지    뉴진스
#             ASAP                                            뉴진스    뮤비    민희진
#             All                                             뉴진스   하이브    민희진
#             Attention                                        노래   뉴진스    민희진
#             Bubble Gum                                      뉴진스   민희진     노래
#             Cookie                                           쿠키    노래    뉴진스
#             Ditto (side A)                                  뉴진스    뮤비     노래
#             Ditto (side B)                                  뉴진스    뮤비    민희진
#             ETA                                             뉴진스    노래     뮤비
#             How Sweet                                       뉴진스   하이브     뮤비
#             Hurt                                             노래    뮤비    뉴진스
#             New Jeans                                       뉴진스    노래     뮤비
#             OMG                                             하이브   단월드    민희진
#             Right Now                                       뉴진스    노래     뮤비
#             Super Shy                                       뉴진스    노래     뮤비
#             Supernatural (Part.1)                           뉴진스    노래     일본
#             Supernatural (Part.2)                           뉴진스   한국어     버전
#             Zero                                           코카콜라    광고    뉴진스
# STAYC       All                                              노래  스테이씨     사랑
#             No quoted content found.                         노래  스테이씨     사랑
# aespa       All                                             에스파    노래     뮤비
#             Armageddon                                      에스파    뮤비     노래
#             Better Things                                    노래   에스파     사랑
#             Black Mamba                                     에스파    노래    카리나
#             Drama                                           에스파    노래    드라마
#             Forever                                          노래   에스파     사랑
#             Girls                                           에스파    노래    카리나
#             Live My Life                                    에스파    노래     뮤비
#             Next Level                                       노래   에스파     중독
#             Savage                                           노래   에스파     사랑
#             Spicy                                           에스파    노래    카리나
#             Supernova                                       에스파    노래     뮤비
#             Welcome To MY World (Feat. nævis)                노래   에스파     사랑
# tripleS     All                                              노래   트리플     뮤비
#             Generation                                       노래    뮤비    뉴진스
#             Rising                                           노래   트리플     에스
#
# Keyword_Index                                                 4    5     6   \
# Group       Title
# All         All                                               컨셉   멤버    응원
# FIFTY FIFTY All                                               응원   멤버    뮤비
#             Cupid                                             멤버  소속사   아이돌
#             Higher                                            아란   멤버    뮤비
#             Lovin' Me                                        큐피드   음악    멤버
#             SOS                                               대표   앨범    멤버
#             Starry Night                                      대표   멤버   전홍준
# ITZY        All                                               채령   뮤비   한국인
#             BET ON ME                                         가사   예지    유나
#             BORN TO BE                                      퍼포먼스   유나    컴백
#             Boys Like You                                    테일러   채령    영어
#             CAKE                                              뮤비   컴백    중독
#             Cheshire                                          컴백   예지    뮤비
#             ICY                                               뮤비   예지    달라
#             LOCO                                              류진   뮤비    채령
#             Mr. Vampire                                       류진   채령   타이틀
#             None of My Business                               여름   리아    뮤비
#             Not Shy                                          한국인   리아    채령
#             SNEAKERS                                          채령   리아    날자
#             SWIPE                                             사랑   중독    로꼬
#             UNTOUCHABLE                                       리아  화이팅    활동
#             Voltage                                           한국   류진   한국어
#             WANNABE                                          한국인   채령    예지
#             달라달라(DALLA DALLA)                           달라   데뷔  트와이스
#             마.피.아. In the morning                          사랑  박진영    리아
# IVE         Accendio                                          노래   사랑    컨셉
#             After LIKE                                        가을   레이    파트
#             All                                               리즈   뮤비    중국
#             All Night (Feat. Saweetie)                        신곡   리즈    원영
#             Baddie                                           고양이   원영    컨셉
#             ELEVEN                                            원영   데뷔    유진
#             Either Way                                        원영   유진    가사
#             I AM                                              리즈   유진    원영
#             Kitsch                                            파트   레이    사랑
#             LOVE DIVE                                         사랑   원영    리즈
#             Off The Record                                    뮤비  옾더레    리즈
#             해야 (HEYA)                                       문화   노래   중국인
# Kep1er      All                                               데뷔  화이팅    파트
#             Giddy                                             컴백  화이팅    채현
#             Grand Prix                                        한국  화이팅    영은
#             I do! Do you                                      일본   사랑    컴백
#             Straight Line                                     일본   한국    컴백
#             Sugar Rush                                       NaN  NaN   NaN
#             Up!                                               여름  짱플러    파트
#             WA DA DA                                          데뷔  화이팅    파트
#             We Fresh                                          뮤비  화이팅    컴백
#             Wing Wing                                         사랑   데뷔    한국
# LE SSERAFIM ANTIFRAGILE                                       채원   사랑    안티
#             All                                               사랑   채원   하이브
#             CRAZY                                            라이브   뮤비   조회수
#             EASY                                              사랑   교회   단월드
#             FEARLESS                                        르세라핌   데뷔   사쿠라
#             Impurities                                        사랑  사쿠라    안무
#             Perfect Night                                   오버워치  뉴진스    사랑
#             Smart                                            스마트   사랑   하이브
#             UNFORGIVEN (feat. Nile Rodgers)                   사랑  하이브    채원
#             이브, 프시케 그리고 푸른 수염의 아내            제목  허윤진    안무
# NMIXX       All                                               뮤비   컨셉    컴백
#             DASH                                              사랑   음색    릴리
#             DICE                                              실력  대중성    사랑
#             Funky Glitter Christmas                           사랑   릴리    지니
#             Love Me Like This                                 뮤비   중독    릴리
#             O.O                                               뮤비   사랑    가사
#             Party O’Clock                                     뮤비   여름    컴백
#             Roller Coaster                                    여름   설윤    뮤비
#             Soñar (Breaker)                                  사랑   뮤비    중독
#             Young, Dumb, Stupid                               사랑   컨셉    동요
#             별별별 (See that)                             별별별   사랑    컴백
#             蜚蜚 (FEIFEI)                                       홍콩  거슬러    음색
# NewJeans    'Cool With You' & 'Get Up' (side B)               정호   노래    사랑
#             'Cool With You' (side A)                          정호   사랑    영화
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)     뮤비  다니엘   민희진
#             'Hype Boy' Official MV (HANNI ver.)               뮤비  걸그룹   뉴진스
#             'Hype Boy' Official MV (HYEIN ver.)               노래   매력   뉴진스
#             'Hype Boy' Official MV (MINJI ver.)               뮤비  민희진    컨셉
#             ASAP                                              노래  하이브    토끼
#             All                                               노래   뮤비   단월드
#             Attention                                         뮤비  걸그룹    데뷔
#             Bubble Gum                                       하이브   응원    뮤비
#             Cookie                                            가사   뮤비   민희진
#             Ditto (side A)                                   민희진   감성    희수
#             Ditto (side B)                                    노래   희수    감성
#             ETA                                              민희진  하이브    광고
#             How Sweet                                         노래  민희진    제한
#             Hurt                                              얼빡  민희진    얼굴
#             New Jeans                                      파워퍼프걸   사랑    해린
#             OMG                                              뉴진스  사이비    뮤비
#             Right Now                                        버니즈   일본    데뷔
#             Super Shy                                         슈퍼  유튜브    사랑
#             Supernatural (Part.1)                            버니즈   뮤비    혜인
#             Supernatural (Part.2)                             뮤비   혜인    사랑
#             Zero                                              노래   제로    콜라
# STAYC       All                                               테이   뮤비    중독
#             No quoted content found.                          뮤비   테이   화이팅
# aespa       All                                              카리나   사랑    윈터
#             Armageddon                                      아마겟돈   컨셉    예술
#             Better Things                                    카리나   윈터    컨셉
#             Black Mamba                                       윈터   뮤비    데뷔
#             Drama                                             뮤비   사랑   카리나
#             Forever                                           윈터   지젤   카리나
#             Girls                                             사랑   윈터    지젤
#             Live My Life                                      사랑  카리나    표절
#             Next Level                                        윈터   뮤비   카리나
#             Savage                                            윈터   중독   카리나
#             Spicy                                             광야   컨셉    사랑
#             Supernova                                         컨셉   중독  수퍼노바
#             Welcome To MY World (Feat. nævis)                 컴백  나비스    뮤비
# tripleS     All                                               에스   멤버   화이팅
#             Generation                                        데뷔   중독   트리플
#             Rising                                            뮤비   데뷔   화이팅
#
# Keyword_Index                                                 7      8     9   \
# Group       Title
# All         All                                              화이팅     한국    가사
# FIFTY FIFTY All                                              아이돌    빌보드    앨범
#             Cupid                                             한국     배신    응원
#             Higher                                           목소리     보컬    음악
#             Lovin' Me                                        걸그룹     음색   아이돌
#             SOS                                               음악     뮤비   화이팅
#             Starry Night                                      뮤비    화이팅   빌보드
# ITZY        All                                               예지     리아    유나
#             BET ON ME                                         리아     컴백    채령
#             BORN TO BE                                        뮤비     류진    멤버
#             Boys Like You                                   스위프트     뮤비    예지
#             CAKE                                              날자     류진    예지
#             Cheshire                                          채령     활동    류진
#             ICY                                               유나     채령    류진
#             LOCO                                              유나     리아    로꼬
#             Mr. Vampire                                       예지     컴백   목소리
#             None of My Business                              타이틀     예지   목소리
#             Not Shy                                           뮤비     유나    실시
#             SNEAKERS                                          류진     뮤비    컨셉
#             SWIPE                                             류진    와이프    예지
#             UNTOUCHABLE                                       뮤비     류진    멤버
#             Voltage                                          일본어     리아    버전
#             WANNABE                                           가사     뮤비    한국
#             달라달라(DALLA DALLA)                           류진     뮤비    사랑
#             마.피.아. In the morning                          유나     중독    뮤비
# IVE         Accendio                                          유진     가을  마법소녀
#             After LIKE                                        리즈     유진    원영
#             All                                               한국     레이    원영
#             All Night (Feat. Saweetie)                        언니     컴백    가을
#             Baddie                                            이브     리즈    레이
#             ELEVEN                                            레이     리즈   화이팅
#             Either Way                                        금발     뮤비    리즈
#             I AM                                              뮤비     레이    파트
#             Kitsch                                            원영     가을    신곡
#             LOVE DIVE                                      러브다이브     가을   화이팅
#             Off The Record                                    가을     원영    유진
#             해야 (HEYA)                                       뮤비     나라    리즈
# Kep1er      All                                              히카루     뮤비    컴백
#             Giddy                                             뮤비     예서    중독
#             Grand Prix                                        일본    히카루    활동
#             I do! Do you                                      활동    한국어   화이팅
#             Straight Line                                    샤오팅     활동    해체
#             Sugar Rush                                       NaN    NaN   NaN
#             Up!                                              화이팅     컴백    뮤비
#             WA DA DA                                         히카루     중독    멤버
#             We Fresh                                          파트    히카루   샤오팅
#             Wing Wing                                        일본어     활동   화이팅
# LE SSERAFIM ANTIFRAGILE                                       뮤비     은채   사쿠라
#             All                                               중독    뉴진스   사쿠라
#             CRAZY                                             중독     토끼    천지
#             EASY                                             하이브    사이비    컨셉
#             FEARLESS                                          뮤비    하이브    멤버
#             Impurities                                        채원    수록곡   분위기
#             Perfect Night                                    콜라보     채원    뮤비
#             Smart                                             채원     표절   허윤진
#             UNFORGIVEN (feat. Nile Rodgers)                  카즈하     컴백   단월드
#             이브, 프시케 그리고 푸른 수염의 아내            채원     사랑    이브
# NMIXX       All                                               릴리     실력    멤버
#             DASH                                              보컬     컴백    음악
#             DICE                                              멤버     뮤비    중독
#             Funky Glitter Christmas                           캐롤     겨울    규진
#             Love Me Like This                                 컴백     실력   화이팅
#             O.O                                               컨셉     중독    음악
#             Party O’Clock                                    조회수  롤러코스터    파트
#             Roller Coaster                                    컨셉    타이틀    릴리
#             Soñar (Breaker)                                  릴리     컨셉   타이틀
#             Young, Dumb, Stupid                               릴리     뮤비   스타일
#             별별별 (See that)                              음악     앨범   대중성
#             蜚蜚 (FEIFEI)                                       커버    광동어    뮤비
# NewJeans    'Cool With You' & 'Get Up' (side B)              민희진     영화    해석
#             'Cool With You' (side A)                          남자     해석   민희진
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)    하이브     멤버  하입보이
#             'Hype Boy' Official MV (HANNI ver.)               멤버     여자    컨셉
#             'Hype Boy' Official MV (HYEIN ver.)               남자     멤버    버전
#             'Hype Boy' Official MV (MINJI ver.)              걸그룹    아이돌    멤버
#             ASAP                                             단월드     요정   사이비
#             All                                              사이비     삭제   방시혁
#             Attention                                         컨셉    하이브   아이돌
#             Bubble Gum                                        사랑    화이팅    감성
#             Cookie                                            데뷔     음악    논란
#             Ditto (side A)                                    디토     사랑   하이브
#             Ditto (side B)                                    추억    하이브   아이돌
#             ETA                                              아이폰    단월드    가사
#             How Sweet                                        조회수     사랑    연령
#             Hurt                                              혜인     하니    사랑
#             New Jeans                                        민희진    캐릭터    컴백
#             OMG                                               삭제    방시혁  여자친구
#             Right Now                                        조회수     하니    사랑
#             Super Shy                                         독자    다니엘    하니
#             Supernatural (Part.1)                             사랑    민희진    응원
#             Supernatural (Part.2)                            버니즈     노래    민지
#             Zero                                              펩시    문단속    뮤비
# STAYC       All                                              화이팅     컴백    수민
#             No quoted content found.                          중독     멤버   트리플
# aespa       All                                               컨셉     지젤    닝닝
#             Armageddon                                      슈퍼노바     스엠   퀄리티
#             Better Things                                     광야     뮤비    지젤
#             Black Mamba                                       사랑     닝닝    스엠
#             Drama                                             윈터     컨셉    지젤
#             Forever                                           닝닝     컨셉   목소리
#             Girls                                             닝닝     뮤비   앞머리
#             Live My Life                                     수록곡     앨범    광고
#             Next Level                                        사랑     닝닝    스엠
#             Savage                                            닝닝     지젤    광야
#             Spicy                                             윈터     닝닝    뮤비
#             Supernova                                         윈터    카리나    지젤
#             Welcome To MY World (Feat. nævis)                분위기     몽환   카리나
# tripleS     All                                               컨셉     사랑    데뷔
#             Generation                                        에스     유연    컨셉
#             Rising                                            컨셉     멤버    중독
#
# Keyword_Index                                                10    11    12  \
# Group       Title
# All         All                                              데뷔   아이돌    삭제
# FIFTY FIFTY All                                              음악   화이팅   큐피드
#             Cupid                                            활동   빌보드    가수
#             Higher                                           응원    데뷔   걸그룹
#             Lovin' Me                                        시오    아란    보컬
#             SOS                                             빌보드   조회수   큐피드
#             Starry Night                                     앨범   큐피드   조회수
# ITZY        All                                              달라    컨셉    중독
#             BET ON ME                                        뮤비    멤버    음악
#             BORN TO BE                                       컨셉    안무    예지
#             Boys Like You                                    컨셉    한국    류진
#             CAKE                                             활동   화이팅    유나
#             Cheshire                                         날자    유나   화이팅
#             ICY                                              한국    별로    중독
#             LOCO                                             중독    컨셉   마피아
#             Mr. Vampire                                      뮤비    유나    보컬
#             None of My Business                              컴백    채령    유나
#             Not Shy                                          예지    언니    컨셉
#             SNEAKERS                                         유나    예지    컴백
#             SWIPE                                            로코    틱톡    유나
#             UNTOUCHABLE                                      앨범    채령    유나
#             Voltage                                          예지    컨셉    앨범
#             WANNABE                                          유나    리아    언니
#             달라달라(DALLA DALLA)                          별로    예지    중독
#             마.피.아. In the morning                         컨셉    별로   한국인
# IVE         Accendio                                         멤버    이브    레이
#             After LIKE                                       이서    뮤비    이브
#             All                                              유진    파트    가을
#             All Night (Feat. Saweetie)                       뮤비    영어    응원
#             Baddie                                           중독    유진    뮤비
#             ELEVEN                                           이서    멤버    뮤비
#             Either Way                                      장원영    신곡    컴백
#             I AM                                             이브    가을    이서
#             Kitsch                                           키치    스타   장원영
#             LOVE DIVE                                        유진    이브    뮤비
#             Off The Record                                   이서    레이    이브
#             해야 (HEYA)                                      컨셉    전통    사랑
# Kep1er      All                                              중독    한국    멤버
#             Giddy                                            활동    멤버   짱플러
#             Grand Prix                                       뮤비    컨셉  그랑프리
#             I do! Do you                                     버전    컨셉    뮤비
#             Straight Line                                   서영은   일본어   비주얼
#             Sugar Rush                                      NaN   NaN   NaN
#             Up!                                              컨셉    상큼   히카루
#             WA DA DA                                         뮤비    유진    응원
#             We Fresh                                         컨셉   조회수    멤버
#             Wing Wing                                       히카루    윙윙   한국어
# LE SSERAFIM ANTIFRAGILE                                      가사    멤버   카즈하
#             All                                              가람    컨셉    멤버
#             CRAZY                                           하이브    악플  크레이지
#             EASY                                             채원    이지    컴백
#             FEARLESS                                         사랑    학폭    컨셉
#             Impurities                                      카즈하   뉴진스    앨범
#             Perfect Night                                    게임    컨셉   사쿠라
#             Smart                                           단월드    교복    가사
#             UNFORGIVEN (feat. Nile Rodgers)                 뉴진스   사쿠라    안무
#             이브, 프시케 그리고 푸른 수염의 아내           수염   사쿠라    푸른
# NMIXX       All                                              중독    음악    설윤
#             DASH                                             앨범    실력    멤버
#             DICE                                             컴백   걸그룹    대중
#             Funky Glitter Christmas                          뮤비    컨셉   분위기
#             Love Me Like This                              원더걸스    설윤    디스
#             O.O                                             에스파    멤버   걸그룹
#             Party O’Clock                                    컨셉    릴리   화이팅
#             Roller Coaster                                   청량    멤버    컴백
#             Soñar (Breaker)                                 컴백    멤버    음악
#             Young, Dumb, Stupid                             타이틀    컴백   수록곡
#             별별별 (See that)                             힙합    릴리    멤버
#             蜚蜚 (FEIFEI)                                      사랑   중국어    중국
# NewJeans    'Cool With You' & 'Get Up' (side B)              소름    배우    남자
#             'Cool With You' (side A)                        양조위   아이돌    한국
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)    사랑    컨셉   고양이
#             'Hype Boy' Official MV (HANNI ver.)              사랑   스토리   하이브
#             'Hype Boy' Official MV (HYEIN ver.)             스토리    막내    데뷔
#             'Hype Boy' Official MV (MINJI ver.)            하입보이    사랑    남자
#             ASAP                                             소름    컨셉    사랑
#             All                                              사랑    응원    혜인
#             Attention                                        멤버    감성    사랑
#             Bubble Gum                                       하니    대표   방시혁
#             Cookie                                           사랑    해석   하이브
#             Ditto (side A)                                  아이돌    학교    친구
#             Ditto (side B)                                   소름    해석    디토
#             ETA                                              하니    애플   사이비
#             How Sweet                                        응원    삭제   화이팅
#             Hurt                                             멤버   걸그룹    해린
#             New Jeans                                        컨셉   하이브   버니즈
#             OMG                                              가사    마녀    노래
#             Right Now                                       일본어   한국어    앨범
#             Super Shy                                       민희진    앨범   하이브
#             Supernatural (Part.1)                           하이브    음악   아이돌
#             Supernatural (Part.2)                            파트    한국   민희진
#             Zero                                             배탈    신곡    사랑
# STAYC       All                                              멤버    컨셉    파트
#             No quoted content found.                         컨셉    컴백    에스
# aespa       All                                              중독    광야    스엠
#             Armageddon                                       영화  수퍼노바    앨범
#             Better Things                                    닝닝    여름  인어공주
#             Black Mamba                                      블랙    지젤    핑크
#             Drama                                            컴백    광야    중독
#             Forever                                          보컬    뮤비   유영진
#             Girls                                            광야    가사    중국
#             Live My Life                                     최애    밴드    닝닝
#             Next Level                                      유영진    광야    컨셉
#             Savage                                           뮤비    음악   나비스
#             Spicy                                           스파이    지젤    컴백
#             Supernova                                      슈퍼노바    광야    쇠맛
#             Welcome To MY World (Feat. nævis)                윈터   타이틀    컨셉
# tripleS     All                                             뉴진스    응원    소녀
#             Generation                                       유닛   김유연    멤버
#             Rising                                           사랑    라이   뉴진스
#
# Keyword_Index                                                  13      14  \
# Group       Title
# All         All                                                중독      대표
# FIFTY FIFTY All                                               소속사     전홍준
#             Cupid                                              회사      수돌
#             Higher                                             대표     아이돌
#             Lovin' Me                                          대표     목소리
#             SOS                                               전홍준      영어
#             Starry Night                                      아이돌      천만
# ITZY        All                                                가사      한국
#             BET ON ME                                          응원     타이틀
#             BORN TO BE                                        에스파      크루
#             Boys Like You                                      미국      가사
#             CAKE                                               여름      응원
#             Cheshire                                           컨셉      리아
#             ICY                                                리아      언니
#             LOCO                                              화이팅      컴백
#             Mr. Vampire                                        멤버      응원
#             None of My Business                                앨범      홍보
#             Not Shy                                            한국     낫샤이
#             SNEAKERS                                           보컬     안무가
#             SWIPE                                              리아      안무
#             UNTOUCHABLE                                        날자     아이돌
#             Voltage                                            날자      컴백
#             WANNABE                                            달라      컨셉
#             달라달라(DALLA DALLA)                            컨셉      한국
#             마.피.아. In the morning                           류진      예지
# IVE         Accendio                                           원영      이서
#             After LIKE                                         중독     다이브
#             All                                                문화      이서
#             All Night (Feat. Saweetie)                        장원영     화이팅
#             Baddie                                            장원영      이서
#             ELEVEN                                             응원     장원영
#             Either Way                                         레이     앞머리
#             I AM                                              아이엠     장원영
#             Kitsch                                             컴백      유진
#             LOVE DIVE                                          레이      이서
#             Off The Record                                     음색     안유진
#             해야 (HEYA)                                        매듭      역사
# Kep1er      All                                               샤오팅      일본
#             Giddy                                             김일성     비주얼
#             Grand Prix                                       휴닝바히      버전
#             I do! Do you                                      히카루     일본어
#             Straight Line                                      영은     최유진
#             Sugar Rush                                        NaN     NaN
#             Up!                                                중독      영은
#             WA DA DA                                           언니     샤오팅
#             We Fresh                                          김채현      영은
#             Wing Wing                                         샤오팅      버전
# LE SSERAFIM ANTIFRAGILE                                        컨셉     세라핌
#             All                                                안무     카즈하
#             CRAZY                                              사랑      컨셉
#             EASY                                             신성모독      종교
#             FEARLESS                                          카즈하      중독
#             Impurities                                         일본     하이브
#             Perfect Night                                      스킨     키리코
#             Smart                                              컨셉     사쿠라
#             UNFORGIVEN (feat. Nile Rodgers)                   허윤진      가사
#             이브, 프시케 그리고 푸른 수염의 아내             아내      중독
# NMIXX       All                                                데뷔      지우
#             DASH                                               규진     아이돌
#             DICE                                               파트      제왑
#             Funky Glitter Christmas                            시즌      멤버
#             Love Me Like This                                  안무      지우
#             O.O                                                별로    트와이스
#             Party O’Clock                                    트와이스      지우
#             Roller Coaster                                    뉴진스      선공
#             Soñar (Breaker)                                   선공      실력
#             Young, Dumb, Stupid                                실력      파트
#             별별별 (See that)                               실력      컨셉
#             蜚蜚 (FEIFEI)                                        버전     한국어
# NewJeans    'Cool With You' & 'Get Up' (side B)               분위기     에로스
#             'Cool With You' (side A)                          에로스     걸그룹
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)      매력     아이돌
#             'Hype Boy' Official MV (HANNI ver.)               아이돌    하입보이
#             'Hype Boy' Official MV (HYEIN ver.)                친구    하입보이
#             'Hype Boy' Official MV (MINJI ver.)               하이브     케이팝
#             ASAP                                               금발      해석
#             All                                                가사      하니
#             Attention                                          텐션      음악
#             Bubble Gum                                        아이돌     단월드
#             Cookie                                             한국      식사
#             Ditto (side A)                                     소름      시절
#             Ditto (side B)                                     눈물      친구
#             ETA                                               방시혁     박지원
#             How Sweet                                         버니즈     방시혁
#             Hurt                                               음색      컨셉
#             New Jeans                                         콜라보      비트
#             OMG                                               박지원    르세라핌
#             Right Now                                          음원      한국
#             Super Shy                                          가사      혜인
#             Supernatural (Part.1)                             화이팅      데뷔
#             Supernatural (Part.2)                             어도어      일본
#             Zero                                              스즈메      중독
# STAYC       All                                                활동      데뷔
#             No quoted content found.                           수민      활동
# aespa       All                                                멤버      음악
#             Armageddon                                        카리나      작품
#             Better Things                                      영어      가사
#             Black Mamba                                       한국인      멤버
#             Drama                                              닝닝      음악
#             Forever                                            스엠      의상
#             Girls                                              컨셉    블랙맘바
#             Live My Life                                       스엠      청춘
#             Next Level                                     넥스트 레벨      지젤
#             Savage                                             컨셉  넥스트 레벨
#             Spicy                                              마이     화이팅
#             Supernova                                          사랑     뉴진스
#             Welcome To MY World (Feat. nævis)                  닝닝      광야
# tripleS     All                                                중독      유연
#             Generation                                         유빈      사랑
#             Rising                                             레이      응원
#
# Keyword_Index                                                15     16    17  \
# Group       Title
# All         All                                              음악     앨범    파트
# FIFTY FIFTY All                                              음색    조회수   목소리
#             Cupid                                            부모     소송    뮤비
#             Higher                                          큐피드     시오   뉴진스
#             Lovin' Me                                        이곡     데뷔    앨범
#             SOS                                              천만     중독   라이브
#             Starry Night                                    아테나     샤넬    음색
# ITZY        All                                              별로     언니    컴백
#             BET ON ME                                        보컬     날자   수록곡
#             BORN TO BE                                       무대     퍼포    기대
#             Boys Like You                                    팝송    한국어    컴백
#             CAKE                                             리아     앨범    케잌
#             Cheshire                                         중독     안무   고양이
#             ICY                                              신곡     파트  트와이스
#             LOCO                                             날자     멤버    별로
#             Mr. Vampire                                    뱀파이어     앨범    레아
#             None of My Business                             수록곡     보컬    컨셉
#             Not Shy                                          중독     파트   화이팅
#             SNEAKERS                                         나리    화이팅    멤버
#             SWIPE                                          타이틀곡     컨셉    앨범
#             UNTOUCHABLE                                      무대    조회수    컨셉
#             Voltage                                          응원    화이팅    활동
#             WANNABE                                         워너비     파트   한국어
#             달라달라(DALLA DALLA)                         걸그룹     언니    채연
#             마.피.아. In the morning                         채령     한국    멤버
# IVE         Accendio                                        에스파     마법    연기
#             After LIKE                                      화이팅     신곡    컴백
#             All                                              컨셉   아센디오   화이팅
#             All Night (Feat. Saweetie)                       레이   리메이크    유진
#             Baddie                                           컴백     가을    신곡
#             ELEVEN                                          일레븐     가을    중독
#             Either Way                                      안유진     멤버    가을
#             I AM                                            화이팅    안유진    컴백
#             Kitsch                                          수록곡    타이틀    분량
#             LOVE DIVE                                        참고     순간    중독
#             Off The Record                                  화이팅     파트   분위기
#             해야 (HEYA)                                      레이    한국인   호랑이
# Kep1er      All                                             짱플러     채현    응원
#             Giddy                                            플리     응원    영은
#             Grand Prix                                       응원    샤오팅   NaN
#             I do! Do you                                   트와이스     언니    인기
#             Straight Line                                    뮤비     가사    컨셉
#             Sugar Rush                                      NaN    NaN   NaN
# ...
#             Starry Night                                     보컬    가사      마음
# ITZY        All                                              날자   박진영      음악
#             BET ON ME                                        감동    홍보   뮤직비디오
#             BORN TO BE                                       소녀    미지      채령
#             Boys Like You                                    멤버    표정      연기
#             CAKE                                             안무    한국      홍보
#             Cheshire                                         역대   비주얼      표정
#             ICY                                              가사    얼굴      음악
#             LOCO                                            워너비   비주얼      안무
#             Mr. Vampire                                      고음    여자      마음
#             None of My Business                              헤메    중독     조회수
#             Not Shy                                          아들    마리      달라
#             SNEAKERS                                        걸그룹    한국      음악
#             SWIPE                                           마피아   화이팅      언니
#             UNTOUCHABLE                                      재능  퍼포먼스      아예
#             Voltage                                          하루    가사      멤버
#             WANNABE                                          신곡    멤버      매력
#             달라달라(DALLA DALLA)                          가사    제왑      블핑
#             마.피.아. In the morning                         구리    존나      음악
# IVE         Accendio                                         스타    장면      주문
#             After LIKE                                      아이돌   카메라     레전드
#             All                                              스타    응원      나라
#             All Night (Feat. Saweetie)                      콜라보   목소리      컨셉
#             Baddie                                           아기    하루      토끼
#             ELEVEN                                          다이브    음색      운지
#             Either Way                                       하트    번개      언니
#             I AM                                             활동    스타      응원
#             Kitsch                                           실화    별로      선공
#             LOVE DIVE                                        굿굿    안무      무대
#             Off The Record                                   중독    스타  오프더레코드
#             해야 (HEYA)                                      도둑    파트     유튜브
# Kep1er      All                                             파이팅   김다연     김채현
#             Giddy                                           파이팅    김일      언니
#             Grand Prix                                      NaN   NaN     NaN
#             I do! Do you                                     예서    보컬      파트
#             Straight Line                                    신곡    언니    휴닝바히
#             Sugar Rush                                      NaN   NaN     NaN
#             Up!                                              매력    머리      홀덤
#             WA DA DA                                         인기    예서      별로
#             We Fresh                                         음악    응원      신곡
#             Wing Wing                                        응원    앨범      기대
# LE SSERAFIM ANTIFRAGILE                                      별로    데뷔     아이돌
#             All                                             라이브   조회수      안티
#             CRAZY                                           빌보드    비트      별로
#             EASY                                             악마    은채     화이팅
#             FEARLESS                                        아이브    기대      음악
#             Impurities                                       파트    활동      음악
#             Perfect Night                                    은채   아이돌     하이브
#             Smart                                           빌보드   분위기      한국
#             UNFORGIVEN (feat. Nile Rodgers)                  용서    파트      소름
#             이브, 프시케 그리고 푸른 수염의 아내           소름    멤버      음악
# NMIXX       All                                             아이돌    활동      별로
#             DASH                                             중독    해원     본부장
#             DICE                                             비트    해원      듣기
#             Funky Glitter Christmas                         장규진    윤아      지우
#             Love Me Like This                                음방   아이돌     걸그룹
#             O.O                                              중간    안무      보컬
#             Party O’Clock                                    보컬    음원      듣기
#             Roller Coaster                                   제왑    규진      음색
#             Soñar (Breaker)                                 안무    웅장    타이틀곡
#             Young, Dumb, Stupid                             목소리    선공      설윤
#             별별별 (See that)                            아이돌    응원      장르
#             蜚蜚 (FEIFEI)                                      지우    감성     화이팅
# NewJeans    'Cool With You' & 'Get Up' (side B)              출연    형님     신우석
#             'Cool With You' (side A)                         천사    민지      컨셉
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)   비주얼    얼굴      안무
#             'Hype Boy' Official MV (HANNI ver.)              남자    별로      음색
#             'Hype Boy' Official MV (HYEIN ver.)              안무    해린      애가
#             'Hype Boy' Official MV (MINJI ver.)              별로    매력      충격
#             ASAP                                             민지    삭제      앨범
#             All                                              일본  기자회견      마녀
#             Attention                                        전설    매력      혜인
#             Bubble Gum                                      어도어    머리    기자회견
#             Cookie                                          타이틀    멤버      표현
#             Ditto (side A)                                   음악    감독      한국
#             Ditto (side B)                                   장면   캠코더      마음
#             ETA                                            르세라핌    해린      한국
#             How Sweet                                        감성    대표      이브
#             Hurt                                             애기   다니엘      소녀
#             New Jeans                                        파워   단월드     방시혁
#             OMG                                             기독교    마고      종교
#             Right Now                                       케이팝    대표     캐릭터
#             Super Shy                                        한국   사이비      컨셉
#             Supernatural (Part.1)                           일본어    관심      활동
#             Supernatural (Part.2)                           하이브   다니엘     조회수
#             Zero                                             민지  광고음악      병원
# STAYC       All                                              버블    음악      가사
#             No quoted content found.                        비주얼   레전드      기대
# aespa       All                                            수퍼노바    한국      보컬
#             Armageddon                                       윈터    소화     뉴진스
#             Better Things                                    바다    별로      여신
#             Black Mamba                                     화이팅    마미      중독
#             Drama                                            마마    마이    스트리밍
#             Forever                                          코디   스타일     갑자기
#             Girls                                            앨범    한국     한국인
#             Live My Life                                     가사    지젤      개인
#             Next Level                                       한국   스타일      핑크
#             Savage                                           블랙   월요일     목요일
#             Spicy                                            중독    응원      비트
#             Supernova                                       걸그룹    수수      달성
#             Welcome To MY World (Feat. nævis)               화이팅    월드      멤버
# tripleS     All                                              마음    눈물      레이
#             Generation                                       응원    세대      디토
#             Rising                                          김유연   걸그룹      비트
#
# Keyword_Index                                                 30
# Group       Title
# All         All                                              NaN
# FIFTY FIFTY All                                               영어
#             Cupid                                             데뷔
#             Higher                                            신인
#             Lovin' Me                                         소름
#             SOS                                               활동
#             Starry Night                                      예원
# ITZY        All                                              아이돌
#             BET ON ME                                         연기
#             BORN TO BE                                        보컬
#             Boys Like You                                     앨범
#             CAKE                                              달라
#             Cheshire                                          찰떡
#             ICY                                               멤버
#             LOCO                                              핑크
#             Mr. Vampire                                       소녀
#             None of My Business                               마비
#             Not Shy                                           음악
#             SNEAKERS                                          자격
#             SWIPE                                             음악
#             UNTOUCHABLE                                       내지
#             Voltage                                           싱글
#             WANNABE                                           안무
#             달라달라(DALLA DALLA)                          이채령
#             마.피.아. In the morning                          언니
# IVE         Accendio                                          언니
#             After LIKE                                        음색
#             All                                               머리
#             All Night (Feat. Saweetie)                       외국인
#             Baddie                                            응원
#             ELEVEN                                           비주얼
#             Either Way                                        눈물
#             I AM                                             레전드
#             Kitsch                                          타이틀곡
#             LOVE DIVE                                         가사
#             Off The Record                                    안경
#             해야 (HEYA)                                       이서
# Kep1er      All                                               앨범
#             Giddy                                             앨범
#             Grand Prix                                       NaN
#             I do! Do you                                      평가
#             Straight Line                                    강예서
#             Sugar Rush                                       NaN
#             Up!                                               유진
#             WA DA DA                                          영은
#             We Fresh                                          활동
#             Wing Wing                                         멤버
# LE SSERAFIM ANTIFRAGILE                                       응원
#             All                                               앨범
#             CRAZY                                            에스파
#             EASY                                              활동
#             FEARLESS                                          논란
#             Impurities                                       카메라
#             Perfect Night                                     중독
#             Smart                                             연습
#             UNFORGIVEN (feat. Nile Rodgers)                   기대
#             이브, 프시케 그리고 푸른 수염의 아내           사이비
# NMIXX       All                                               가사
#             DASH                                              활동
#             DICE                                             아이브
#             Funky Glitter Christmas                          윤진아
#             Love Me Like This                                타이틀
#             O.O                                               지니
#             Party O’Clock                                     요정
#             Roller Coaster                                    상큼
#             Soñar (Breaker)                                 쏘냐르
#             Young, Dumb, Stupid                             트와이스
#             별별별 (See that)                              비트
#             蜚蜚 (FEIFEI)                                       설윤
# NewJeans    'Cool With You' & 'Get Up' (side B)               여자
#             'Cool With You' (side A)                         돌고래
#             'Hype Boy' Official MV (DANIELLE&HAERIN ver.)     천재
#             'Hype Boy' Official MV (HANNI ver.)              비주얼
#             'Hype Boy' Official MV (HYEIN ver.)               하니
#             'Hype Boy' Official MV (MINJI ver.)               나이
#             ASAP                                              하니
#             All                                              박지원
#             Attention                                       에프엑스
#             Bubble Gum                                       다니엘
#             Cookie                                          하입보이
#             Ditto (side A)                                   사이비
#             Ditto (side B)                                    일본
#             ETA                                               생일
#             How Sweet                                         하니
#             Hurt                                             비주얼
#             New Jeans                                         토끼
#             OMG                                               천사
#             Right Now                                         컴백
#             Super Shy                                         돌파
#             Supernatural (Part.1)                            어도어
#             Supernatural (Part.2)                             대표
#             Zero                                              당황
# STAYC       All                                               비트
#             No quoted content found.                          머리
# aespa       All                                              한국인
#             Armageddon                                     뮤직비디오
#             Better Things                                    목소리
#             Black Mamba                                       얼굴
#             Drama                                             기대
#             Forever                                          에스엠
#             Girls                                             멤버
#             Live My Life                                      언니
#             Next Level                                        머리
#             Savage                                           수요일
#             Spicy                                           레드벨벳
#             Supernova                                       르세라핌
#             Welcome To MY World (Feat. nævis)                 스엠
# tripleS     All                                              정병기
#             Generation                                        달소
#             Rising                                            매력
