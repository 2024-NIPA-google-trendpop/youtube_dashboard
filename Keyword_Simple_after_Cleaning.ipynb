# %% [markdown]
# 환경설정

# %%
import os
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import time
import tqdm
import jpype
import ast

# %%
folder_path = '/Users/jaesolshin/Documents/GitHub/youtube_dashboard'
file_path = os.path.join(folder_path, 'KPOP_comments_merged_preprocessed_with_nouns.csv')
comments_df = pd.read_csv(file_path)

# %% [markdown]
# # 키워드 추출

# %%
# 불용어 정의
stopwords = ['timecode', '진짜','이번','사람','정말', '뭔데', '그룹', '우리', '생각', '댓글', '느낌','계속', '지금', '최고', '영상', '처음', '축하', '대박', '이건', '당신', '제발', '항상', '아주', '다음', '정도', '모두', '보고', '그냥', '다시', '그것', '역시', '점점', '오늘', '요즘', '가장', '부분', '전부', '제일', '너머', '내용', '뭔가', '모습', '근데', '너무', '아니', '사람들', '같아요', '데리', '여러분', '세상', '자기', '다른']

# 고유명사 리스트 정의
custom_nouns = ['에스파', '조회수', '하이브', '어도어', 'BTS', '아이브', '르세라핌']

# %%
import time
from collections import defaultdict
import numpy as np

def extract_keywords_frequency(series_word_list, top_n=30, min_df=1, existing_keywords=None):
    # 시작시간 확인
    start_time = time.time()

    # 기존 키워드가 없으면 빈 리스트로 초기화
    if existing_keywords is None:
        existing_keywords = []

    # 단어별 문서 빈도를 저장할 딕셔너리 (각 단어가 등장한 문서 수)
    doc_frequency = defaultdict(int)

    # 각 문서에서 등장한 단어 추출 및 빈도 계산
    for word_list in series_word_list:
        unique_words_in_doc = list(set(word_list))  # 문서 내에서 중복된 단어는 한 번만 카운트
        for word in unique_words_in_doc:
            doc_frequency[word] += 1

    # min_df 조건을 충족하는 단어들의 빈도를 저장할 딕셔너리
    word_frequencies = defaultdict(int)

    # 각 문서의 단어 빈도 카운트 (min_df 조건에 맞는 단어만 빈도 계산)
    for word_list in series_word_list:
        for word in word_list:
            if doc_frequency[word] >= min_df:
                word_frequencies[word] += 1

    # 상위 빈도 단어 추출
    sorted_words = sorted(word_frequencies.items(), key=lambda item: item[1], reverse=True)
    
    # 기존 키워드 제외하고 새로운 키워드만 추출
    new_keywords_with_weights = [(word, count) for word, count in sorted_words if word not in existing_keywords]
    
    # 상위 n개 키워드만 추출 (중복 제외 후)
    if len(new_keywords_with_weights) >= top_n:
        top_keywords_with_weights = new_keywords_with_weights[:top_n]
    else:
        top_keywords_with_weights = new_keywords_with_weights
        # 추가 키워드 부족 시 기존 데이터와 겹치지 않도록 기존 키워드에서 추가
        additional_keywords_needed = top_n - len(top_keywords_with_weights)
        additional_keywords = np.random.choice(existing_keywords, size=additional_keywords_needed, replace=False).tolist()
        top_keywords_with_weights += [(word, 0) for word in additional_keywords]  # 가중치는 0으로 설정
    
    # 키워드만 추출
    top_keywords = [word for word, _ in top_keywords_with_weights]

    # 가중치를 전체 합으로 표준화
    total_count = sum(count for _, count in top_keywords_with_weights)
    if total_count > 0:
        keywords_with_weights = [(word, count / total_count) for word, count in top_keywords_with_weights]
    else:
        keywords_with_weights = [(word, 0) for word, count in top_keywords_with_weights]

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %%
# TF-IDF 기반 키워드 및 상대적 비중 추출 함수
def extract_keywords_tfidf(series_word_list, top_n=100, min_df=1):

    # 시작시간 확인
    start_time = time.time()

    # 리스트 시리즈를 문자열 시리즈로 변형
    word_list_str = series_word_list.apply(lambda words: ' '.join(words))

    # TF-IDF 벡터화 (min_df를 설정해 빈도수가 적은 단어 제거)
    vectorizer = TfidfVectorizer(max_features=1000, min_df=min_df)
    tfidf_matrix = vectorizer.fit_transform(word_list_str)

    # 각 단어의 TF-IDF 점수를 추출
    feature_names = vectorizer.get_feature_names_out()
    tfidf_scores = np.mean(tfidf_matrix.toarray(), axis=0)  # 전체 문서에서 평균 TF-IDF 추출

    # TF-IDF 점수를 기준으로 상위 키워드 추출
    top_n_indices = tfidf_scores.argsort()[-top_n:][::-1]
    top_keywords = [feature_names[idx] for idx in top_n_indices]

    # 각 단어의 TF-IDF 점수 추출
    weights = [tfidf_scores[idx] for idx in top_n_indices]

    # 가중치를 전체 합으로 표준화
    weights = weights / np.sum(weights)

    # 키워드와 가중치를 묶어서 반환
    keywords_with_weights = list(zip(top_keywords, weights))

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %%
from rank_bm25 import BM25Okapi
import time
import numpy as np
import pandas as pd
from collections import defaultdict

# BM25 기반 키워드 및 상대적 비중 추출 함수 (min_df 추가)
def extract_keywords_bm25(series_word_list, top_n=100, min_df=1):
    # 시작시간 확인
    start_time = time.time()

    # 시리즈의 각 리스트를 문서로 간주하여 BM25 모델 생성
    tokenized_corpus = series_word_list.tolist()
    bm25 = BM25Okapi(tokenized_corpus)

    # 각 단어의 출현 빈도를 저장할 딕셔너리
    doc_frequency = defaultdict(int)

    # 문서 내 각 단어의 출현 빈도 계산
    for doc in tokenized_corpus:
        unique_words_in_doc = set(doc)
        for word in unique_words_in_doc:
            doc_frequency[word] += 1

    # 각 단어의 BM25 점수를 저장할 딕셔너리
    word_scores = defaultdict(float)
    total_docs = len(tokenized_corpus)

    # 각 문서에서의 BM25 점수를 계산하여 해당 단어에 대한 점수를 합산
    for doc in tokenized_corpus:
        scores = bm25.get_scores(doc)
        for word, score in zip(doc, scores):
            # 단어의 출현 빈도가 min_df 이상인 경우에만 점수 계산
            if doc_frequency[word] >= min_df:
                word_scores[word] += score

    # 문서 전체에 대한 평균 BM25 점수로 변환
    word_scores = {word: score / total_docs for word, score in word_scores.items()}

    # 상위 BM25 점수를 기준으로 키워드 추출
    sorted_words = sorted(word_scores.items(), key=lambda item: item[1], reverse=True)
    top_keywords = sorted_words[:top_n]

    # 가중치를 전체 합으로 표준화
    total_weight = sum(score for _, score in top_keywords)
    keywords_with_weights = [(word, score / total_weight) for word, score in top_keywords]

    # 종료시간 확인
    end_time = time.time()

    # 소요시간 출력
    print(f"{len(series_word_list)}개 댓글 키워드 추출에 걸린 시간: {end_time - start_time} 초\n")

    return top_keywords, keywords_with_weights

# %%
sample_df = comments_df.copy()
#sample_df = comments_df.sample(frac=0.1, random_state=42)
print(len(sample_df), "\n")

# csv 파일로 저장되면서 문자열로 변형된 word_list 컬럼을 다시 리스트로 변환
sample_df['word_list'] = sample_df['word_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# 단순 빈도 기반 키워드 추출
print('**단순 빈도 기반 키워드 추출**\n')
keywords1, keywords_with_weights1 = extract_keywords_frequency(sample_df['word_list'], top_n=300, min_df=50)

# 결과 출력
for item in keywords_with_weights1: print(item)
print('\n')

# TF-IDF 기반 키워드 추출
print('**TF-IDF 기반 키워드 추출**\n')
keywords2, keywords_with_weights2 = extract_keywords_tfidf(sample_df['word_list'], top_n=300, min_df=50)

# 결과 출력
for item in keywords_with_weights2: print(item)
print('\n')
# Out:
# 648060
#
# **단순 빈도 기반 키워드 추출**
#
# 648060개 댓글 키워드 추출에 걸린 시간: 1.0672390460968018 초
#
# ('노래', 0.06267088912923381)
# ('뉴진스', 0.04044226923645531)
# ('뮤비', 0.027513441592293745)
# ('아이브', 0.021102716329881185)
# ('하이브', 0.02050202693765124)
# ('사랑', 0.020448338377983023)
# ('민희진', 0.018436184533026246)
# ('단월드', 0.014549599670087692)
# ('컨셉', 0.010167368249052669)
# ('멤버', 0.0100413168480925)
# ('응원', 0.009197083699686427)
# ('에스파', 0.009012675168652106)
# ('사이비', 0.008673425719154366)
# ('화이팅', 0.008631408585500976)
# ('한국', 0.008589391451847587)
# ('가사', 0.007769279250538831)
# ('데뷔', 0.00753429454010691)
# ('아이돌', 0.007198935565947448)
# ('삭제', 0.007085333686069764)
# ('하나', 0.007005189894101261)
# ('중독', 0.006841011834825979)
# ('르세라핌', 0.006658937588994623)
# ('대표', 0.006640263307370895)
# ('여기', 0.0061531757950186354)
# ('방시혁', 0.006013896777908325)
# ('음악', 0.006001447256825839)
# ('앨범', 0.0058388253876858675)
# ('이제', 0.005617846388471744)
# ('리즈', 0.005595281631509738)
# ('파트', 0.005550152117585727)
# ('아이', 0.005508134983932337)
# ('컴백', 0.005340066449318778)
# ('조회수', 0.005134649351457761)
# ('마지막', 0.004796956092095332)
# ('혜인', 0.004639780888428948)
# ('하니', 0.004555746621122169)
# ('활동', 0.004543297100039683)
# ('때문', 0.004523066628280644)
# ('이유', 0.004505948536792225)
# ('모든', 0.004477937114356632)
# ('중국', 0.004466265688341802)
# ('소름', 0.004429695220162)
# ('일본', 0.0043153152452166605)
# ('걸그룹', 0.004288081917848722)
# ('위해', 0.0041877076541211805)
# ('믹스', 0.004018861024439966)
# ('머리', 0.004004855313222169)
# ('이름', 0.003922377236050701)
# ('신곡', 0.0038647982010442034)
# ('한국인', 0.0038243372575261247)
# ('감성', 0.003816556306849571)
# ('자체', 0.0038157782117819155)
# ('다니엘', 0.003804106785767085)
# ('기억', 0.0013696860419425353)
# ('순간', 0.0013690485006342316)
# ('천만', 0.0013687163150180534)
# ('장르', 0.0013531022931822028)
# ('왜케', 0.00134898283872226)
# ('대한민국', 0.00134654928948691)
# ('트와이스', 0.0013442932394540437)
# ('채원', 0.001341210845669424)
# ('시혁', 0.0013406196747393192)
# ('자살', 0.001331890713464637)
# ('이노', 0.001328143000838102)
# ('사건', 0.0013217513447066024)
# ('논란', 0.0013198352426074963)
# ('실망', 0.0013155080333202842)
# ('그거', 0.0013149322632688345)
# ('하자', 0.0013120796264153931)
# ('종교', 0.0013099640409252897)
# ('미국', 0.0013067625417158412)
# ('마녀', 0.0013037111874009335)
# ('댄스', 0.0012988094492330567)
# ('수도', 0.0012917703788210045)
# ('언론', 0.0012905631546140106)
# ('돼지', 0.001285252015119585)
# ('해명', 0.0012828431456158782)
# ('존재', 0.0012821287994451375)
# ('뉴스', 0.0012757769726993685)
# ('상황', 0.0012742959520094814)
# ('수고', 0.0012680102399613943)
# ('본인', 0.0012672728902096346)
# ('시절', 0.0012650308372014855)
# ('아무', 0.001263051812448699)
# ('심장', 0.0012606586589344918)
# ('아기', 0.0012593981876758004)
# ('국민', 0.001249327919362538)
# ('천사', 0.0012471046906798722)
# ('시대', 0.0012373870805930825)
# ('가요', 0.001231025758959375)
# ('부터', 0.0012306127817142715)
# ('공개', 0.0012301835616213394)
# ('프로', 0.001226129091692827)
# ('혼자', 0.0012215339568436218)
# ('검색', 0.0012179455397526929)
# ('추억', 0.0012150052363243471)
# ('혹시', 0.0012020748785410609)
# ('실시간', 0.001201895921149849)
# ('대한', 0.0011988606771307047)
# ('전체', 0.001195717598152699)
# ('얼마', 0.0011956680842153398)
# ('슈퍼', 0.001181827034372802)
# ('위로', 0.0011811414054750783)

# %%
# 출력 옵션 설정: 모든 열을 출력
pd.set_option('display.max_columns', None)  # 모든 열 출력
pd.set_option('display.max_rows', None)     # 모든 행 출력

# 데이터프레임 전치 및 출력
compare_result  = pd.DataFrame([keywords1, keywords2]).transpose()
compare_result
# Out:
#          0      1
# 0       노래     노래
# 1      뉴진스    뉴진스
# 2       뮤비    아이브
# 3      아이브     사랑
# 4      하이브     뮤비
# 5       사랑    하이브
# 6      민희진    민희진
# 7      단월드    단월드
# 8       컨셉    화이팅
# 9       멤버    에스파
# 10      응원     응원
# 11     에스파     컨셉
# 12     사이비     중독
# 13     화이팅     한국
# 14      한국     아이
# 15      가사     멤버
# 16      데뷔     리즈
# 17     아이돌     삭제
# 18      삭제     파트
# 19      하나    사이비
# 20      중독     컴백
# 21    르세라핌    아이돌
# 22      대표    조회수
# 23      여기     여기
# 24     방시혁     가사
# 25      음악     음악
# 26      앨범     데뷔
# 27      이제     하나
# 28      리즈     소름
# 29      파트   르세라핌
# 30      아이     이제
# 31      컴백    한국인
# 32     조회수     믹스
# 33     마지막     방지
# 34      혜인     앨범
# 35      하니     대표
# 36      활동    스테이
# 37      때문     레이
# 38      이유     신곡
# 39      모든     중국
# 40      중국     유진
# 41      소름    방시혁
# 42      일본     감성
# 43     걸그룹     별로
# 44      위해     하니
# 45      믹스     원영
# 46      머리    걸그룹
# 47      이름     완전
# 48      신곡     이브
# 49     한국인     활동
# 50      감성     가을
# 51      자체    마지막
# 52     다니엘     언니
# 53     아일릿     프티
# 54    여자친구     혜인
# 55      시작    목소리
# 56      의미     모든
# 57      민지     머리
# 58     유튜브     안무
# 59      완전     일본
# 60      문화    카리나
# 61      안무     기대
# 62      마음     음색
# 63      관련    레전드
# 64      무슨     누가
# 65      레이     민지
# 66      별로     무슨
# 67      사실     어디
# 68      프티     문화
# 69     스테이     광고
# 70      유진     시작
# 71      절대    분위기
# 72      원영     얼굴
# 73      가을     진심
# 74    기자회견     때문
# 75      마녀     매력
# 76      광고    한국어
# 77      누가     소리
# 78     목소리    타이틀
# 79      홍보     한번
# 80      시간     이서
# 81     케이팝     마음
# 82      소리     스밍
# 83   뮤직비디오     류진
# 84      해석     건가
# 85      한번     윈터
# 86      어디     시간
# 87      방지     절대
# 88      얼굴     무대
# 89      기사     하루
# 90      원래     자체
# 91      음색     누구
# 92      영어     영어
# 93      문제     비트
# 94     분위기   코카콜라
# 95      기대    케이팝
# 96      언니    얼마나
# 97      장면    장원영
# 98      매력    유튜브
# 99     어도어     자꾸
# 100     바로     스타
# 101     자신    스타일
# 102     이브     음원
# 103     진심     이유
# 104     누구     친구
# 105     이상     여름
# 106     스밍     비주
# 107     해체     보컬
# 108     스타    파이팅
# 109     천사     달라
# 110     얘기    다이브
# 111     무대     바로
# 112     정신     기분
# 113     가지     인기
# 114    한국어  뮤직비디오
# 115     친구     버니
# 116    얼마나     해린
# 117     회사     이름
# 118     건가    다니엘
# 119     대중     위해
# 120    타이틀     뉴진
# 121     존재     수록
# 122     자꾸    아일릿
# 123    카리나     수가
# 124     종교     듣기
# 125     언급     언제
# 126     방탄     실력
# 127     하루     채령
# 128     신도    안유진
# 129     영화     침착
# 130    레전드     너희
# 131     나라     나라
# 132     마고     사실
# 133    기독교     영화
# 134     수가     역대
# 135     채널    최고다
# 136     보이     소녀
# 137     음원     회사
# 138     실력     여자
# 139     버니     와우
# 140     이서    멜로디
# 141     관심     의미
# 142     중간     버전
# 143     보컬     지젤
# 144     소녀     정신
# 145     뉴진     알바
# 146    외국인     약간
# 147     여자     취향
# 148    스타일     벌써
# 149     인기     닝닝
# 150     해외     관심
# 151     수록     이상
# 152     역대     기사
# 153    소속사    라이브
# 154    멜로디     장면
# 155     거기     해석
# 156     이해     대중
# 157     수도     멜론
# 158     찬양     홍보
# 159     비주     이해
# 160    갑자기     쩐다
# 161     버블     원래
# 162     윈터     보이
# 163     그네     세대
# 164     기분     관련
# 165     개인     핑크
# 166     제목     개인
# 167     비트    어도어
# 168     너희     가수
# 169   정신병원     표절
# 170     해린     광야
# 171     류진    중국인
# 172     가수     버블
# 173     발음     애기
# 174     촬영     예지
# 175     언제     도입
# 176     약간     매우
# 177     멜론     문제
# 178     복사     인정
# 179     달라     고생
# 180    이야기     미모
# 181    정신병    빌보드
# 182     단신     왤케
# 183     화형     존나
# 184     사건     눈물
# 185     전체     조금
# 186     조금    갑자기
# 187   아티스트     매일
# 188     뉴스   여자친구
# 189     생일     가지
# 190     여친    외국인
# 191    장원영     찰떡
# 192     대한    소속사
# 193     심판     하이
# 194    다이브     해외
# 195     듣기     예술
# 196     자살     해도
# 197     사용    제대로
# 198     여름     차트
# 199     이후     가즈
# 200     본인     리아
# 201   단군신화     블랙
# 202     반복     의상
# 203     상황     최애
# 204     해도     토끼
# 205     사과     얘기
# 206     침착     거기
# 207     차트     디오
# 208     버전     독보
# 209     등장     채널
# 210    박지원     제한
# 211     세대     중간
# 212     현실     수준
# 213     핑크     외국
# 214     화면     유나
# 215   코카콜라     세계
# 216     표현     천재
# 217     직원     직원
# 218    중국인     그게
# 219     현재     나이
# 220     취향   기자회견
# 221     그게    케플러
# 222    지원이     테이
# 223     방송     걱정
# 224    제대로   스트리밍
# 225     언론     이후
# 226     매일     스엠
# 227    파이팅     인생
# 228    일부러   타이틀곡
# 229     일단     옛날
# 230     디토     힙합
# 231     상징    퀄리티
# 232    빌보드   아티스트
# 233     그날     자신
# 234     세계     디토
# 235     혼자     보기
# 236    라이브     일이
# 237     그림     표현
# 238     미국     방탄
# 239  방탄소년단     반복
# 240     역사     아센
# 241     그거     표정
# 242     제한     희진
# 243     타고     스파
# 244     채령     대체
# 245     인정     충격
# 246     표정    양조위
# 247     반대     악플
# 248     외국     일단
# 249     매우     거의
# 250     토끼     기억
# 251     눈물     순간
# 252     알바     천만
# 253    하나님     장르
# 254   대한민국     왜케
# 255     시절   대한민국
# 256     한복   트와이스
# 257     라인     채원
# 258     블랙     시혁
# 259     희진     자살
# 260     표절     이노
# 261     정리     사건
# 262     감독     논란
# 263     벌써     실망
# 264    안유진     그거
# 265     논란     하자
# 266     파티     종교
# 267     공식     미국
# 268     고생     마녀
# 269     실제     댄스
# 270   스트리밍     수도
# 271     일이     언론
# 272     찰떡     돼지
# 273     지젤     해명
# 274     퍼트     존재
# 275     거의     뉴스
# 276     부터     상황
# 277     기억     수고
# 278    그대로     본인
# 279     아무     시절
# 280     오엠     아무
# 281     발매     심장
# 282     나이     아기
# 283     계정     국민
# 284     걱정     천사
# 285    관계자     시대
# 286     수준     가요
# 287     보임     부터
# 288    최고다     공개
# 289     의상     프로
# 290     천재     혼자
# 291     닝닝     검색
# 292     거임     추억
# 293     희수     혹시
# 294     이기    실시간
# 295     보기     대한
# 296     혜진     전체
# 297     의도     얼마
# 298    실시간     슈퍼
# 299     굳이     위로

# %% [markdown]
# # 추가적인 불용어, 교정이 필요한 단어 찾아내기

# %%
## keyword_list 초기화 및 설정
keyword_list = pd.DataFrame(columns=['Group', 'Title', 'keyword'])

## 모든 댓글에 대한 키워드 추가
#sample_df['word_list'] = sample_df['word_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
# 단순 빈도 기반 키워드 추출
keywords, _ = extract_keywords_frequency(sample_df['word_list'], top_n=300, min_df=50)
keyword_list['keyword'] = pd.DataFrame(keywords)
keyword_list['Group'] = 'All'
keyword_list['Title'] = 'All'

## 각 그룹에 대한 추가키워드 발견
# Group 열에 속한 그룹들의 리스트
groups = sample_df['Group'].unique()

# 기존 keyword_list에서 추출된 키워드와 중복되지 않도록 새로운 키워드 추출
existing_keywords = keyword_list['keyword'].tolist()

# 그룹별로 새로운 키워드 추출
for group in groups:
    word_list = sample_df[sample_df['Group'] == group]['word_list']
    new_keywords, _ = extract_keywords_frequency(word_list, top_n=30, min_df=50, existing_keywords=existing_keywords)
    
    # 새로운 키워드를 기존 리스트에 추가
    frac = pd.DataFrame()
    frac['keyword'] = new_keywords
    frac['Group'] = group
    frac['Title'] = 'All'
    
    keyword_list = pd.concat([keyword_list, frac])
    keyword_list.drop_duplicates(subset='keyword', keep='first')
    existing_keywords = keyword_list['keyword'].tolist()
## 각 뮤비에 대한 추가 키워드 발견
# Title 열에 속한 그룹들의 리스트
titles = sample_df['Title'].unique()

# 그룹별로 새로운 키워드 추출
for title in titles:
    group = sample_df[sample_df['Title'] == title]['Group'].iloc[0] # 해당 타이틀에 속한 그룹 조회
    word_list = sample_df[sample_df['Title'] == title]['word_list'] # 댓글 시리즈 가져오기
    new_keywords, _ = extract_keywords_frequency(word_list, top_n=10, min_df=50, existing_keywords=existing_keywords)
    
    # 새로운 키워드를 기존 리스트에 추가
    frac = pd.DataFrame()
    frac['keyword'] = new_keywords
    frac['Group'] = group
    frac['Title'] = title
    
    keyword_list = pd.concat([keyword_list, frac])
    keyword_list.drop_duplicates(subset='keyword', keep='first')
    existing_keywords = keyword_list['keyword'].tolist()

# 인덱스 초기화
keyword_list = keyword_list.reset_index(drop=True)
# Out:
# 648060개 댓글 키워드 추출에 걸린 시간: 1.0455050468444824 초
#
# 23511개 댓글 키워드 추출에 걸린 시간: 0.026419878005981445 초
#
# 50699개 댓글 키워드 추출에 걸린 시간: 0.051187992095947266 초
#
# 249967개 댓글 키워드 추출에 걸린 시간: 0.5359420776367188 초
#
# 45376개 댓글 키워드 추출에 걸린 시간: 0.06146502494812012 초
#
# 7425개 댓글 키워드 추출에 걸린 시간: 0.006674289703369141 초
#
# 136993개 댓글 키워드 추출에 걸린 시간: 0.16198325157165527 초
#
# 33181개 댓글 키워드 추출에 걸린 시간: 0.03946185111999512 초
#
# 7846개 댓글 키워드 추출에 걸린 시간: 0.008840084075927734 초
#
# 69125개 댓글 키워드 추출에 걸린 시간: 0.0744779109954834 초
#
# 23937개 댓글 키워드 추출에 걸린 시간: 0.02672600746154785 초
#
# 4339개 댓글 키워드 추출에 걸린 시간: 0.005337953567504883 초
#
# 2622개 댓글 키워드 추출에 걸린 시간: 0.002788066864013672 초
#
# 551개 댓글 키워드 추출에 걸린 시간: 0.0006890296936035156 초
#
# 1442개 댓글 키워드 추출에 걸린 시간: 0.0016980171203613281 초
#
# 1406개 댓글 키워드 추출에 걸린 시간: 0.0017058849334716797 초
#
# 1416개 댓글 키워드 추출에 걸린 시간: 0.0014960765838623047 초
#
# 1916개 댓글 키워드 추출에 걸린 시간: 0.001901865005493164 초
#
# 1608개 댓글 키워드 추출에 걸린 시간: 0.0015230178833007812 초
#
# 570개 댓글 키워드 추출에 걸린 시간: 0.0007202625274658203 초
#
# 3550개 댓글 키워드 추출에 걸린 시간: 0.004310131072998047 초
#
# 1895개 댓글 키워드 추출에 걸린 시간: 0.002079010009765625 초
#
# 3602개 댓글 키워드 추출에 걸린 시간: 0.0036711692810058594 초
#
# 1068개 댓글 키워드 추출에 걸린 시간: 0.0012958049774169922 초
#
# 1984개 댓글 키워드 추출에 걸린 시간: 0.0023560523986816406 초
#
# 1451개 댓글 키워드 추출에 걸린 시간: 0.0018770694732666016 초
#
# 2487개 댓글 키워드 추출에 걸린 시간: 0.0028002262115478516 초
#
# 677개 댓글 키워드 추출에 걸린 시간: 0.0009479522705078125 초
#
# 3766개 댓글 키워드 추출에 걸린 시간: 0.005001068115234375 초
#
# 6162개 댓글 키워드 추출에 걸린 시간: 0.007678031921386719 초
#
# 1499개 댓글 키워드 추출에 걸린 시간: 0.0017850399017333984 초
#
# 12484개 댓글 키워드 추출에 걸린 시간: 0.015002965927124023 초
#
# 1616개 댓글 키워드 추출에 걸린 시간: 0.0019290447235107422 초
#
# 885개 댓글 키워드 추출에 걸린 시간: 0.0008759498596191406 초
#
# 17909개 댓글 키워드 추출에 걸린 시간: 0.02119922637939453 초
#
# 1521개 댓글 키워드 추출에 걸린 시간: 0.0016551017761230469 초
#
# 655개 댓글 키워드 추출에 걸린 시간: 0.0007231235504150391 초
#
# 11868개 댓글 키워드 추출에 걸린 시간: 0.018146038055419922 초
#
# 174개 댓글 키워드 추출에 걸린 시간: 0.0006220340728759766 초
#
# 3328개 댓글 키워드 추출에 걸린 시간: 0.003011941909790039 초
#
# 281개 댓글 키워드 추출에 걸린 시간: 0.0005567073822021484 초
#
# 28개 댓글 키워드 추출에 걸린 시간: 0.0002779960632324219 초
#
# 102개 댓글 키워드 추출에 걸린 시간: 0.0004298686981201172 초
#
# 451개 댓글 키워드 추출에 걸린 시간: 0.0006051063537597656 초
#
# 638개 댓글 키워드 추출에 걸린 시간: 0.0007159709930419922 초
#
# 3244개 댓글 키워드 추출에 걸린 시간: 0.002840757369995117 초
#
# 2823개 댓글 키워드 추출에 걸린 시간: 0.0025510787963867188 초
#
# 802개 댓글 키워드 추출에 걸린 시간: 0.0009398460388183594 초
#
# 749개 댓글 키워드 추출에 걸린 시간: 0.0008308887481689453 초
#
# 900개 댓글 키워드 추출에 걸린 시간: 0.0009908676147460938 초
#
# 1185개 댓글 키워드 추출에 걸린 시간: 0.0014200210571289062 초
#
# 1278개 댓글 키워드 추출에 걸린 시간: 0.001405954360961914 초
#
# 5531개 댓글 키워드 추출에 걸린 시간: 0.005800008773803711 초
#
# 2212개 댓글 키워드 추출에 걸린 시간: 0.0023109912872314453 초
#
# 777개 댓글 키워드 추출에 걸린 시간: 0.000843048095703125 초
#
# 1200개 댓글 키워드 추출에 걸린 시간: 0.001317739486694336 초
#
# 3832개 댓글 키워드 추출에 걸린 시간: 0.004775047302246094 초
#
# 11114개 댓글 키워드 추출에 걸린 시간: 0.01259303092956543 초
#
# 5739개 댓글 키워드 추출에 걸린 시간: 0.00487208366394043 초
#
# 7269개 댓글 키워드 추출에 걸린 시간: 0.006609916687011719 초
#
# 24683개 댓글 키워드 추출에 걸린 시간: 0.021928787231445312 초
#
# 10514개 댓글 키워드 추출에 걸린 시간: 0.008305072784423828 초
#
# 8939개 댓글 키워드 추출에 걸린 시간: 0.00815582275390625 초
#
# 23094개 댓글 키워드 추출에 걸린 시간: 0.018717050552368164 초
#
# 7809개 댓글 키워드 추출에 걸린 시간: 0.0080108642578125 초
#
# 1494개 댓글 키워드 추출에 걸린 시간: 0.0018498897552490234 초
#
# 3775개 댓글 키워드 추출에 걸린 시간: 0.005392789840698242 초
#
# 2572개 댓글 키워드 추출에 걸린 시간: 0.0025069713592529297 초
#
# 2973개 댓글 키워드 추출에 걸린 시간: 0.0033440589904785156 초
#
# 4106개 댓글 키워드 추출에 걸린 시간: 0.004712343215942383 초
#
# 4625개 댓글 키워드 추출에 걸린 시간: 0.004480123519897461 초
#
# 4402개 댓글 키워드 추출에 걸린 시간: 0.0047948360443115234 초
#
# 1359개 댓글 키워드 추출에 걸린 시간: 0.001589059829711914 초
#
# 989개 댓글 키워드 추출에 걸린 시간: 0.0013470649719238281 초
#
# 5572개 댓글 키워드 추출에 걸린 시간: 0.0051000118255615234 초
#
# 4446개 댓글 키워드 추출에 걸린 시간: 0.00695490837097168 초
#
# 15153개 댓글 키워드 추출에 걸린 시간: 0.020817995071411133 초
#
# 9556개 댓글 키워드 추출에 걸린 시간: 0.014507055282592773 초
#
# 33707개 댓글 키워드 추출에 걸린 시간: 0.049636125564575195 초
#
# 45641개 댓글 키워드 추출에 걸린 시간: 0.06683683395385742 초
#
# 3508개 댓글 키워드 추출에 걸린 시간: 0.004971981048583984 초
#
# 6748개 댓글 키워드 추출에 걸린 시간: 0.00978994369506836 초
#
# 9605개 댓글 키워드 추출에 걸린 시간: 0.009603261947631836 초
#
# 3835개 댓글 키워드 추출에 걸린 시간: 0.004065990447998047 초
#
# 10466개 댓글 키워드 추출에 걸린 시간: 0.00984811782836914 초
#
# 5489개 댓글 키워드 추출에 걸린 시간: 0.005212306976318359 초
#
# 1114개 댓글 키워드 추출에 걸린 시간: 0.0013251304626464844 초
#
# 4381개 댓글 키워드 추출에 걸린 시간: 0.004321098327636719 초
#
# 1576개 댓글 키워드 추출에 걸린 시간: 0.0015950202941894531 초
#
# 7685개 댓글 키워드 추출에 걸린 시간: 0.008620023727416992 초
#
# 11309개 댓글 키워드 추출에 걸린 시간: 0.012830972671508789 초
#
# 3678개 댓글 키워드 추출에 걸린 시간: 0.0035419464111328125 초
#
# 910개 댓글 키워드 추출에 걸린 시간: 0.0014259815216064453 초
#
# 9077개 댓글 키워드 추출에 걸린 시간: 0.009474039077758789 초
#
# 2949개 댓글 키워드 추출에 걸린 시간: 0.0039157867431640625 초
#
# 1917개 댓글 키워드 추출에 걸린 시간: 0.0030672550201416016 초
#
# 7332개 댓글 키워드 추출에 걸린 시간: 0.008826017379760742 초
#
# 3901개 댓글 키워드 추출에 걸린 시간: 0.0041921138763427734 초
#
# 81707개 댓글 키워드 추출에 걸린 시간: 0.25048208236694336 초
#
# 3707개 댓글 키워드 추출에 걸린 시간: 0.005613088607788086 초
#
# 6528개 댓글 키워드 추출에 걸린 시간: 0.009881973266601562 초
#
# 8220개 댓글 키워드 추출에 걸린 시간: 0.007678985595703125 초
#
# 10022개 댓글 키워드 추출에 걸린 시간: 0.010046958923339844 초
#
# 5879개 댓글 키워드 추출에 걸린 시간: 0.0044329166412353516 초
#
# 10473개 댓글 키워드 추출에 걸린 시간: 0.008696794509887695 초
#
# 5813개 댓글 키워드 추출에 걸린 시간: 0.004621982574462891 초
#
# 27447개 댓글 키워드 추출에 걸린 시간: 0.04749178886413574 초
#
# 1909개 댓글 키워드 추출에 걸린 시간: 0.0024712085723876953 초
#
# 1425개 댓글 키워드 추출에 걸린 시간: 0.0016560554504394531 초
#
# 29435개 댓글 키워드 추출에 걸린 시간: 0.031010866165161133 초

# %%
keyword_list
# Out:
#             Group                                          Title keyword
# 0             All                                            All      노래
# 1             All                                            All     뉴진스
# 2             All                                            All      뮤비
# 3             All                                            All     아이브
# 4             All                                            All     하이브
# 5             All                                            All      사랑
# 6             All                                            All     민희진
# 7             All                                            All     단월드
# 8             All                                            All      컨셉
# 9             All                                            All      멤버
# 10            All                                            All      응원
# 11            All                                            All     에스파
# 12            All                                            All     사이비
# 13            All                                            All     화이팅
# 14            All                                            All      한국
# 15            All                                            All      가사
# 16            All                                            All      데뷔
# 17            All                                            All     아이돌
# 18            All                                            All      삭제
# 19            All                                            All      하나
# 20            All                                            All      중독
# 21            All                                            All    르세라핌
# 22            All                                            All      대표
# 23            All                                            All      여기
# 24            All                                            All     방시혁
# 25            All                                            All      음악
# 26            All                                            All      앨범
# 27            All                                            All      이제
# 28            All                                            All      리즈
# 29            All                                            All      파트
# 30            All                                            All      아이
# 31            All                                            All      컴백
# 32            All                                            All     조회수
# 33            All                                            All     마지막
# 34            All                                            All      혜인
# 35            All                                            All      하니
# 36            All                                            All      활동
# 37            All                                            All      때문
# 38            All                                            All      이유
# 39            All                                            All      모든
# 40            All                                            All      중국
# 41            All                                            All      소름
# 42            All                                            All      일본
# 43            All                                            All     걸그룹
# 44            All                                            All      위해
# 45            All                                            All      믹스
# 46            All                                            All      머리
# 47            All                                            All      이름
# 48            All                                            All      신곡
# 49            All                                            All     한국인
# 50            All                                            All      감성
# 51            All                                            All      자체
# 52            All                                            All     다니엘
# 53            All                                            All     아일릿
# 54            All                                            All    여자친구
# 55            All                                            All      시작
# 56            All                                            All      의미
# 57            All                                            All      민지
# 58            All                                            All     유튜브
# 59            All                                            All      완전
# 60            All                                            All      문화
# 61            All                                            All      안무
# 62            All                                            All      마음
# 63            All                                            All      관련
# 64            All                                            All      무슨
# 65            All                                            All      레이
# 66            All                                            All      별로
# 67            All                                            All      사실
# 68            All                                            All      프티
# 69            All                                            All     스테이
# 70            All                                            All      유진
# 71            All                                            All      절대
# 72            All                                            All      원영
# 73            All                                            All      가을
# 74            All                                            All    기자회견
# 75            All                                            All      마녀
# 76            All                                            All      광고
# 77            All                                            All      누가
# 78            All                                            All     목소리
# 79            All                                            All      홍보
# 80            All                                            All      시간
# 81            All                                            All     케이팝
# 82            All                                            All      소리
# 83            All                                            All   뮤직비디오
# 84            All                                            All      해석
# 85            All                                            All      한번
# 86            All                                            All      어디
# 87            All                                            All      방지
# 88            All                                            All      얼굴
# 89            All                                            All      기사
# 90            All                                            All      원래
# 91            All                                            All      음색
# 92            All                                            All      영어
# 93            All                                            All      문제
# 94            All                                            All     분위기
# 95            All                                            All      기대
# 96            All                                            All      언니
# 97            All                                            All      장면
# 98            All                                            All      매력
# 99            All                                            All     어도어
# 100           All                                            All      바로
# 101           All                                            All      자신
# 102           All                                            All      이브
# 103           All                                            All      진심
# 104           All                                            All      누구
# 105           All                                            All      이상
# 106           All                                            All      스밍
# 107           All                                            All      해체
# 108           All                                            All      스타
# 109           All                                            All      천사
# 110           All                                            All      얘기
# 111           All                                            All      무대
# 112           All                                            All      정신
# 113           All                                            All      가지
# 114           All                                            All     한국어
# 115           All                                            All      친구
# 116           All                                            All     얼마나
# 117           All                                            All      회사
# 118           All                                            All      건가
# 119           All                                            All      대중
# 120           All                                            All     타이틀
# 121           All                                            All      존재
# 122           All                                            All      자꾸
# 123           All                                            All     카리나
# 124           All                                            All      종교
# 125           All                                            All      언급
# 126           All                                            All      방탄
# 127           All                                            All      하루
# 128           All                                            All      신도
# 129           All                                            All      영화
# 130           All                                            All     레전드
# 131           All                                            All      나라
# 132           All                                            All      마고
# 133           All                                            All     기독교
# 134           All                                            All      수가
# 135           All                                            All      채널
# 136           All                                            All      보이
# 137           All                                            All      음원
# 138           All                                            All      실력
# 139           All                                            All      버니
# 140           All                                            All      이서
# 141           All                                            All      관심
# 142           All                                            All      중간
# 143           All                                            All      보컬
# 144           All                                            All      소녀
# 145           All                                            All      뉴진
# 146           All                                            All     외국인
# 147           All                                            All      여자
# 148           All                                            All     스타일
# 149           All                                            All      인기
# 150           All                                            All      해외
# 151           All                                            All      수록
# 152           All                                            All      역대
# 153           All                                            All     소속사
# 154           All                                            All     멜로디
# 155           All                                            All      거기
# 156           All                                            All      이해
# 157           All                                            All      수도
# 158           All                                            All      찬양
# 159           All                                            All      비주
# 160           All                                            All     갑자기
# 161           All                                            All      버블
# 162           All                                            All      윈터
# 163           All                                            All      그네
# 164           All                                            All      기분
# 165           All                                            All      개인
# 166           All                                            All      제목
# 167           All                                            All      비트
# 168           All                                            All      너희
# 169           All                                            All    정신병원
# 170           All                                            All      해린
# 171           All                                            All      류진
# 172           All                                            All      가수
# 173           All                                            All      발음
# 174           All                                            All      촬영
# 175           All                                            All      언제
# 176           All                                            All      약간
# 177           All                                            All      멜론
# 178           All                                            All      복사
# 179           All                                            All      달라
# 180           All                                            All     이야기
# 181           All                                            All     정신병
# 182           All                                            All      단신
# 183           All                                            All      화형
# 184           All                                            All      사건
# 185           All                                            All      전체
# 186           All                                            All      조금
# 187           All                                            All    아티스트
# 188           All                                            All      뉴스
# 189           All                                            All      생일
# 190           All                                            All      여친
# 191           All                                            All     장원영
# 192           All                                            All      대한
# 193           All                                            All      심판
# 194           All                                            All     다이브
# 195           All                                            All      듣기
# 196           All                                            All      자살
# 197           All                                            All      사용
# 198           All                                            All      여름
# 199           All                                            All      이후
# 200           All                                            All      본인
# 201           All                                            All    단군신화
# 202           All                                            All      반복
# 203           All                                            All      상황
# 204           All                                            All      해도
# 205           All                                            All      사과
# 206           All                                            All      침착
# 207           All                                            All      차트
# 208           All                                            All      버전
# 209           All                                            All      등장
# 210           All                                            All     박지원
# 211           All                                            All      세대
# 212           All                                            All      현실
# 213           All                                            All      핑크
# 214           All                                            All      화면
# 215           All                                            All    코카콜라
# 216           All                                            All      표현
# 217           All                                            All      직원
# 218           All                                            All     중국인
# 219           All                                            All      현재
# 220           All                                            All      취향
# 221           All                                            All      그게
# 222           All                                            All     지원이
# 223           All                                            All      방송
# 224           All                                            All     제대로
# 225           All                                            All      언론
# 226           All                                            All      매일
# 227           All                                            All     파이팅
# 228           All                                            All     일부러
# 229           All                                            All      일단
# 230           All                                            All      디토
# 231           All                                            All      상징
# 232           All                                            All     빌보드
# 233           All                                            All      그날
# 234           All                                            All      세계
# 235           All                                            All      혼자
# 236           All                                            All     라이브
# 237           All                                            All      그림
# 238           All                                            All      미국
# 239           All                                            All   방탄소년단
# 240           All                                            All      역사
# 241           All                                            All      그거
# 242           All                                            All      제한
# 243           All                                            All      타고
# 244           All                                            All      채령
# 245           All                                            All      인정
# 246           All                                            All      표정
# 247           All                                            All      반대
# 248           All                                            All      외국
# 249           All                                            All      매우
# 250           All                                            All      토끼
# 251           All                                            All      눈물
# 252           All                                            All      알바
# 253           All                                            All     하나님
# 254           All                                            All    대한민국
# 255           All                                            All      시절
# 256           All                                            All      한복
# 257           All                                            All      라인
# 258           All                                            All      블랙
# 259           All                                            All      희진
# 260           All                                            All      표절
# 261           All                                            All      정리
# 262           All                                            All      감독
# 263           All                                            All      벌써
# 264           All                                            All     안유진
# 265           All                                            All      논란
# 266           All                                            All      파티
# 267           All                                            All      공식
# 268           All                                            All      고생
# 269           All                                            All      실제
# 270           All                                            All    스트리밍
# 271           All                                            All      일이
# 272           All                                            All      찰떡
# 273           All                                            All      지젤
# 274           All                                            All      퍼트
# 275           All                                            All      거의
# 276           All                                            All      부터
# 277           All                                            All      기억
# 278           All                                            All     그대로
# 279           All                                            All      아무
# 280           All                                            All      오엠
# 281           All                                            All      발매
# 282           All                                            All      나이
# 283           All                                            All      계정
# 284           All                                            All      걱정
# 285           All                                            All     관계자
# 286           All                                            All      수준
# 287           All                                            All      보임
# 288           All                                            All     최고다
# 289           All                                            All      의상
# 290           All                                            All      천재
# 291           All                                            All      닝닝
# 292           All                                            All      거임
# 293           All                                            All      희수
# 294           All                                            All      이기
# 295           All                                            All      보기
# 296           All                                            All      혜진
# 297           All                                            All      의도
# 298           All                                            All     실시간
# 299           All                                            All      굳이
# 300         NMIXX                                            All      릴리
# 301         NMIXX                                            All      설윤
# 302         NMIXX                                            All      지우
# 303         NMIXX                                            All     대중성
# 304         NMIXX                                            All      규진
# 305         NMIXX                                            All      제왑
# 306         NMIXX                                            All      해원
# 307         NMIXX                                            All    트와이스
# 308         NMIXX                                            All      장르
# 309         NMIXX                                            All      별별
# 310         NMIXX                                            All      지니
# 311         NMIXX                                            All      존나
# 312         NMIXX                                            All    타이틀곡
# 313         NMIXX                                            All      본부
# 314         NMIXX                                            All     박진영
# 315         NMIXX                                            All      재능
# 316         NMIXX                                            All     오해원
# 317         NMIXX                                            All      힙합
# 318         NMIXX                                            All      도입
# 319         NMIXX                                            All    권모술수
# 320         NMIXX                                            All      선공
# 321         NMIXX                                            All     다이스
# 322         NMIXX                                            All      색깔
# 323         NMIXX                                            All      대쉬
# 324         NMIXX                                            All     차라리
# 325         NMIXX                                            All     퀄리티
# 326         NMIXX                                            All      윤아
# 327         NMIXX                                            All      음방
# 328         NMIXX                                            All      미모
# 329         NMIXX                                            All      처럼
# 330          ITZY                                            All      예지
# 331          ITZY                                            All      리아
# 332          ITZY                                            All      유나
# 333          ITZY                                            All     마피아
# 334          ITZY                                            All      날자
# 335          ITZY                                            All      너비
# 336          ITZY                                            All      채연
# 337          ITZY                                            All      블핑
# 338          ITZY                                            All      와우
# 339          ITZY                                            All    퍼포먼스
# 340          ITZY                                            All      댄스
# 341          ITZY                                            All    스니커즈
# 342          ITZY                                            All      한글
# 343          ITZY                                            All     케이크
# 344          ITZY                                            All      동생
# 345          ITZY                                            All     이채령
# 346          ITZY                                            All      신인
# 347          ITZY                                            All      실망
# 348          ITZY                                            All      티저
# 349          ITZY                                            All     아이즈
# 350          ITZY                                            All      개성
# 351          ITZY                                            All      노력
# 352          ITZY                                            All      실시
# 353          ITZY                                            All      존예
# 354          ITZY                                            All      왤케
# 355          ITZY                                            All      진영
# 356          ITZY                                            All     안무가
# 357          ITZY                                            All     이채연
# 358          ITZY                                            All      후렴
# 359          ITZY                                            All      신경
# 360      NewJeans                                            All    너뿐이야
# 361      NewJeans                                            All      투바
# 362      NewJeans                                            All      인사
# 363      NewJeans                                            All      명상
# 364      NewJeans                                            All      침묵
# 365      NewJeans                                            All     사이버
# 366      NewJeans                                            All      제물
# 367      NewJeans                                            All     인터뷰
# 368      NewJeans                                            All      단군
# 369      NewJeans                                            All      연관
# 370      NewJeans                                            All      추측
# 371      NewJeans                                            All      출신
# 372      NewJeans                                            All     글로벌
# 373      NewJeans                                            All      카톡
# 374      NewJeans                                            All      협박
# 375      NewJeans                                            All      탈출
# 376      NewJeans                                            All      정보
# 377      NewJeans                                            All      목차
# 378      NewJeans                                            All     아이폰
# 379      NewJeans                                            All      타임
# 380      NewJeans                                            All      학교
# 381      NewJeans                                            All      대학
# 382      NewJeans                                            All      천공
# 383      NewJeans                                            All      연령
# 384      NewJeans                                            All      며칠
# 385      NewJeans                                            All      단어
# 386      NewJeans                                            All      소속
# 387      NewJeans                                            All      사회
# 388      NewJeans                                            All      강조
# 389      NewJeans                                            All      통해
# 390   FIFTY FIFTY                                            All      홍준
# 391   FIFTY FIFTY                                            All     큐피드
# 392   FIFTY FIFTY                                            All      아란
# 393   FIFTY FIFTY                                            All      천만
# 394   FIFTY FIFTY                                            All      샤넬
# 395   FIFTY FIFTY                                            All      배신
# 396   FIFTY FIFTY                                            All     아테나
# 397   FIFTY FIFTY                                            All      안성
# 398   FIFTY FIFTY                                            All    어트랙트
# 399   FIFTY FIFTY                                            All      구매
# 400   FIFTY FIFTY                                            All      예원
# 401   FIFTY FIFTY                                            All      투자
# 402   FIFTY FIFTY                                            All      부모
# 403   FIFTY FIFTY                                            All      수돌
# 404   FIFTY FIFTY                                            All      인성
# 405   FIFTY FIFTY                                            All      소송
# 406   FIFTY FIFTY                                            All      인생
# 407   FIFTY FIFTY                                            All      가즈
# 408   FIFTY FIFTY                                            All      국내
# 409   FIFTY FIFTY                                            All      통수
# 410   FIFTY FIFTY                                            All      시오
# 411   FIFTY FIFTY                                            All      중소
# 412   FIFTY FIFTY                                            All      버스
# 413   FIFTY FIFTY                                            All      국민
# 414   FIFTY FIFTY                                            All      성공
# 415   FIFTY FIFTY                                            All     기획사
# 416   FIFTY FIFTY                                            All      몽환
# 417   FIFTY FIFTY                                            All      둥이
# 418   FIFTY FIFTY                                            All      사장
# 419   FIFTY FIFTY                                            All     큐피트
# 420        Kep1er                                            All     케플러
# 421        Kep1er                                            All     히카루
# 422        Kep1er                                            All     샤오팅
# 423        Kep1er                                            All     짱플러
# 424        Kep1er                                            All      영은
# 425        Kep1er                                            All      예서
# 426        Kep1er                                            All     김다연
# 427        Kep1er                                            All     김채현
# 428        Kep1er                                            All      플리
# 429        Kep1er                                            All      그녀
# 430        Kep1er                                            All      현이
# 431        Kep1er                                            All     서영은
# 432        Kep1er                                            All     최유진
# 433        Kep1er                                            All      바히
# 434        Kep1er                                            All      채현
# 435        Kep1er                                            All    휴닝바히
# 436        Kep1er                                            All      라인
# 437        Kep1er                                            All      기대
# 438        Kep1er                                            All      홍보
# 439        Kep1er                                            All      그게
# 440        Kep1er                                            All      혜진
# 441        Kep1er                                            All      대쉬
# 442        Kep1er                                            All      이서
# 443        Kep1er                                            All      인성
# 444        Kep1er                                            All      리아
# 445        Kep1er                                            All     아이즈
# 446        Kep1er                                            All      조금
# 447        Kep1er                                            All      목차
# 448        Kep1er                                            All      보컬
# 449        Kep1er                                            All      천공
# 450           IVE                                            All      디오
# 451           IVE                                            All      아센
# 452           IVE                                            All      전통
# 453           IVE                                            All      러브
# 454           IVE                                            All      매듭
# 455           IVE                                            All      키치
# 456           IVE                                            All     일레븐
# 457           IVE                                            All     아이엠
# 458           IVE                                            All     호랑이
# 459           IVE                                            All      하자
# 460           IVE                                            All      아기
# 461           IVE                                            All      최애
# 462           IVE                                            All      국문
# 463           IVE                                            All     대혁명
# 464           IVE                                            All      국가
# 465           IVE                                            All      선배
# 466           IVE                                            All      요소
# 467           IVE                                            All      도둑
# 468           IVE                                            All     애프터
# 469           IVE                                            All      분량
# 470           IVE                                            All      고음
# 471           IVE                                            All      순이
# 472           IVE                                            All      금발
# 473           IVE                                            All      수고
# 474           IVE                                            All      웨이
# 475           IVE                                            All      공주
# 476           IVE                                            All      순간
# 477           IVE                                            All      쩐다
# 478           IVE                                            All      비교
# 479           IVE                                            All    마법소녀
# 480   LE SSERAFIM                                            All      채원
# 481   LE SSERAFIM                                            All     사쿠라
# 482   LE SSERAFIM                                            All      가람
# 483   LE SSERAFIM                                            All     카즈하
# 484   LE SSERAFIM                                            All     허윤진
# 485   LE SSERAFIM                                            All      은채
# 486   LE SSERAFIM                                            All     세라핌
# 487   LE SSERAFIM                                            All      안티
# 488   LE SSERAFIM                                            All      오버
# 489   LE SSERAFIM                                            All      워치
# 490   LE SSERAFIM                                            All      피어
# 491   LE SSERAFIM                                            All     윤진이
# 492   LE SSERAFIM                                            All      악플
# 493   LE SSERAFIM                                            All      천지
# 494   LE SSERAFIM                                            All     가람이
# 495   LE SSERAFIM                                            All      윤진
# 496   LE SSERAFIM                                            All    크레이지
# 497   LE SSERAFIM                                            All      악마
# 498   LE SSERAFIM                                            All      이지
# 499   LE SSERAFIM                                            All      학폭
# 500   LE SSERAFIM                                            All      교회
# 501   LE SSERAFIM                                            All      연습
# 502   LE SSERAFIM                                            All      친일
# 503   LE SSERAFIM                                            All    언포기븐
# 504   LE SSERAFIM                                            All     코첼라
# 505   LE SSERAFIM                                            All      탈퇴
# 506   LE SSERAFIM                                            All      즈하
# 507   LE SSERAFIM                                            All      하이
# 508   LE SSERAFIM                                            All     이미지
# 509   LE SSERAFIM                                            All     콜라보
# 510       tripleS                                            All     트리플
# 511       tripleS                                            All      에스
# 512       tripleS                                            All      유연
# 513       tripleS                                            All      병기
# 514       tripleS                                            All      포기
# 515       tripleS                                            All     김유연
# 516       tripleS                                            All      위로
# 517       tripleS                                            All      청춘
# 518       tripleS                                            All      유닛
# 519       tripleS                                            All      크아
# 520       tripleS                                            All      유빈
# 521       tripleS                                            All      라이
# 522       tripleS                                            All      소현
# 523       tripleS                                            All      공감
# 524       tripleS                                            All      걸스
# 525       tripleS                                            All      서연
# 526       tripleS                                            All    크리스탈
# 527       tripleS                                            All      감동
# 528       tripleS                                            All      신위
# 529       tripleS                                            All      달소
# 530       tripleS                                            All      체리
# 531       tripleS                                            All      학폭
# 532       tripleS                                            All      천공
# 533       tripleS                                            All      본인
# 534       tripleS                                            All      분량
# 535       tripleS                                            All      이름
# 536       tripleS                                            All      눈물
# 537       tripleS                                            All      활동
# 538       tripleS                                            All     글로벌
# 539       tripleS                                            All     타이틀
# 540         aespa                                            All      광야
# 541         aespa                                            All      스엠
# 542         aespa                                            All      스파
# 543         aespa                                            All      파가
# 544         aespa                                            All      레벨
# 545         aespa                                            All    블랙맘바
# 546         aespa                                            All     넥스트
# 547         aespa                                            All     유영진
# 548         aespa                                            All    아마겟돈
# 549         aespa                                            All    수퍼노바
# 550         aespa                                            All    슈퍼노바
# 551         aespa                                            All      마이
# 552         aespa                                            All     에스엠
# 553         aespa                                            All     세계관
# 554         aespa                                            All      예술
# 555         aespa                                            All     나비스
# 556         aespa                                            All      쇠맛
# 557         aespa                                            All      파의
# 558         aespa                                            All     드라마
# 559         aespa                                            All      달성
# 560         aespa                                            All      미래
# 561         aespa                                            All     스파이
# 562         aespa                                            All      레드
# 563         aespa                                            All      독보
# 564         aespa                                            All      냄새
# 565         aespa                                            All      벨벳
# 566         aespa                                            All     이수만
# 567         aespa                                            All      소화
# 568         aespa                                            All    소녀시대
# 569         aespa                                            All      겨울
# 570         STAYC                                            All      테이
# 571         STAYC                                            All      수민
# 572         STAYC                                            All     색안경
# 573         STAYC                                            All    테디베어
# 574         STAYC                                            All      에이
# 575         STAYC                                            All      스윗
# 576         STAYC                                            All      돌파
# 577         STAYC                                            All     런투유
# 578         STAYC                                            All     박시은
# 579         STAYC                                            All      정규
# 580         STAYC                                            All      헤메
# 581         STAYC                                            All     블아필
# 582         STAYC                                            All      자윤
# 583         STAYC                                            All      상큼
# 584         STAYC                                            All     심자윤
# 585         STAYC                                            All     윤세은
# 586         STAYC                                            All      예은
# 587         STAYC                                            All      입덕
# 588         STAYC                                            All     홍진경
# 589         STAYC                                            All      다운
# 590         STAYC                                            All     배수민
# 591         STAYC                                            All      입시
# 592         STAYC                                            All      숙대
# 593         STAYC                                            All      배드
# 594         STAYC                                            All      제이
# 595         STAYC                                            All      포함
# 596         STAYC                                            All      코디
# 597         STAYC                                            All      합산
# 598         STAYC                                            All      애기
# 599         STAYC                                            All      치아
# 600         NMIXX                           별별별 (See that)      걸스
# 601         NMIXX                           별별별 (See that)     아일릿
# 602         NMIXX                           별별별 (See that)    수퍼노바
# 603         NMIXX                           별별별 (See that)     윤진이
# 604         NMIXX                           별별별 (See that)     지원이
# 605         NMIXX                           별별별 (See that)      순이
# 606         NMIXX                           별별별 (See that)      보컬
# 607         NMIXX                           별별별 (See that)      활동
# 608         NMIXX                           별별별 (See that)      방송
# 609         NMIXX                           별별별 (See that)      수고
# 610         NMIXX                                           DASH      아무
# 611         NMIXX                                           DASH      천지
# 612         NMIXX                                           DASH      희진
# 613         NMIXX                                           DASH      미래
# 614         NMIXX                                           DASH      한번
# 615         NMIXX                                           DASH      천공
# 616         NMIXX                                           DASH     하나님
# 617         NMIXX                                           DASH     타이틀
# 618         NMIXX                                           DASH      파티
# 619         NMIXX                                           DASH      이지
# 620         NMIXX                                    蜚蜚 (FEIFEI)      홍콩
# 621         NMIXX                                    蜚蜚 (FEIFEI)     거슬러
# 1404        aespa                                          Drama     프시케
# 1405        aespa                                          Drama     샤이니
# 1406        aespa                                          Drama      토끼
# 1407        aespa                                          Drama      시절
# 1408        aespa                                          Drama    르세라핌
# 1409        aespa                                          Drama     미성년
# 1410        aespa                                   Live My Life      채현
# 1411        aespa                                   Live My Life      신도
# 1412        aespa                                   Live My Life     일레븐
# 1413        aespa                                   Live My Life      정리
# 1414        aespa                                   Live My Life      은채
# 1415        aespa                                   Live My Life      가즈
# 1416        aespa                                   Live My Life      냄새
# 1417        aespa                                   Live My Life     마피아
# 1418        aespa                                   Live My Life      소녀
# 1419        aespa                                   Live My Life     박시은
# 1420        aespa                                    Black Mamba      마미
# 1421        aespa                                    Black Mamba      맘바
# 1422        aespa                                    Black Mamba      나야
# 1423        aespa                                    Black Mamba     유지민
# 1424        aespa                                    Black Mamba      보아
# 1425        aespa                                    Black Mamba      그림
# 1426        aespa                                    Black Mamba      사과
# 1427        aespa                                    Black Mamba      표정
# 1428        aespa                                    Black Mamba      기억
# 1429        aespa                                    Black Mamba      절대
# 1430     NewJeans            'Cool With You' & 'Get Up' (side B)     양조위
# 1431     NewJeans            'Cool With You' & 'Get Up' (side B)      정호
# 1432     NewJeans            'Cool With You' & 'Get Up' (side B)     에로스
# 1433     NewJeans            'Cool With You' & 'Get Up' (side B)      사이
# 1434     NewJeans            'Cool With You' & 'Get Up' (side B)     이채령
# 1435     NewJeans            'Cool With You' & 'Get Up' (side B)      사과
# 1436     NewJeans            'Cool With You' & 'Get Up' (side B)      실망
# 1437     NewJeans            'Cool With You' & 'Get Up' (side B)      뉴진
# 1438     NewJeans            'Cool With You' & 'Get Up' (side B)      본인
# 1439     NewJeans            'Cool With You' & 'Get Up' (side B)      토끼
# 1440     NewJeans                       'Cool With You' (side A)      연기
# 1441     NewJeans                       'Cool With You' (side A)      디토
# 1442     NewJeans                       'Cool With You' (side A)      자체
# 1443     NewJeans                       'Cool With You' (side A)     대혁명
# 1444     NewJeans                       'Cool With You' (side A)      진자
# 1445     NewJeans                       'Cool With You' (side A)     최유진
# 1446     NewJeans                       'Cool With You' (side A)      시오
# 1447     NewJeans                       'Cool With You' (side A)      소송
# 1448     NewJeans                       'Cool With You' (side A)      반대
# 1449     NewJeans                       'Cool With You' (side A)      애기
# 1450     NewJeans                                      Super Shy      독자
# 1451     NewJeans                                      Super Shy     자전거
# 1452     NewJeans                                      Super Shy      건물
# 1453     NewJeans                                      Super Shy      색감
# 1454     NewJeans                                      Super Shy    포르투갈
# 1455     NewJeans                                      Super Shy      겟업
# 1456     NewJeans                                      Super Shy      창문
# 1457     NewJeans                                      Super Shy    에어로빅
# 1458     NewJeans                                      Super Shy     일레븐
# 1459     NewJeans                                      Super Shy      충치
# 1460     NewJeans                                      New Jeans   파워퍼프걸
# 1461     NewJeans                                      New Jeans     고양이
# 1462     NewJeans                                      New Jeans     리스닝
# 1463     NewJeans                                      New Jeans      공주
# 1464     NewJeans                                      New Jeans     정신병
# 1465     NewJeans                                      New Jeans      지구
# 1466     NewJeans                                      New Jeans      폭죽
# 1467     NewJeans                                      New Jeans      입덕
# 1468     NewJeans                                      New Jeans      제이
# 1469     NewJeans                                      New Jeans      순이
# 1470     NewJeans                                            OMG      재단
# 1471     NewJeans                                            OMG      시리
# 1472     NewJeans                                            OMG     화장품
# 1473     NewJeans                                            OMG    주주총회
# 1474     NewJeans                                            OMG     신도림
# 1475     NewJeans                                            OMG     대학교
# 1476     NewJeans                                            OMG      일지
# 1477     NewJeans                                            OMG     식인종
# 1478     NewJeans                                            OMG      졸업
# 1479     NewJeans                                            OMG     이승헌
# 1480     NewJeans                                 Ditto (side B)      사슴
# 1481     NewJeans                                 Ditto (side B)    학창시절
# 1482     NewJeans                                 Ditto (side B)     캠코더
# 1483     NewJeans                                 Ditto (side B)      그때
# 1484     NewJeans                                 Ditto (side B)     박지후
# 1485     NewJeans                                 Ditto (side B)      유괴
# 1486     NewJeans                                 Ditto (side B)     곰인형
# 1487     NewJeans                                 Ditto (side B)      교복
# 1488     NewJeans                                 Ditto (side B)     사이드
# 1489     NewJeans                                 Ditto (side B)      절망
# 1490     NewJeans                                 Ditto (side A)    여고괴담
# 1491     NewJeans                                 Ditto (side A)     최현욱
# 1492     NewJeans                                 Ditto (side A)      학생
# 1493     NewJeans                                 Ditto (side A)    고등학교
# 1494     NewJeans                                 Ditto (side A)      귀신
# 1495     NewJeans                                 Ditto (side A)      연출
# 1496     NewJeans                                 Ditto (side A)      나라
# 1497     NewJeans                                 Ditto (side A)     아이즈
# 1498     NewJeans                                 Ditto (side A)      목차
# 1499     NewJeans                                 Ditto (side A)      마미
# 1500          IVE                                     Either Way      하트
# 1501          IVE                                     Either Way      번개
# 1502          IVE                                     Either Way      라서
# 1503          IVE                                     Either Way      안티
# 1504          IVE                                     Either Way      중독
# 1505          IVE                                     Either Way      가을
# 1506          IVE                                     Either Way      음악
# 1507          IVE                                     Either Way     심자윤
# 1508          IVE                                     Either Way     실시간
# 1509          IVE                                     Either Way      버블
# 1510          IVE                                         Kitsch      실화
# 1511          IVE                                         Kitsch    메인보컬
# 1512          IVE                                         Kitsch      저음
# 1513          IVE                                         Kitsch      메보
# 1514          IVE                                         Kitsch      염색
# 1515          IVE                                         Kitsch   슈퍼내추럴
# 1516          IVE                                         Kitsch      남친
# 1517          IVE                                         Kitsch      기대
# 1518          IVE                                         Kitsch     분위기
# 1519          IVE                                         Kitsch      위로
# 1520          IVE                                         Baddie      배디
# 1521          IVE                                         Baddie      오리
# 1522          IVE                                         Baddie      여름
# 1523          IVE                                         Baddie      버전
# 1524          IVE                                         Baddie     타이틀
# 1525          IVE                                         Baddie      무슨
# 1526          IVE                                         Baddie      중소
# 1527          IVE                                         Baddie      보임
# 1528          IVE                                         Baddie     케이팝
# 1529          IVE                                         Baddie      사용
# 1530          IVE                                       Accendio      마법
# 1531          IVE                                       Accendio      요술
# 1532          IVE                                       Accendio     스토리
# 1533          IVE                                       Accendio      주문
# 1534          IVE                                       Accendio     주인공
# 1535          IVE                                       Accendio      변신
# 1536          IVE                                       Accendio     냉장고
# 1537          IVE                                       Accendio      액션
# 1538          IVE                                       Accendio      초딩
# 1539          IVE                                       Accendio      손끝
# 1540          IVE                                 Off The Record     옾더레
# 1541          IVE                                 Off The Record  오프더레코드
# 1542          IVE                                 Off The Record      안경
# 1543          IVE                                 Off The Record      지니
# 1544          IVE                                 Off The Record      찬양
# 1545          IVE                                 Off The Record      신경
# 1546          IVE                                 Off The Record      이브
# 1547          IVE                                 Off The Record      한글
# 1548          IVE                                 Off The Record      외국
# 1549          IVE                                 Off The Record      바람
# 1550          IVE                                    해야 (HEYA)     공산당
# 1551          IVE                                    해야 (HEYA)      경의
# 1552          IVE                                    해야 (HEYA)    전통문화
# 1553          IVE                                    해야 (HEYA)      상운
# 1554          IVE                                    해야 (HEYA)      산수
# 1555          IVE                                    해야 (HEYA)      한눈
# 1556          IVE                                    해야 (HEYA)      가득
# 1557          IVE                                    해야 (HEYA)      미술
# 1558          IVE                                    해야 (HEYA)      주장
# 1559          IVE                                    해야 (HEYA)     시진핑
# 1560          IVE                     All Night (Feat. Saweetie)     월요일
# 1561          IVE                     All Night (Feat. Saweetie)      눈물
# 1562          IVE                     All Night (Feat. Saweetie)      건가
# 1563          IVE                     All Night (Feat. Saweetie)    어트랙트
# 1564          IVE                     All Night (Feat. Saweetie)      정의
# 1565          IVE                     All Night (Feat. Saweetie)      활동
# 1566          IVE                     All Night (Feat. Saweetie)      기록
# 1567          IVE                     All Night (Feat. Saweetie)      단어
# 1568          IVE                     All Night (Feat. Saweetie)      희진
# 1569          IVE                     All Night (Feat. Saweetie)      이름
# 1570  LE SSERAFIM                                     Impurities      샤넬
# 1571  LE SSERAFIM                                     Impurities     제대로
# 1572  LE SSERAFIM                                     Impurities    신성모독
# 1573  LE SSERAFIM                                     Impurities     소속사
# 1574  LE SSERAFIM                                     Impurities      관심
# 1575  LE SSERAFIM                                     Impurities     유튜브
# 1576  LE SSERAFIM                                     Impurities    수퍼노바
# 1577  LE SSERAFIM                                     Impurities     차라리
# 1578  LE SSERAFIM                                     Impurities      아무
# 1579  LE SSERAFIM                                     Impurities      건가
# 1580        STAYC                       No quoted content found.      매번
# 1581        STAYC                       No quoted content found.     사운드
# 1582        STAYC                       No quoted content found.     가사도
# 1583        STAYC                       No quoted content found.     무조건
# 1584        STAYC                       No quoted content found.    뮤직뱅크
# 1585        STAYC                       No quoted content found.      이노
# 1586        STAYC                       No quoted content found.      심장
# 1587        STAYC                       No quoted content found.      명곡
# 1588        STAYC                       No quoted content found.      준비
# 1589        STAYC                       No quoted content found.     이채영

# %%
keyword_list.to_csv('keyword_list_before_cleaning.csv')

# %%
# 특정 단어가 포함된 댓글 조회하기

def keyword_search(hot_word, dataframe=sample_df, likes=False, n_comments=10, random_state=42):

    # 데이터 프레임에서 hot_word를 포함하고 있는 행 필터링
    filtered_df = dataframe[dataframe['comment'].str.contains(hot_word, na=False)]
    print(len(filtered_df))

    # 좋아요 기준 정렬
    if likes:
        filtered_df = filtered_df[['comment','word_list','likes']].sort_values(by='likes', ascending=False)
        result = filtered_df[:n_comments]
    
    # 랜덤으로 조회
    else :
        result = filtered_df[['comment','word_list','likes']].sample(n = n_comments, random_state=42)
    
    return result

# %%
keyword_search('레벨', likes=True)
# Out:
# 1076
#                                                   comment  \
# 309153        뉴진스는 논란이고 뭐고 그냥 행복했으면 좋겠다… 그냥 뉴진스는 어나더레벨임..
# 330901  그냥 매력이 넘사잖아... 방시혁이 키우는 애덜하고 컨셉이 뭐 비슷하고뭐고간에 애들...
# 418549  예전부터 느꼈지만 MV는 SM이 할리우드급 아니 미국 MV보다 잘 뽑음.. 이번 노...
# 380216  와 이제야 봤는데 블랙맘바 넥스트레벨 세비지랑 컨셉이 엄청 다른데 엄청 익숙하지않으...
# 390541  넥스트 레벨때도 처음에는 먼가 당황스러웠는데 나도 모르게 중독되어 버렸지...이것도...
# 371436  2억 조회수 갑시다이야~~~~~~~~~~~ NEXT LEVEL 2억 조회수 닿을때 ...
# 391872          넥스트 레벨 이해했다고 노래 난이도 떡상시키네.... 반복 학습하겠습니다.
# 422848  ses 드컴투 + 소시 갤럭시 슈퍼노바 플라워파워 + 에펙 피노키오 일렉트릭쇼크 +...
# 391145  뭔가 느낌이 저번 넥스트 레벨처럼 초반에는 난해하나 나중에는 대박치는 노래일듯..넥...
# 393613  넥스트 레벨보다 더 에스엠피 스러운 곡이 나왔네요 ㅎㅎ 게다가 뭔가 다들 실력이 더...
#
#                                                 word_list  likes
# 309153                                 [어나더, 뉴진스, 레벨, 논란]   3929
# 330901                     [뉴진스, 컨셉, 시혁, 고간, 방시혁, 매력, 레벨]   2135
# 418549        [이후, 미국, 지향, 펑키, 예전, 노래, 할리우드, 미래, 넥스트, 레벨]    987
# 380216                      [블랙맘바, 이제야, 컨셉, 세비지, 넥스트, 레벨]    858
# 390541                              [중독, 당황, 스엠, 넥스트, 레벨]    797
# 371436                         [조회수, 쵝오, 수고, 마이, 넥스트, 레벨]    569
# 391872                     [이해, 난이도, 학습, 노래, 반복, 넥스트, 레벨]    561
# 422848  [에스파, 드컴투, 파워, 피노키오, 트릭, 쇼크, 파의, 정통, 플라워, 소시, ...    547
# 391145          [초반, 박치, 나중, 넥레, 킬링, 파트, 노래, 저번, 넥스트, 레벨]    449
# 393613           [실력, 에스파, 감탄, 파이팅, 감상, 넥스트, 게다가, 레벨, 엠피]    390

# %%
group = 'NMIXX'
hot_word = '짱플러'
sample_df[(sample_df['Group'] == group) & (sample_df['comment'].str.contains(hot_word, na=False))][['comment','word_list','likes']][:10]
# Out:
# Empty DataFrame
# Columns: [comment, word_list, likes]
# Index: []

# %%
title = '蜚蜚 (FEIFEI)'
hot_word = '스윗'
sample_df[(sample_df['Title'] == title) & (sample_df['comment'].str.contains(hot_word, na=False))][['comment','word_list','likes']][:10]
# Out:
# Empty DataFrame
# Columns: [comment, word_list, likes]
# Index: []
