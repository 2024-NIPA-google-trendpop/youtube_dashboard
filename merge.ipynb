# %%
import pandas as pd

df1 = pd.read_csv('processing.csv')

# %%
df2 = pd.read_csv('processing2.csv')

# %%
merged_df = pd.concat([df1, df2])

# %%
merged_df
# Out:
#         Group                     Title  Unnamed: 0 comment_type  \
# 0       NMIXX      별별별 (See that)          21         node
# 1       NMIXX      별별별 (See that)          32         node
# 2       NMIXX      별별별 (See that)          43         node
# 3       NMIXX      별별별 (See that)          69         node
# 4       NMIXX      별별별 (See that)          71         node
# ...       ...                       ...         ...          ...
# 147055  STAYC  No quoted content found.        2581         node
# 147056  STAYC  No quoted content found.        2590         node
# 147057  STAYC  No quoted content found.        2591         node
# 147058  STAYC  No quoted content found.        2592         node
# 147059  STAYC  No quoted content found.        2595         node
#
#                     comment_id_key parent_id_key  \
# 0       UgyiK-QaarUUumBCjUJ4AaABAg           NaN
# 1       Ugw_6c4z7iSqIjzfgZB4AaABAg           NaN
# ...

# %%
folder_path = '/Users/jaesolshin/Documents/GitHub/trendpop/'
file_path = folder_path + 'KPOP_comments_merged_preprocessed.csv'
comments_df = pd.read_csv(file_path)

# %%
comments_df.shape
# Out:
# (648060, 10)

# %%
merged_df.to_csv('KPOP_comments_merged_preprocessed_with_nouns.csv')
