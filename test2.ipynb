# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd
import time


# 다운로드 폴더 경로 설정
download_dir = "/Users/jaesolshin/Library/CloudStorage/GoogleDrive-ysys143@gmail.com/내 드라이브/2024-2/Google ML Bootcamp2024/"

# Chrome 옵션 설정
chrome_options = Options()
#chrome_options.add_argument('--headless')  # 브라우저 창을 띄우지 않음
chrome_options.add_experimental_option('prefs', {
    "download.default_directory": download_dir,  # 다운로드 경로 설정
})

# 크롬 드라이버 서비스 설정 및 실행
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options = chrome_options)

# URL 열기
url = 'https://www.youtube.com/'
driver.get(url)

# 대기 설정
driver.implicitly_wait(5)  # 최대 10초 대기
driver.find_element(By.CSS_SELECTOR, 'input#search').send_keys('르세라핌')  # 원하는 키워드로 변경
driver.implicitly_wait(1) 
driver.find_element(By.CSS_SELECTOR, 'button#search-icon-legacy').click()  # 검색 버튼 클릭
driver.implicitly_wait(1) 
driver.find_element(By.CSS_SELECTOR, 'button#search-icon-legacy').click()  # 검색 버튼 클릭
driver.implicitly_wait(1) 
driver.find_elements(By.CSS_SELECTOR, '#thumbnail > yt-image > img:nth-child(1)')[0].click()

# 작업 후 드라이버 종료
#driver.quit()

# %%
for i in range(100):
    driver.execute_script("window.scrollBy(0, 10000);") # 1000픽셀 아래로 스크롤
    time.sleep(1)

# %%
# 댓글과 작성자 ID 요소 가져오기
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content #content-text")
author_elements = driver.find_elements(By.CSS_SELECTOR, "#header-author #author-text")

# 댓글과 작성자 ID 추출
comments_data = []
for comment, author in zip(comment_elements, author_elements):
    comment_text = comment.text
    author_name = author.text.strip()
    comments_data.append({"author": author_name, "comment": comment_text})

# 수집한 댓글과 ID 출력
for i, data in enumerate(comments_data):
    print(f"작성자: {data['author']}\n")
    print(f"댓글 {i + 1}: {data['comment']}")
# Out:
# 댓글 1: can we talk about how AWESOME it is to have the juicy couture crew in the mv and also have them credited? this is house vogue ballroom, this is black culture. i'm so proud! my fimmies!
# 작성자: @stank0nia
#
# 댓글 2: I’m sure at the time they said, ”All the girls are girling girling” & “Act like an angel and dress like crazy” will be their iconic part.
# 작성자: @Hannainyourheart
#
# 댓글 3: THE VOGUEING WAS LITERALLY CRAZY THEY ATEEEE
# 작성자: @hongteezer
#
# 댓글 4: I CANT STOP WATCHING THIS MV HELP MEE
# 작성자: @en-xo-hypen
#
# 댓글 5: OMG RAPPER YUNJIN?! RAPPER CHAEWON?? RAPPER SAKURA?? RAPPER
# KAZUHA?? RAPPER EUNCHAE?? IM IN LOVE OMGGG
# 작성자: @123rawr8
#
# 댓글 6: Two weeks on the HOT 100 BILLBOARD this is Otaku Bestie
# 작성자: @aydozEKpop
#
# 댓글 7: I just wanna say, a lot of people were comparing their concept photos, teasers and snippets - just their concept as a whole to Red Velvet, but this song was sooo Le Sserafim style. Like they did the "weird" concept and ATE it up in THEIR own way. They did amazing!!
# 작성자: @sabii_iii
#
# 댓글 8: STREAMING!!! LETS STREAM PERFECT NIGHT!! PN SOTY!
# 작성자: @Naemygfsunghoon
#
# 댓글 9: That voguing is really CRAZY on this danceable song!!
# Sakura's excellence, Chaewon's brilliance, Yunjin's confidence, Kazuha's stylish, Eunchae's versatility LE SSERAFIM LITERALLY SLAYING
# 작성자: @dalknb4268
#
# 댓글 10: This line when they said " All the girls are girling girling " will Forever be Iconic.
# 작성자: @AyeshaKhan-l4c4y
#
# 댓글 11: Let’s go 70 million
# 작성자: @chapspoduri5518
#
# 댓글 12: Chaewon’s “pikachu”
# Sakura’s “Otaku bestie”
# Eunchae’s “deep voice “
# Kazuha’s “rap part”
# Yunjin’s “acting&blue hair”
# LE SSERAFIM IS ICONIC!
# 작성자: @STRAWMARII_offical
#
# 댓글 13: Sakura's "I'm an otaku bestie" and Eunchae's rap part are my favourite thing about this songIdk why but they are so addictive to listen
# 작성자: @Bangtanbell.7
#
# 댓글 14: "I'M AN OTAKU BESTIE"  Sakura always iconic!!!
# 작성자: @edybellizia2274
#
# 댓글 15: I LOVE Eunchae's part it's crazy
# 작성자: @Sarah_Pixie
#
# 댓글 16: Yunjin saying le seraffim will never get old
# 작성자: @Jungkooks_night_apple1
#
# 댓글 17: The "pikachu" of Chaewon The "Otaku bestie" of Sakura The "deep voice" of Eunchae The "rap part" of Kazuha The "acting&blue hair" of Yunjin LE SSERAFIM IS REMARKABLE!
# 작성자: @TEMPOREMIX
#
# 댓글 18: The choreo, the face, the duck walk, the vouge omg they hit all the check marks. Crazy how K-pop and western music benefit each other.
# 작성자: @Abiel23-x
#
# 댓글 19: CRAZY 3RD WIN GIRLSS
# 작성자: @nurmahwati4461
#
# 댓글 20: The song!!? The mv!!? The concept!!?  The dancers!!? The vocals!!? The visuals!!? Everything is perfect le sserafim never disappoint.
# 작성자: @croserroblox6981
#
# 댓글 21: Yunjin saying LE SSERAFIM will forever be iconic
# 작성자: @by678smca
#
# 댓글 22: ‪1:36‬ Eunchae surprised me a lot in this part. You are amazing, Eunchae. Keep going. I support you forever, my dear little one
# 작성자: @Launa-od6kd
#
# 댓글 23: IM ALREADY OBSESSED WITH THIS SONG ITS SO CATCHY OMGG🩷
# 작성자: @rosasanchez7761
#
# 댓글 24: I was NOT prepared for Le Sera to do a vouge style song, I'm really happy that they had black backup dancers involved in this
# 작성자: @mamobee
#
# 댓글 25: I cant stop singing "All the girls are girling girling" and "Act like an angel and dress like crazy"!!!! They alllllll slayyyyyyyyed!!!
# 작성자:
#
# 댓글 26: DADADADADADADADA ACTING LIKE AN ANGEL & DRESS LIKE CRAZY
# 작성자: @lisa-lx5pi
#
# 댓글 27: Fearnots are doing a great job! I think we are crazier than the girls. Let’s go crazy together and fly high
# 작성자: @Figo_Amigo
#
# 댓글 28: Saying "All the girls are girling, girling", "I'm an otaku bestie" and "Act like an Angel dress like crazy" has become a part of my routine
# 작성자: @Flamoong
#
# 댓글 29: Idk why but it's giving 'awesome screen, awesome camera, long lasting battery life'
# 작성자: @stay-as-stay
#
# 댓글 30: An ARMY here supporting Le Sserafim! Love you girls!
# 작성자: @beluuzz
#
# 댓글 31: LEGENDARY
# 작성자: @LUNY498
#
# 댓글 32: Sakura's 'I'm an otaku bestie' part is really addictive
# 작성자: @BeYourself05
#
# 댓글 33: Eunchaes "make me super crazy" IS SO FRICKING ADORABLE i cant  And dont get me started on chaewons entry pikachu! they total ate this comback up! I cant wait for more
# 작성자: @Skz_Kpop_Addicts
#
# 댓글 34: ルセラ最近知り始めたんですが、ウンチェちゃんが好きです！いつもニコニコしていて月曜１限も頑張れてます！アルバムも過去の購入してしまいました。本当に推しが出来るってこういう気持ちなんですね。。。。。。
# 작성자: @nancy-qs3np
#
# 댓글 35: Omg the dance and this song is so crazy I love this song
# 작성자: @taekookloving
#
# 댓글 36: That line when they said ”All the girls are girling girling” will FOREVER be iconic.
# 작성자: @anthonydiaz6091
#
# 댓글 37: As a black girl I gotta say HOW AMAZING IT WAS TO SEE BACKUP DANCERS LIKE THIS. A short dream i had was being a kpop backup dancer. But i always doubted it for the color of my skin. So i hope they continue this in kpop generally. Let’s not make this another controversies toward our amazing girls WHO ATE SO MUCH LIKE THE SONG IS KINDA THE DEFINITION OF ATE. Thank you so much for incorporating this. This truly makes me happy. I WILL FOREVER SUPORT LE SSERAFIM! KEEP GOING <333
# 작성자: @Hanniiejisungplussooobin
#
# 댓글 38: absolutely gagged. love seeing them with the black kings and queens. the girls, the dance, and the iconic line "act like an angel and dress like crazy" ATTEEE
# 작성자: @itsmelennaaa
#
# 댓글 39: One thing about being a fearnot is the fact that you never know what concept you’ll get next. LeSserafim’s so versatile! I’m never bored 🫶
# 작성자: @-PublicNuisance-
#
# 댓글 40: Juicy Coutour as backup dancers is the best thing HYBE has done this year. Im so happy when I see black dancers who look like me in kpop
# 작성자: @Heyguhh
#
# 댓글 41: THE CAMP OF IT ALL, THIS WAS MADE FOR ME. IT WAS MADE FOR THE GIRLS AND THE GAYS. Ahh, i love being a lesserafim stan.
# 작성자: @hadrianhexe9603
#
# 댓글 42: "I'm an otaku bestie" SAKURA ATEEEE
# 작성자: @Onebillon
#
# 댓글 43: KAZUHA's pronunciation is so addictive All the girls are Girling Girling
# 작성자: @usee-ov3uo
#
# 댓글 44: Now THIS is kpop. They werent afraid to be different, this concept is amazing!!
# 작성자: @Yourfav_cheri4
#
# 댓글 45: Мы все крейзи от вашего клипа
# 작성자: @Человек-у7х8е
#
# 댓글 46: Can we actually appreciate them for making this addictive song, LETS GO SAKURA, CHAEWON, EUNCHAE, YUNJIN, KAZUHAAA!!!!
# 작성자: @yammyxox8290
#
# 댓글 47: Congratulations on winning first place on M Countdown and Push Performance of the year on the VMAs today!!!
# 작성자: @sakura190
#
# 댓글 48: Ok but I am LOVING juicy crew in this. So rare to see kpop (or any music really) acknowledging their inspiration from poc and queer groups. I'm fully obsessed
# 작성자: @carleighlaxton9233
#
# 댓글 49: ALL THE GURLS ARE GURLLING GURLLING
# 작성자: @keliciaiskpop
#
# 댓글 50: Sakura doing the duckwalk while she is saying Otaku bestie. She is serving!
# 작성자: @alejandrocorchero2797
#
# 댓글 51: ayo??? Chaewon absolutely devoured this! Also please let Sakura rap more often she did amazing and I think this concept fits her so well in general! All the girls were incredible but Chaewon and Sakura were such highlights to me
# 작성자: @dinojk8034
#
# 댓글 52: Yunjin REALLY flexing her New York background with this comeback concept, damn.
# 작성자: @isoldemaisol3709
#
# 댓글 53: 주말이다 다들 뮤비 보고 즐거운 주말 보내세요
# 작성자: @asdfghjkl12345-u
#
# 댓글 54: My mind couldn't comprehend anything ,,,, the vocals were so amazing, Eunchae’s voice was amazing, Chaewon's voice was amazing, and Sakura, Kazuha, and Yunjin were also amazing,,,,, the MV was crazy in every sense of the word
# 작성자: @Roaa-gj6pb
#
# 댓글 55: Cmon Le sserafim is the craziest kpop group..so creative..Rock I'm fearless
# 작성자: @MD_12344
#
# 댓글 56: Le sserafim will never be the untalented group yall want them to be, this is another banger
# 작성자: @melissanowak6248
#
# 댓글 57: LESSERAFIM is the best
# 작성자: @banamalimandal4750
#
# 댓글 58: THIER visuals getting more prettier and prettier
# 작성자: @STRAWMARII_offical
#
# 댓글 59: Chaewon’s “pikachu”
# Sakura’s “Otaku bestie”
# Eunchae’s “deep voice “
# Kazuha’s “rap part”
# Yunjin’s “acting&blue hair”
# LE SSERAFIM IS ICONIC!
# 작성자: @l9개꼴리는야뎡-k6x
#
# 댓글 60: "All the girls are girling girling, "Act like an angel dress like crazy" and "Im an otaku bestie" I already know that those three lines will forever be iconic!!
# 작성자: @multiFANNNNN
#
# 댓글 61: Me encanta lesserafim
# 작성자: @dorissophiavelasquezramos4305
#
# 댓글 62: i'm an otaku bestie️
# I never hated on le sserafim because i always knew they're talented. LOVE FROM POLAND!!
# 작성자: @Hanjisungnocap
#
# 댓글 63: "I'M YOUR OTAKU BESTIE" and "all the girls are girling, girling" will forever be stuck in my head. The girls ate down on this one, I fear. The representation, the vogueing, face and energy iconic. I was a little apprehensive to see how this particular group executed the phonk genre in KPOP, but I must say they delivered. Defintely will be tuning into this comeback!
# 작성자: @binxthee_blackcat
#
# 댓글 64: This how kpop should feel like now. Something WEIRD, something NEW, something ADDICTIVE and VIBING.
# 작성자: @msj0015
#
# 댓글 65: LET'S GO M COUNTDOWN TRIPLE CROWN!
# 작성자: @asep1898
#
# 댓글 66: Body is BODYING. Not because they’re thin but because they’re toned and look healthy which is so rare with female kpop idols!
# 2:07 like are you kidding me?????
# 작성자: @Tnagigog
#
# 댓글 67: "I'm an otaku, bestie" ARGHHHH ITS ONE OF THE BEST LINES IN THE WHOLE M/V!!
# 작성자: @juaubert_
#
# 댓글 68: 0:16 this move is stuck in my mind
# 작성자: @Fearnaurt
#
# 댓글 69: The song is addiction
# 작성자: @WaadYounis
#
# 댓글 70: "All the girls are girling girling, "Act like an angel dress like crazy" I already know that those two lines will forever be iconic.
# 작성자: @Meowz_xx
#
# 댓글 71: “I’m an otaku, bestie” ARGHHHHH ITS ONE OF THE BEST LINES IN THE WHOLE M/V!!!
# 작성자: @ShyunciiReo
#
# 댓글 72: Happy to see Black dancers/artists featured with the heavy voguing and ballroom dance choreography ️
# 작성자: @HaowardTheGreat
#
# 댓글 73: THIS IS THE BEST SONG I EVER HEARD
# 작성자: @Lilykate_21
#
# 댓글 74: the respect for voguing and african american culture goes crazy… lesserafim I never hated you️
# 작성자: @illitoutsold
#
# 댓글 75: finally they put Eunchae's unique voice to use! She ate the rap part
# 작성자: @BruByBeru
#
# 댓글 76: Congratulations LE SSERAFIM for winning ‘push performance of the year’ at this yearʼs VMAs
# 작성자: @sakura190
#
# 댓글 77: Act like an angel dress like crazy goes hard
# 작성자: @fatimafarheen-yw5qj
#
# 댓글 78: LE SERRAFIM in their rapper, voguing, and villain era, where are the haters at?
# 작성자: @carloscjabletes1103
#
# 댓글 79: Omfg the respect they have for Vogue is so beautiful. And seeing my community in the video makes me so happy and proud
# 작성자: @TreatzVtuber
#
# 댓글 80: WHY DOES LE SSERAFIM KEEP SURPRISING US??? THEY ALWAYS ATE THEIR COMEBACK??? SERIOUSLY???
# 작성자: @riyuhnnnn
#
# 댓글 81: Back in the days 미침에 미치지 못했던 me
# →→→→
# 더이상 내 끌림 앞에 거짓 증언은 않지
# ←←←←
# 작성자: @skyhigh5955
#
# 댓글 82: Sakura, Yunjin, Chaewon, Kazuha and Eunchae, they came back to ate the industry  FACTS
# 작성자: @Sunnji
#
# 댓글 83: Whenever I listen to "Lofi" music and try to work, I end up losing focus, but every time I listen to this, I suddenly have the energy to write a 4,000-word essay. Thank LE SSERAFIM
# 작성자: @jiroyoshida6617
#
# 댓글 84: I’ve been watching Kpop for over five years and this is the first music video I have seen when there were this many black people. Thank you Lesserafim for constantly raising the bar for the Genre
# 작성자: @prxncejae
#
# 댓글 85: I think this is my playlist now
# 작성자: @unananananananahehehaw
#
# 댓글 86: 0:37 I'm an Otaku Bestie can't get out of my head
# 작성자: @aiby_xy9614
#
# 댓글 87: Army here but really rooting for these girls this time. Hit big big this time
# 작성자: @mystry9393
#
# 댓글 88: 0:08 1:22 2:35 THE SHOULDER MOVEMENT WHEN THEY SAY "ALL THE GIRLS ARE GIRLING GIRLING" IS TOO GODDAMN MUCH ICONIC. I CAN'T HELP IT BUT I DO IT TOO WHILE THEY DO, 'CAUSE IT IS TOO FUN
# 작성자: @rbcsfreya
#
# 댓글 89: 7000再生までupuppupp
# 작성자: @ああ-w4j2r
#
# 댓글 90: something about Kazuha's diction/pronunciation scratches my BRAIN really well. I'M NOT EVEN COMPLAINING. slay girliesss
# 작성자: @lorriejane6704
#
# 댓글 91: The girls are EATING this comeback, this is SO CRAZY!
# 작성자: @SimonBreizh
#
# 댓글 92: KAZUHA THE WOMAN YOU ARE. this is your comeback just like Easy was your comeback
# 작성자: @zuleymacastillo3162
#
# 댓글 93: They overtook Antifragile with this release and I genuinely cannot speak. The RAP. THE CULTURAL REPRESENTATION. I'M JUST SO GAGGED. Thank you LSF FOR BEING WHO YOU ARE
# 작성자: @michael-qt8rg
#
# 댓글 94: Sakura’s otaku bestie was the best part omg
# 작성자: @ajay-s1j
#
# 댓글 95: Armys here to support Le Sserafim >>
#
# Fighting, gurlies
# 작성자: @Dildora_7
#
# 댓글 96: Le sserafim ATE every time they have a comeback
# 작성자: @lasanthihettiarachi7083
#
# 댓글 97: No amount of hate train will stop them from making hits!! Lesserafim the icons that you are
# 작성자: @bangtan4970
#
# 댓글 98: OTAKU BESTIE by Sakura will forever be iconic.
# 작성자: @bobrandellezaratedejesus3941
#
# 댓글 99: 2:45 thought something was wrong with my internet connection for a sec lol... lesserafim, y'all ate!!
# 작성자: @cloprk
#
# 댓글 100: 70M 100M we can do it fearnots
# 작성자: @lauritapereiradesouza9029
#
# 댓글 101: "I'M A OTAKU BESTIE" AND PHONK? LE SSERAFIM YOU ALL ATE
# 작성자: @JustAEvanescenceFan
#
# 댓글 102: Mother is mothering , queen is queening  act like an angel dress like CRAZY
# 작성자: @kissy_haneul
#
# 댓글 103: Chaewon's RAP.... y'all thats it no words to explain whole song is a bop .... Really missed songs like this so much which are just about fun ..brings back old 2nd gen vibes plus futuristic vibes too ..
# LESSERAFIM DELIVERING AS USUAL!
# 작성자: @hybelabels-jokesandcomedia5940
#
# 댓글 104: 65m 축하
# 작성자: @Lovewinsall0909
#
# 댓글 105: Congratulations LE SSERAFIM for winning the VMAs Push Performance of the year
# 작성자: @NEWWORLD98195
#
# 댓글 106: SAKURA TODAY GOT THE "OTAKU BESTIE" GOTCHA LIKE A SLAYING PART ️ so proud of her
# 작성자: @w00180
#
# 댓글 107: Whoever did the casting and choreo, THANK YOU for getting actual ballroom people and key stars and statements of both the kiki and major scene into this!
# 작성자: @adorkable7196
#
# 댓글 108: Eunchae's part is ON FIRE
# 작성자: @Angelynss
#
# 댓글 109: Kkura’s dance with the princess dress at the “I’m an otaku bestie” line has me crying
# 작성자: @certiee
#
# 댓글 110: Koreans find it boring? They don’t like this song? It's such a bop and the best Ssera song since 'Antifragile.' Well, at least the international fans love it!
# 작성자: @yoganime6942
#
# 댓글 111: 5 vocalists, 5 all rounders, 5 dancers, 5 aces, 5 rrapers, 5 members, 5 queens, 5 visuals, MV  beast
# 작성자: @hyhyqjqj33388
#
# 댓글 112: ACT LIKE AN ANGEL DRESS LIKE CRAZY
# 작성자: @K-gg_zone
#
# 댓글 113: OMG SAKURA’S “IM AN OTAKU BESTIE” ITS TYE BEST LINE OF THIS SONG IT HAS ME IN A OBSESSION WITH THAT LINE I CANT STOP SINGING IT
# 작성자: @Park_TN123
#
# 댓글 114: THE VERSES THAT ARE KINDA RAPPY IN CHEST VOICE ARE SO ADDICTIVEEE
# 작성자: @EthelJung-j5w
#
# 댓글 115: As a fearnot, a queer person and a black person I am soooooo proud of this song! This is such a great display of vogue and ballroom scene, and more than this the girls were incredible! I love love love this song! LE SSERAFIM served as always
# 작성자: @andrewskarlkimbembe6018
#
# 댓글 116: 初めは微妙な気がしたけどどんどん自分の中で上がってきた！！めっちゃ聞いちゃう笑笑
# 작성자: @Earth-kw7mp
#
# 댓글 117: Omg, kkura wrote that I'm an otaku bestie part. ICONIC
# 작성자: @Fearnaurt
#
# 댓글 118: "All the girls are charting charting"
#
# LE SSERAFIM debuts at #61 on Global Spotify with 2.03 million streams
# 작성자: @hasunjung7781
#
# 댓글 119: so glad the company did their research for voguing as well as including some of the actual people that are apart of the ballroom scene. YALL ATE WITH THIS ONE
# 작성자: @pseudoxen
#
# 댓글 120: CRAZY 노래가 너무 좋아요
# 작성자: @삐삐의채널
#
# 댓글 121: The line when they said " All the girls are girling girling " will forever be iconic
# 작성자: @mangogo21
#
# 댓글 122: I. CAN. NOT. GET. OVER. THE. VOGUEING!!!  It's magnificent! That ballroom is ballroom-ing
# 작성자: @catherinewandera8790
#
# 댓글 123: "i'm an otaku bestie" is DEFINITELY my favorite part
# 작성자: @Mig0182jsd
#
# 댓글 124: ATEEEE ️️️️️
# 작성자: @loonaneada
#
# 댓글 125: "Crazy" debuts with 2.03million first day str3ams on Spotify, making it the highest K-pop girlgroup debut in 2024!
# Congratulations Le sserafim & Fearnot! <3
# 작성자: @desislavabozhinova906
#
# 댓글 126: THE VOUGEING?!?!! THE GIRLING GIRLING?!?!!?! literally an ICON.
# 작성자: @KURUSAWAUWU
#
# 댓글 127: KAZUHAA ATE THIS WHOLE MV UPP!!
# 작성자: @C_A129
#
# 댓글 128: !Me encanta!
# 작성자: @jennypacheco2526
#
# 댓글 129: Sakura's rapping sounds is somehow addictive. Girly but deep. She should be the main rapper (after training ofc)
# 작성자: @cahyamaula
#
# 댓글 130: juicy couture crew are incredible, the use of this crew was IMMACULATE as they beautifully framed the whole video, tied the entire story together, they were EVERYTHING!!!!!
# 작성자: @DovregubbentheEMMAStan
#
# 댓글 131: " I WILL NO LONGER BEAR FALSE WITNESS BEFORE MY ATTRACTION
# WHAT IT MEANS, WHAT ITS WORTH, WHAT IT CAN DO AND CANT DO" made me so confidenttt ughh
# 작성자: @xloudyxics
#
# 댓글 132: THIS SONG IS A MASTERPIECE
# 작성자: @llove_maybe
#
# 댓글 133: 'all the girls are girling' and 'im an otaku bestie' will always be iconic. ><
# edit - holeshe it has been less than a day ty
# 작성자: @yznings
#
# 댓글 134: The “i’m an otaku bestie” and “galileo” are so satisfying
#
#
#
#
#
#
#
#
#
#
#
# Edit : I think I started a war 🫣
# 작성자: @aoate
#
# 댓글 135: Thank you for the inclusion of the Iconic House of Juicy Couture. The Black queer community are the originators of house music & ballroom culture. It’s important to see their presence as a reminder of who created this genre.
# 작성자: @quietcaracal
#
# 댓글 136: im getting adicted to the song omg
# 작성자: @GwaiRespuesto
#
# 댓글 137: I listened to this song so much that my 7 year old son (who knows nothing about kpop) start singing this too every morning day and night
# 작성자: @bq1412
#
# 댓글 138: ugh can this be their permanent concept? they ATE thissss!!!
# 작성자: @lussembleartmslover
#
# 댓글 139: The amount of black culture and queer culture in this MV is freaking incredible. I’m flying so much!!!
# 작성자: @marioburo2492
#
# 댓글 140: 65M fearnots congratulations
# 작성자: @lauritapereiradesouza9029
#
# 댓글 141: This is the craziest pretty concept I’ve ever seen. LSFM came to devour omg
# 작성자: @MiryanCamelia
#
# 댓글 142: The choreo the outfits the mv the visual the vocals the facial expressions the singing tone SCREAMS SOTY
# LE SSERAFIM YOU HAVE DONE IT AGAIN!!
# 작성자: @biscoffcake1594
#
# 댓글 143: 2:35  the water scene serving visuals
# 작성자: @faiii02
#
# 댓글 144: 65M fearnot~ keep streaming ️  ️
# 작성자: @haileynguyen502
#
# 댓글 145: Despite the harsh criticism and hate these girls have been receiving since their debut, they always held their heads high And they paid no attention to people comparing them to aespa, they really fit their Fearless Concept. I'm proud of these girls especially My Queen Sakura ️️️
# 작성자: @primomondragon7069
#
# 댓글 146: Chaewon can do anything FR! Vocalist, dancer, and now RAPPER??? She's literally all rounder
# 작성자: @bita-y3v
#
# 댓글 147: Queens are back !!!
# 작성자: @saheliswift4790
#
# 댓글 148: it's so addictive specially eunchae's parts
# 작성자: @isratmira2274
#
# 댓글 149: The phrase "All the girls are girling girling" will always be remembered as iconic.
# 작성자: @bilinasmini3480
#
# 댓글 150: omg idk if they said this but if they did "all the girls are girling girling" Im OBSESSED lets all support fearnotss
# 작성자: @iloveboba100
#
# 댓글 151: LESSERAFIM WILL DEFINITELY ATE CRAZILY IN THIS COMEBACK!!!
# 작성자: @連孝庭-b9o
#
# 댓글 152: Fearnots CRAZY from Le sserafim remains firm and strong on the billboard hot 100. They don't want to leave the chart and neither do you. wow you are incredible congratulations to the Korean and international fans you are incredible and determined.
# 작성자: @lauritapereiradesouza9029
#
# 댓글 153: the representation, the beat, the dance moves this might be THE comeback of all comebacks
# 작성자: @annaxsheridan
#
# 댓글 154: That “Le Sserafim “ will be forever iconic!!!
# 작성자: @STRAWMARII_offical
#
# 댓글 155: YUNJIN SAYS LE SSERAFIM AT THE END,THIS WAS ICONIC ALL THE TIME>>>>
# 작성자: @m1nyluw
#
# 댓글 156: Keep streaming fearnots!! let's go 70m!! Let's give lesserafim another win!️️️
# 작성자: @sera_fina12
#
# 댓글 157: At last!! Congratulations on Le Sserafim’s comeback!!
# 작성자: @KimJisoo-jm7sf
#
# 댓글 158: LE SSERAFIM reaches 3B streaming on Spotify, is the second fastest Kpop group to achieve this
# 작성자: @tallesm5543
#
# 댓글 159: the girls are DEF girling this comeback OMG
# 작성자: @kylawhite2140
#
# 댓글 160: Quase 65M <3
# 작성자: @Barmygs
#
# 댓글 161: SAKURA-STUNNING
# CHAEWON-STUNNING
# YUNJIN-STUNNING
# KAZUHA-STUNNING
# EUNCHAE-STUNNING
# THE VOCALS-STUNNING
# The CHOREO-STUNNING
# THE RAPPS-STUNNING
# THE VISUALS-STUNNING
# THE MV-STUNNING
# ALL-STUNNING
# FEARNOT KEEP SWIMMING!!!
# 작성자: @lesserafim145
#
# 댓글 162: Chaewon is the main ACE of the 4th generation or one of them.
# She has a damn beautiful and consistent vocal, an incredible stage presence and she also great at rapping.
# 작성자: @sentlec
#
# 댓글 163: CRAZY has debuted on Billboard Hot 100 at #76, their highest entry so far! This makes them the only k-pop girl group to chart two songs this year and only the 4th k-pop girl group in HISTORY to chart multiple songs. Congrats Le Sserafim!
# 작성자: @illyrianaa
#
# 댓글 164: 중독성 있다
# 작성자: @lllllloollllllll
#
# 댓글 165: All the girls are girling GIRLING
# 작성자: @Minyougurtt
#
# 댓글 166: I’m happy my girl Eunchae is RAPPING , you deserve it queen . Crazy is a bop from the choreo to the catchy chorus ! Yesss Le SSerafim.
# 작성자: @Sandrinarhonda
#
# 댓글 167: Just talking about the confidence, the style , the facial expresions, the skills... such a excellent comeback
#
# edit 1 : Hey guys tysm for the likes 🫶
# 작성자: @hehe_skz123
#
# 댓글 168: the influence of club culture, voguing, and specifically queer house art is soooo interesting in this video. all the girls are girling indeed
# 작성자: @madisonpetty9321
#
# 댓글 169: IM SO EXCITED THIS ALBUM SOUNDS SO GOID
# 작성자: @chaeryzcoco
#
# 댓글 170: CRAZY officially becomes the FIRST and ONLY k-pop group song to chart for two weeks on Billboard Hot 100 in 2024. Le Sserafim, ladies and gentlemen! The unstoppable and indisputable queens of the 4th gen!
# 작성자: @illyrianaa
#
# 댓글 171: Can we finally give the appreciation le sserafim deserve they have had unnecessary hate since debut and still worked hard  it is finally time to appreciate them apart from that slayedd >>>>>
# 작성자: @P1stay_engene4ever
#
# 댓글 172: めっちゃいい曲
# 작성자: @一気-q3k
#
# 댓글 173: THE VOGUING!!!OMG!!!THEY ARE ICONS!!!
# 작성자: @YOUHE.
#
# 댓글 174: "All the girls are girling" and "im an otaku bestie" will always be iconic. ><
# 작성자: @juaubert_
#
# 댓글 175: THIS IS CRAZY
# 작성자: @LSFFEARNOT
#
# 댓글 176: LE SSERAFIM YOUVE DONE IT AGAIN!!!!! BEST 4TH GEN GIRL GROUP
# 작성자: @qwdrul
#
# 댓글 177: Sakura’s part is soooo gooddd.I love Sakura.
# 작성자: @Nn_2884
#
# 댓글 178: The way Sakura embodies this vibe, Chaewon and the jellyfish hair, Eunchae is adorable, and kazuha slaying as usual. Yunjin and her glasses are a vibe, I am in love with the basic white tee and jeans fits.
# 작성자: @pariwhoop4935
#
# 댓글 179: LESSERAFIM FIGHTING 3rd winning
# 작성자: @banamalimandal3919
#
# 댓글 180: ウンチェがミューバン卒業するまでに1位とれますように！
# 작성자: @kana-w4k
#
# 댓글 181: This song is so UNIQUE
# This concept is so UNIQUE
# This mv is so UNIQUE
# Finally someone brought uniqueness into kpop.
# 작성자: @msj0015
#
# 댓글 182: THE GALILEO PART IS SO ADDICTING. THIS FULL MV IS TOO ADDICTIVE
# 작성자: @rbcsfreya
#
# 댓글 183: This is one of my favorite le sserafims song now!!!
# 작성자: @Grimmkimm8
#
# 댓글 184: Chaewon saying Pikachu is addictive ️
# 작성자: @Dxodxo738
#
# 댓글 185: “CRAZY” has reached new peaks both on global spotify (#57) and global apple music (#20). Congrats Le Sserafim, the unstoppable hitmakers!
# 작성자: @illyrianaa
#
# 댓글 186: They are 5 talented girls , who’s have a great friendship and family energy!!! They can Rap , sing , dance and they can stole our hearts with THIER only stares, the MV is top tier and in every comeback they are slays as always but somebody is not know about them so let’s str3aming Le Sserafim’s new song and old songs also and Let’s enjoy this masterpiece together my Fearnots !!! I’m so proud of them!!!
# 작성자: @STRAWMARII_offical
#
# 댓글 187: Congratulations LE SSERAFIM and FEARNOT 'CRAZY' 3rd Win M Countdown
# 작성자: @Ezodya
#
# 댓글 188: This Chaewon's Pikachu alongside Sakura's 'best Otaku' as well as Eunchae's enhanced voice and Kazuha's fast spoken parts plus Yunjin's acting and stunning black blue hair ahh LE SSERAFIM
# 작성자: @dalknb4268
#
# 댓글 189: 70,000,000
# fearnot Let's go
# 작성자: @SmMsmohammd
#
# 댓글 190: fearnot's lets give the cb our best to show the girls we love them! We love you fimmies I hope this cb breaks lots of records and your happy throughout promotions.
# 작성자: @ForeverKawaii
#
# 댓글 191: IS EVERYBORY ACTING LIKE AN ANGEL AND DRESSING LIKE CRAZY???????????????
# 작성자: @fernandacardoso2639
#
# 댓글 192: now, it's my favorite LE SSERAFIM's song!!!!
# 작성자: @vladhx
#
# 댓글 193: FIMMIES ATE WITH THIS SOTYYYY!
# 작성자: @luvzuuyu
#
# 댓글 194: "im an otaku bestie" is the best kpop line ever
# 작성자: @Soojin_luvv
#
# 댓글 195: THIS IS ACTUALLY INSANE I WAS NOT EXPECTING THIS??? QUEENS OF VERSATILITY ITS ALWAYS ENTERTAINING TO BE A FEARNOT
# 작성자: @galaxyplzz
#
# 댓글 196: This is so addictive
# 작성자: @kthsfortaehyung
#
# 댓글 197: Super adictiva!! Amoo ♡
# 작성자: @CarolDiaz_r
#
# 댓글 198: Let’s go 70 million
# 작성자: @chapspoduri5518
#
# 댓글 199: The "pikachu" of Chaewon The "Otaku bestie" of Sakura The "deep voice" of Eunchae The "rap part" of Kazuha The "acting&blue hair" of Yunjin LE SSERAFIM IS REMARKABLE!
# 작성자: @GasperSindatok
#
# 댓글 200: THE VERSES THAT ARE KINDA RAPPY IN CHEST VOICE ARE SO ADDICTIVEEE
# 작성자: @wonnies_choco_strawberry
#
# 댓글 201: Kazuha looks soooo pretty in this mv. Omg they really break the rules. This MV is so unique  its one of a kind!!!
# 작성자: @zuhazanaangel
#
# 댓글 202: Lesserafim would never disappoint us
# 작성자: @tasyamala2008
#
# 댓글 203: chaewon and yunjin are so impressive. they're so versatile and fit perfectly into so many different concepts, and their VOICES??
# 작성자: @czmbnch
#
# 댓글 204: LESSERAFIM FIGHTING
# 작성자: @bons123ilu
#
# 댓글 205: happy that le sserafim is giving credit to black culture and the vogue scene by having the juice couture crew in the background! it's time that idols credit black culture more, this song is so cute and catchy
# 작성자: @kid-ava
#
# 댓글 206: I am BTS ARMY and I never watch girl groups. But after seeing Jin's funny dance clip on insta I thought the track sounded great. I wasn't disappointed and this is going on a playlist. Great job!
# 작성자: @alipotter0613
#
# 댓글 207: CRAZY is predicted to chart on the Billboard Hot 100 for a second week at 88. This would make them the first K-pop group and the second K-pop act to chart a single on the Billboard Hot 100 for multiple weeks in 2024.
# 작성자: @tallesm5543
#
# 댓글 208: OK, this is actually so cool.
# 작성자: @maialsenussi3096
#
# 댓글 209: this type of music fits so well with Le Sserafim, Kazuha caught my eyes the most, girl looks gorgeous
# 작성자: @monochrome8731
#
# 댓글 210: The vocals, raps, dancing and visuals are out of this world. They have their own style and concept, independent of other bands, and this makes them different. This song is literally ATE!
# 작성자: @twicevansi-9
#
# 댓글 211: Sakura part "I'M AN OTAKU BESTIE" 0:38 IS SO ADDICTIVE. QUEEN
# 작성자: @QuralinaTanori
#
# 댓글 212: I just wanna say, a lot of people were comparing their concept photos, teasers and snippets - just their concept as a whole to Red Velvet, but this song was sooo Le Sserafim style. Like they did the "weird" concept and ATE it up in THEIR own way. They did amazing!!
# 작성자: @mangogo21
#
# 댓글 213: THIS IS SO ICONIC OML. EVERY MEMBER IS EATING UP THE POSES HELLOOOOO LITERALLY A MODEL SONG
# 작성자: @yourenotfunny4631
#
# 댓글 214: SAKURA SO BEAUTIFUL AND TALENTED! More Sakura rapping please!  Best comeback yet I’m so happy and excited for the future. Le Sserafim fighting!
# 작성자: @chanyo6529
#
# 댓글 215: Slayers are Slaying , Mothers are Mothering, Queens are Queening and All the Girls are Girling Girling !!!
# 작성자: @STRAWMARII_offical
#
# 댓글 216: WHY IS THIS SO CATCHY
# 작성자: @Emberpurple
#
# 댓글 217: Dark blue yunjin is something we didnt expect she nailed it.
# 작성자: @hybelabels-jokesandcomedia5940
#
# 댓글 218: I love how all of us are obsessed with "Back in the days" "I'm an otaku bestie" and "Pikachu" lmao
# 작성자: @Fearnaurt
#
# 댓글 219: さっさと1億行こうぜその素質ある曲だよ
# 작성자: @Llllllllllllll227
#
# 댓글 220: Cheawon Pikachu
# 작성자: @JiaKim-n6y
#
# 댓글 221: This song is giving them the chic sassy vibes! Les serafim ate once again! So many rap parts and I'm not complaining! Vocals on point! Personally, Chaewon rap is my favorite!
# 작성자: @kaiii-sh9kv
#
# 댓글 222: the Saki vogue, the Manchae drop and bridge, the Chaewon rap, the Kazuha slaying during all the MV, the Yunjin girling - WAAAAAHHHH, i am going crazy watching this!
# 작성자: @Bambuchurik
#
# 댓글 223: 0:37 STOP SAKURA'S DUCK WALK? OMG??
# 작성자: @besofryoutube
#
# 댓글 224: LESSERAFIM FIGHTING
# 작성자: @banny95ilu
#
# 댓글 225: OMG THE EUNCHAE RAP ??? SHE LITERALLY SLAYED !! (all of them slayed, as always !!)
# 작성자: @giselleestarr
#
# 댓글 226: That hand movement at 2:06was a spoiler??!!! They did it at gda 2024 tooooOMFG,
# 작성자: @Yukinohana-cp7xj
#
# 댓글 227: this music video goes unbelievably hard. sakura hitting the duck walk within the first minute is crazzzzzzy stuff. they served periodt
# 작성자: @Jo-jw8xm
#
# 댓글 228: let's go 100m
# 작성자: @Envarcadia
#
# 댓글 229: Le sserafim bringing vogue and EDM house to kpop, something not often used in kpop. Queens of bringing new things and different styles and genres to each release, this just makes me more of a fan.
# 작성자: @lauritapereiradesouza9029
#
# 댓글 230: Omg. Kazuha’s dance skills and visuals are so amazing. The all black look and the hair. Visual overload
# 작성자: @VictorReza-ch2ns
#
# 댓글 231: I'm an otaku bestie, this is the best part. sakura ate, her dance, her voice. she's insane
# 작성자: @emiliatanori8104
#
# 댓글 232: Let’s go 65M
# 작성자: @taianemoura2799
#
# 댓글 233: THE GIRLS WORKED SO HARD ON THIS CB SO LETS SUPPORT FEARNOTS <33
# 작성자: @Kikopolok
#
# 댓글 234: An Army here to support Lesserafim ♡
# As an Army I really love this song, It's so addicting..... Love it ♡
# LESSERAFIM FIGHTING!!!!
# 작성자: @aditiawantikachaudhary866
#
# 댓글 235: CHAEWON -CRAZY
# YUNJIN- CRAZY
# EUNCHAE-CRAZY
# SAKURA-CRAZY
# KAZUHA-CRAZY
# LE SSERAFIM-CRAZY
#
#
# 작성자: @STRAWMARII_offical
#
# 댓글 236: Galileooo
# 작성자: @confidenceconfidence2823
#
# 댓글 237: THE VOGUEING IM OBSESSED
# 작성자: @khadijachoudry
#
# 댓글 238: LE SSERAFIM QUEENS
#  CHAEWON QUEEN
#  YUNJIN QUEEN
#  SAKURA QUEEN
#  KAZUHA QUEEN
#  EUNCHAE LITTLE QUEEN
#  WE LOVE LE SSERAFIM
#  WE ARE TRUE FEARNOT
#  SUPPORT LE SSERAFIM
# 작성자: @ProtivVirta
#
# 댓글 239: I literally don't get why people call this song a mess... it's so catchy and the mv is fire...the song is a bop
# 작성자: @tasty_sugarr
#
# 댓글 240: oh another catchy song is here! i love it
# 작성자: @terusik9622
#
# 댓글 241: finally a concept that gives eunchae a decent amount of lines!!!
# 작성자: @ewalinaa
#
# 댓글 242: I lit love the representation of trans women on this, like Kamiyah, Brooklyn and Tati voguing in the ending gives me lifeeeeee, oouu lesserafim ate with this one
# 작성자: @yellow6547
#
# 댓글 243: “Galileo” line is so iconic. It’s so satisfying ️
# 작성자: @Danam12
#
# 댓글 244: Yunjin saying le seraffim will never get old
# 작성자: @mangogo21
#
# 댓글 245: That line "all the girls are girling, girling"
# Will be forever iconic in lesserafim's History
# 작성자: @Aes_rina
#
# 댓글 246: Sakura is so pretty this era was crazy love you lessrafim
# 작성자: @Kpopworld172
#
# 댓글 247: THE WAY YUNJIN SAY LE SSERAFIM AT THE END IS ICONIC THE WAY THE LINE IS ALL THE GIRLS ARE GIRLING GIRLING IS ICONIC AND THE WAY THE LINE IS ACTING LIKE AN ANGEL, DRESS LIKE CRAZY IS ICONIC
# 작성자: @croserroblox6981
#
# 댓글 248: COME ON FEARNOTS GET THIS UP TO 100 TRILLION VIEWS!
# 작성자: @claydogg234
#
# 댓글 249: Yunjin saying Le Sserafim at the end will forever be ICONIC!
# 작성자: @ForgetMenot-i6e
#
# 댓글 250: I feel like this is the first Comeback that takes all their strengts and weakness into account..It feel like them!! SAKURA being an otuko besti,YUNJIN owning everything she does our ace CHEAWON, and the stunning dance, ENCHEAe's unique voice rapping,KAZUHA -It's all so beautiful!!
# 작성자: @nadeemahmed-fu2yd
#
# 댓글 251: I love how they give credit to those people who participated in this MV, the literally put a long list of names in the details section  Love the warmth seeing how they appreciate those who worked hard for this MV. SouMu/Hybe/LSF staffs and artists are doing better and better
# 작성자: @tsh9584
#
# 댓글 252: Le sserarim never fails to impress us with their skills and how talented they are they outdone themselves I love that it’s black culture too and vogue in it this is so amazing they’re the best group ever!
# 작성자: @oreofilling1751
#
# 댓글 253: How many international fans are here to support  le sserafim
# 작성자: @ShyamGidwani-w9y
#
# 댓글 254: 5 vocalists, 5 all rounders, 5 dancers, 5 aces, 5 rappers, 5 members, 5 queens, 5 visuals. Yes this is LE SSERAFIM never dissapoints and the best idols
# 작성자: @StrayKidsTheFutureofKpop
#
# 댓글 255: I’ve never seen so much black representation in kpop despite the industry being completely influenced by Black culture. I love love it
# 작성자: @yaya_97
#
# 댓글 256: SLAYED ATE.
# 작성자: @gearmysylhet2714
#
# 댓글 257: No.7 Billboard HOT 200, No.76 Billboard HOT 100
# 작성자: @thixogud
#
# 댓글 258: HONG EUNCHAE DEATH DROP?? The rap section where Eunchae, Kazuha and Chaewon are rapping one after the other, Kkura duck walking and talking about being an otaku and just Yunjin in general and the voguing with Black dancers!!! Oh i am in love, le sserafim is soooo back <3
# 작성자: @wahiedashaikh9415
#
# 댓글 259: EUNCHAE KAZUHA AND CHAEWON RAPPING OMFG I NEVER KNEW I NEEDED THIS
# 작성자: @Miyahvsr._
#
# 댓글 260: 3冠目おめでとう︎
# 작성자: @sakusaku3571
#
# 댓글 261: Lets all support LESSERAFIM, and dont forget to vote them for MTV Push Award!!!! FIGHTING!!! ️
# 작성자: @bplovedovefimmie
#
# 댓글 262: They’re so pretty in this comeback, but not only pretty, they’re stunning. Their visuals, their singing, their choreo… This is a gold MV!!!
# 작성자: @Eunchantedd
#
# 댓글 263: 0:29 This part ateeeee! Chaewon is so slayyyyyyyy. Especially the “like pikachu” Is so cuuuuteeee.
# Edit: Tysm for almost 50 likes!
# 작성자: @CatKitten-u4f
#
# 댓글 264: Hong Eunchae's part it's crazy..
# 작성자: @nurmahwati4461
#
# 댓글 265: Le serafim on the VMAs stage. Looking forward to the show. Let's support the girls, guys.
# 작성자: @lauritapereiradesouza9029
#
# 댓글 266: love the praise of voguing culture in this video. especially at 0:57 with the eunchae death drop!!! slayyyyyy!!! ️
# 작성자: @addieland456
#
# 댓글 267: This era should be the most successful era of le sserafim.
# 작성자: @rockyMendig
#
# 댓글 268: LE SSERAFIM IS THE BEST!!!
# 작성자: @LSFFEARNOT
#
# 댓글 269: Yunjin OWED this comeback!
# 작성자: @ocfresh
#
# 댓글 270: I love how both Yunjin and Sakura also participated in the lyrics writing, slay mah gurls!
# 작성자: @kpop_fan_foreverx
#
# 댓글 271: Fearnots let's support le sserafim on all platforms they worked so hard
# 작성자: @Lovejenniekim4
#
# 댓글 272: These girls know how to read a culture
# 작성자: @bourjoism3917
#
# 댓글 273: OMG!!!! Perfect Sakura, perfect Kazuha, perfect Eunchae, perfect Yunjin, perfect Chaewon!!! Le Sserafim go!!!!!!!!! You are the best!!!
# 작성자: @lisamomdzhi9937
#
# 댓글 274: Congrats for the VMA , lets make it 60 today with it fearnots
# 작성자: @souravs8797
#
# 댓글 275: Biggest debuts by kpop girl groups on spotify counter in 2024:
# 1. CRAZY- 2,554,686
# 6.EASY - 1,742,227
# 작성자: @lauritapereiradesouza9029
#
# 댓글 276: Yunjin’s glasses + her vogueing is lowkey giving Bayonetta
# 작성자: @allenchristianranada4871
#
# 댓글 277: All the girls are girling,
# all the girls are lesserafiming, all the girls are dancing,
# oh this girls are bringing
# SO-SO-SO-SO
# TY-TY-TY-TY
# 작성자: @mn.kcz27
#
# 댓글 278: İlk çıkışlarından beridir bu kızların hayranıyım beni hiç yanıltmadılar. Her zaman harika şarkılar, performans ve eralarla dönüyorlar! Sizi seviyorum Le Sserafim♡
# 작성자: @meryemyldz8326
#
# 댓글 279: 2:46 "meaningless" spoiler comeback?? call me delusional but i choose to believe
# 작성자: @ChaePupuWon
#
# 댓글 280: FIGHTING FEARNOT STREAM CRAZY X PERFECT NIGHT
# 작성자: @erickamorales7482
#
# 댓글 281: They really broke the record fr like as a black person am so happy to see the black people in the mv like not that other idols have never done that but this is so perfect like the whole mv looks so elegant
# Mamaa am famous  hahah
# 작성자: @Kaystan263
#
# 댓글 282: 6 months have passed already. lesserafim has been through a lot since then, so lets show lots of love for this album fearnots
# 작성자: @brocco6023
#
# 댓글 283: What do you expect? They did it again. I'm so happy this comeback is successful as well. The iconic "Act like an angel and dress like crazy" is awesome.
# 작성자: @SimpingQWER
#
# 댓글 284: Let's not give up untill this MV hit 100M
# 작성자: @Aspiringdoctor__
#
# 댓글 285: Act like an angel and dress like crazy is the most iconic line ever in K-Pop songs history
# 작성자: @SitiAisyahUmrah
#
# 댓글 286: YO… THEY ATE THIS UPP?? I love when K-pop does concept like this
# 작성자: @alvinaeth9393
#
# 댓글 287: This is how you appreciate culture everybody take notes!!! The girls are truly grilling!!!
# 작성자: @JuniperArcher
#
# 댓글 288: just awsome dance awesome rap  awesome vocal awesome girls i was a super crazy
# 작성자: @CuteArmyGirlNowshin777
#
# 댓글 289: 0:16 GOT ME THINKING MY WIFI WAS BAD LMAOO
# 작성자: @renjunh0lic
#
# 댓글 290: I SCREAMED WHEN EUNCHAE DROPPED SHE ATE THAT UPPP
# 작성자: @frugyus
#
# 댓글 291: I'm so addicted to the eunchae part here 1:30 and(act like angel,dress like crazy)
# 작성자: @CallmeVell
#
# 댓글 292: I love song , this is my live THE SONG CRAZY
# 작성자: @Noe-p6k
#
# 댓글 293: THE VOGUEING GUYSSS, THE VOGUEINGGGG  THIS IS FIREEEE
# 작성자: @jessiets
#
# 댓글 294: I would like to thank the people behind the scenes who were lesserafim all along this tough journey!!
# 작성자: @RightFarhana
#
# 댓글 295: "No, a whole song cannot be iconic"
#
# ARE YOU SURE GIRLIE?!?!?
# 작성자: @rbcsfreya
#
# 댓글 296: Push to 65 M please
# 작성자: @CoverUnder-r6h
#
# 댓글 297: As a Black once, I don’t know much about LesseraLarapin, but I clicked on this just because of the thumbnail I’m happy to hear they’re giving credit to black artists.
# Sorry I used the mic, I can spell dw
# 작성자: @applebush6119
#
# 댓글 298: 1:21 GARLY GARLY
# 작성자: @Its_Eddu
#
# 댓글 299: The choreo?! The visuals?! The rap?! The vocals?! LE SSERAFIM never disappoint!
# 작성자: @Meowz_xx
#
# 댓글 300: YEAH NEXT 65M lesgoo
# 작성자: @w00180
#
# 댓글 301: Haters gon hate but lesserafim always served with their comebacks
# 작성자: @lasanthihettiarachi7083
#
# 댓글 302: How many international fans are here to support our girliesss???!!!
# 작성자: @rmoentertainment
#
# 댓글 303: im IMPRESSED,whoever directed the MV NEEDS a raise
# 작성자: @user-qo2vf6vl3g
#
# 댓글 304: ''im an otaku bestie'' lo digo con todo corazon, adictivo
# 작성자: @elotemarinette8275
#
# 댓글 305: This song proof that chaewon is the ace, she can rap, have stable vocal, can also dance, amazing visual, amazing sp
# 작성자: @hoonicekingg
#
# 댓글 306: WHY CHAEWON PART IS SO PERFECT I LOVE THIS PART
# 작성자: @tsukiitaruu
#
# 댓글 307: I love that they made sure to include actual black gay dancers. It's the appreciation and visibility for me.
# 작성자: @dylanpoole2431
#
# 댓글 308: The amazing fact about LE SSERAFIM:ALL LE SSERAFIM'S SONGS ARE HITS AND THEY LEAD THE 4TH GENERATION AS THE BEST GIRL GROUP️
# 작성자: @sunshine2_2
#
# 댓글 309: 0:16 I though actually something was going wrong with my internet
# 작성자: @IHeartOlivaRodridrgo
#
# 댓글 310: THEY ATE WITH THIS ONE!! KAZUHAS PRONOUNCIATION IS SO SATISFYING TO HEAR !!!
# 작성자: @monkeyaye
#
# 댓글 311: 2:47 How much are you willing to bet that they are giving us a hint for the next album?
# 작성자: @DiscountShikamaru
#
# 댓글 312: 65M GOAL
# 작성자: @MaryPadilla-gs7lo
#
# 댓글 313: We're all here for supporting le sserafim let's go girls we're so proud of you
# 작성자: @luxaa111
#
# 댓글 314: them saying “i am the material” slayed so hard
# 작성자: @katiejoyyy08
#
# 댓글 315: どうしよう、めちゃくちゃ好き、、
# 圧倒的smart推しだったんだけど、一瞬で塗り替えられた。CRAZYまじでCRAZY大好きです早くステージ見たい
#
# FEARLESSもEASYもCRAZYもコンセプトバラバラなのにLE SSERAFIM️って感じなの好
# 작성자: @kyo-tyan
#
# 댓글 316: Yess girls
# 작성자: @javiergatica183
#
# 댓글 317: im an otaku bestie 0:37
# 작성자: @Bounceleenaforevah
#
# 댓글 318: XにあがってるVMAsパフォーマンス動画の引用、ピオナ以外のアカウントからも好評コメントがたくさんあって嬉しかった!!
# LE SSERAFIMいつも最高のステージ見せてくれて本当に誇らしいよありがとう
# Billboard️‍CRAZY 1st WIN️‍VMAsパフォーマンス️‍ウンチェ長い間MCお疲れ様️‍
# CRAZYまだまだ楽しもーー！
# 작성자: @user-qo3mp9zc9s
#
# 댓글 319: LE SSERAFIM - 100%
# M/V - 100%
# VOCAL - 100%
# VISUAL - 100%
# BEAUTIFUL - 100%
# INTERNATIONAL - 100%
#
# LET'S SHOW HOW MUCH WE SUPPORT LE SSERAFIM FOREVER!!!
# 작성자: @Kwaen_kpop
#
# 댓글 320: Everytime i get a like i will rewatch it!
# 작성자: @alamiraidelbi3252
#
# 댓글 321: 57 million in 11 days That's incredible Can we get 60 million by the weekend if we don't get it That's fine but let's try hard to get it
# 작성자: @lauritapereiradesouza9029
#
# 댓글 322: Every time someone likes my comment I'll watch it again
# 작성자: @Robloxify69
#
# 댓글 323: まじで何回でも聞ける。アンチに負けず頑張って！！！
# 작성자: @user-ee4ud4ez2j
#
# 댓글 324: Lets get this 1 billion
# 작성자: @Seowonsmangoes
#
# 댓글 325: THIS IS POWER, THIS IS VOGUE, THIS IS REPRESENTATION AND THIS IS LESSERAFIM
# 작성자: @oliverraiza
#
# 댓글 326: MOTHER RAPPING IS EVERYTHING I DIDNT KNOW I NEEDED TILL NOW
# 작성자: @rinnybitty
#
# 댓글 327: LE SSERAFIM is the GOAT FR!! Amazing girls <3! The only reason they don't have billions of views is because she isn't just watching the short on my channel explaining how all these artists are going sooo viral these days!
# 작성자: @sheeiiittt2012
#
# 댓글 328: Keep streaming fearnots please 70M we can do it ?
# 작성자: @lauritapereiradesouza9029
#
# 댓글 329: Las chicas devoraron!! Pero kazuha se pasó de hermosa, sirvió todo, cara, cuerpo y presencia, simplemente increíble
# 작성자: @camiliss2597
#
# 댓글 330: this is EXACTLY what i expected from le sserafim! you won’t hear me shut up about this ️️
# 작성자: @iluvbjs
#
# 댓글 331: Sakura is so pretty 1:30
# 작성자: @Alyn-j5p
#
# 댓글 332: They totally nailed this
# 작성자: @WenWieyy
#
# 댓글 333: ルセラの場合路線変更とかじゃなくそもそも路線拡張系というか路線を固定してなくて毎回新しいジャンルの音楽やダンスやるよね。やりたい事は躊躇なくやるルセラもスタッフ陣もイケ散らかしてる
# 작성자: @ktubebox
#
# 댓글 334: 2:24 not sakura with the sailor moon wand spector
# 작성자: @heyitsjustjulie
#
# 댓글 335: ピオナファイティンだよ！今頑張らないでいつ頑張るの！
# 작성자: @まるまる-r5p
#
# 댓글 336: Le serrafim is slayinggg while vouging
# 작성자: @josephpadin6865
#
# 댓글 337: 0:58  THATTTT ATEEEEEE EUNCHAEEE OMGGGG THIS IS HER ERA FRFR
# 작성자: @AveryBarker-dk6zw
#
# 댓글 338: LESSERAFIM won its first award since its debut at the ‘MTV Video Music Awards’, one of America’s four major pop music awards ceremonies.
# 작성자: @younghokim-i1e
#
# 댓글 339: 70M FOR THIS WEEK, WE CAN DO IT FEARNOTSSS!! #LESSERAFIM
# 작성자: @jovannicastro13
#
# 댓글 340: I’m an otaku bestie
# 작성자: @RalycaUngureanu
#
# 댓글 341: The loading at the beginning actually fooled me 🫣 LE SSERAFIM ATE WITH THIS AHH  LOVE YOU GUYSS
# 작성자: @IzzyMae22
#
# 댓글 342: I love Yunjin's facial expression! She always looks so cute
# 작성자: @TheTev94
#
# 댓글 343: 0:57 this part is funny but sooo coool eunchae
# 작성자: @sh.korkesh7740
#
# 댓글 344: Steaming Perfect Night and Crazy
# 작성자: @lauritapereiradesouza9029
#
# 댓글 345: 0:10 my favorite part!
# 작성자: @iwantds
#
# 댓글 346: Music is such a universal language. Love hearing different styles and genres from all over the world.
# 작성자:
#
# 댓글 347: Congratulations to LE SSERAFIM for all the amazing things you've accomplished this year. You've not only thrived but also bloomed in a place full of thorns. To the ones throwing shade without reason, you're only fueling the fire that's making them shine even brighter. Keep rising, queens—your success speaks louder than the noise!
#
# LE SSERAFIM IS A MINDSET!
# 작성자: @OverdOzingyOu
#
# 댓글 348: I LUV LESSERAFIM!!
# 작성자: @liittlebodybiighearted
#
# 댓글 349: we achieved so much with Easy and Crazy So we can't give the haters reasons to attack. So we need to give them victories, records and views to rub it in their faces. Enjoy the music be happy and towards 100 million
# 작성자: @lauritapereiradesouza9029
#
# 댓글 350: Voguing makes this MV 10x better, what a piece of art
# 작성자: @HeisenbergFam
#
# 댓글 351: Who's here after they entered billboard hot 100 with CRAZY?
# 작성자: @nyeongrandan
#
# 댓글 352: THIS IS THE BESTTTTTTTTTT SONGGGGGGG WOW
# 작성자: @Dazzmael
#
# 댓글 353: 50 million viewz after all those Coachella drama, oh lesserafim slayed those haters PERIOD...
# 작성자: @captainj1669
#
# 댓글 354: Finally hybe gives them a song in their vocal range!
# 작성자: @Coop-kx2ib
#
# 댓글 355: Learning the dance after listening to this masterpiece of a song on loop for almost 2 whole hours is the only logical thing to do. Le Sserafim absolutely ATEeeeee this comeback!
# 작성자: @bossfight6125
#
# 댓글 356: Enak bett lagunyaaa njirr terngiang2 muluuu
# 작성자: @yunitaroudhotuljannah3146
#
# 댓글 357: Kkura is our otaku bestie and I love it!!
# 작성자: @patri_2013
#
# 댓글 358: 全ての感想をこの一言で表せる。
# 「crazy」
# 작성자: @春谷月翔
#
# 댓글 359: CRAZY debuts at No. 7 on the BILLBOARD 200, LE SSERAFIM becomes the second Kpop girl group to enter the BILLBOARD 200 top 10 with 3 different albums after TWICE, and the fastest girl group to achieve this feat
# 작성자: @tallesm5543
#
# 댓글 360: ficou daora pô achei firmeza
# 작성자: @doguinho1686
#
# 댓글 361: Yunjin act a Angel dress like crazy is addicting part and Iconic
# 작성자: @Maroshi_34
#
# 댓글 362: Act like an angel and dress like CRAZY ~most iconic line. luv Le sserafim
# 작성자: @QueenieB4949
#
# 댓글 363: これだよこれこれ！ルセラフィム！！これが欲しかったーーーー！！！！！
# 작성자: @satrinneify
#
# 댓글 364: CRAZY now joins EASY as the only K-pop girl group Korean album to surpassed 100,000 copies sold on Oricon Japan in 2024
# 작성자: @tallesm5543
#
# 댓글 365: カムバのコンセプト通り踊り狂いたくなるほどの中毒性すごいわ、ルセラフィムファイティン！
# 작성자: @はーる-c2e
#
# 댓글 366: Le Sserafim & Rap =
# Perfection
# 작성자: @STRAWMARII_offical
#
# 댓글 367: يعني اكيد راح تكون العودة نار مثل باقي عوداتهم بس متحمسة متحمسة لانو مفهوم جديد و اكيد اصواتهم كمان راح تطلع نار
# 작성자: @army.blinkkpop
#
# 댓글 368: This song is making me crazy.
# 작성자: @sisisisilota1166
#
# 댓글 369: さくらの知らない一面見せてくれてありがとうカッコ良過ぎる！！
# 작성자: @minimini267
#
# 댓글 370: Fearnots stay strong these last two eras were difficult but we achieved things we couldn't in the previous ones. The haters went into despair after seeing that the le seraphim raised his head and shut them up. They are just showing their fear of girls becoming more successful. Our fandom may not be bigger than their favorites, but if there's one thing we have, it's the strength to surpass and break records that they can't even reach. we have gained a lot of fearnots so let's be examples of fans. Because certain fandoms don't know what it's like to be a fan. Obception is not being a fan. fighting
# 작성자: @lauritapereiradesouza9029
#
# 댓글 371: I'm addicted to Kazuha's parts. Like her voice suits this concept very well.
# 작성자: @EnhypenxEngene_forever
#
# 댓글 372: LESSERAFIM FIGHTING
# you are best FIMMIES
# 작성자: @banamalimandal4750
#
# 댓글 373: So the new goal is 70 million till the next week Sunday
# 작성자: @3rd165
#
# 댓글 374: Everytime when they have a comeback ,it became a trend in kpop
# 작성자: @thv_yawnz_chaechae
#
# 댓글 375: こういうたくさん遊んでる挑戦的な曲大好き
# 작성자: @みこしば-v9e
#
# 댓글 376: 64M 70M go go go guys
# 작성자: @lauritapereiradesouza9029
#
# 댓글 377: ルセラーー！頑張れ！！クラオンニの歌声が癖になる日本から応援してます！！
# 작성자: @69vnn
#
# 댓글 378: '' ACT LIKE AN ANGEL AND DRESS LIKE CRAZY ''..............WOOOO............. I'm really crazy after listening this song .....................
# 작성자: @IslmTawabul
#
# 댓글 379: 0:38 OTAKU BESTIE ️️
# 작성자: @alexaleix1
#
# 댓글 380: All the girls are girling girling my fav part
# 작성자: @hackerstatus3742
#
# 댓글 381: 2:46 MEANINGLESS NEXT ALBUM?????
# 작성자: @harryhardy2667
#
# 댓글 382: 歌詞にピカチュウ出てくるのも可愛い️ルセラのぶち上がり曲大好きㅠㅠ
# 작성자: @user-sv5xb3rm2x
#
# 댓글 383: 1:41
# 작성자: @gidle_miyeon_
#
# 댓글 384: LE SSERAFIM IS THE BEST GIRL GROUP IN 4TH GENERATION (QUEENS)
# 작성자: @sunshine2_2
#
# 댓글 385: 0:44 I am addicted to this song
# 작성자: @ChoiYeonjun-l8v
#
# 댓글 386: Omg this is so great  1:39
# 작성자: @MovesInMotion29
#
# 댓글 387: チェウォンの導入ラップがまーーじで好き
# 작성자: @kikikikkiJP
#
# 댓글 388: Congrats LE SSERAFIM CRAZY 3rd Win on Mnet M Countdowns
# 작성자: @Desdex
#
# 댓글 389: 2:13 THIS MV IS ICONIC WHAT?!!!!
# 작성자: @Peachyrina
#
# 댓글 390: 2:28 All the girls like garlic garlic 모든 여자는 마늘을 좋아한다
# 작성자: @주청-r6r
#
# 댓글 391: 神曲の予感しかない
# 작성자: @back_numberlove
#
# 댓글 392: I'm proud of you ma girls
# 작성자: @aom941
#
# 댓글 393: 0:23 SAKURA
# 작성자: @LE_SSERAFIM
#
# 댓글 394: 00:29 CHAEWON ATE
# 작성자: @dhemillesilva9204
#
# 댓글 395: 2:47 reverse meaningless
# 작성자: @punpun9867
#
# 댓글 396: goal is to make le sserafim crazy Achieve 200-300m
# 작성자: @bhenxyrhylRVarquez
#
# 댓글 397: Anyone hear the “what” vine at 1:50 ??
# 작성자: @rity6233
#
# 댓글 398: 01:13
# DON'T DROP THE SOAP
# 작성자: @aufak-live101
#
# 댓글 399: HATERS ARE JUST JEALOUS OF U....KEEP GOING GRILS!!!! YOUR SONGS ARE AWESOME
# 작성자: @Mercury-e9o
#
# 댓글 400: I just wanna say, a lot of people were comparing their concept photos, teasers and snippets - just their concept as a whole to Red Velvet, but this song was sooo Le Sserafim style. Like they did the "weird" concept and ATE it up in THEIR own way. They did amazing!!
# 작성자: @mangogo21
#
# 댓글 401: 64M go
# 작성자: @chang0723
#
# 댓글 402: LE SSERAFlM love腌考高考可靠或️️️
# 작성자: @lisaGüneş
#
# 댓글 403: Mientras mas la escucho mas me gusta xD
# 작성자: @dah-niel1
#
# 댓글 404: Ahhhh come one we can get to 80m!! They deserve it, this is black culture and I'm very happy!
# 작성자: @digitallyboarded1371
#
# 댓글 405: All the gurs are galling galling
# 작성자: @Beomgyuhour100
#
# 댓글 406: CHAEWON SAKURA TE AMO
# 작성자: @Izaanplays
#
# 댓글 407: 르세라핌 빌보드 hot 100 2주연속 진입 축하합니다 3주연속 갔으면 좋겠다
# 작성자: @Great-f4s
#
# 댓글 408: SOTYYYYYY
# 작성자: @Ryujin1lowe
#
# ...
# 작성자: @calripplebear1293
#
# 댓글 689: Streaming fearnots fighting
# 작성자: @lauritapereiradesouza9029
#
# 댓글 690: LETS GO 70 MILLION!!!!!!!
# 작성자: @aprilmorris5343
#
# 댓글 691: me in dti walking down the runway   ️
# 작성자: @bbokari9880
#
# 댓글 692: 이노래 최고..
# 작성자: @Userly_5432
#
# 댓글 693: So is meaningless the name of the next comeback?? They usually put comeback hints at the end of each mv!!
# 작성자: @lilabibi2473
#
# 댓글 694: 0:37  IM AN OTAKU BESTIE ️
# 작성자: @Angy_roblox
#
# 댓글 695: 이번 컴백은 제가 가장 좋아하는 세라핌의 노래가 되었습니다 스타일리쉬하고 대중적이며 혁신적이며 그들의 분위기에 잘 맞습니다
# 작성자: @K_RBY_o3o
#
# 댓글 696: At first i didnt like it and thought it was weird but now i cant stop vibing everytime i hear it
# 작성자: @Cloudy_rosie
#
# 댓글 697: 이 뮤비 왤케 잘만들었어요?
# 작성자: @sspark177
#
# 댓글 698: Sakura is so cool, she,s great at dancing
# 작성자: @n1kolatesla
#
# 댓글 699: まだまだいこう！ピオナ︎
# 작성자: @윤-i8j
#
# 댓글 700: LETS GO 65M
# 작성자: @rndom-to2xq
#
# 댓글 701: Lilies here<3
# Road to 100m...
#
# CRAZY X ROCKSTAR
# 작성자: @Taekook_verse
#
# 댓글 702: 4k로 보니 의상도 이쁘고 멤버들은 더 예쁘고
# 작성자: @양파링-y9r
#
# 댓글 703: サクラがお姫様過ぎる
# 작성자: @きなこ皇子
#
# 댓글 704: They’re so adorable and beatiful
# 작성자: @j-mincompany3457
#
# 댓글 705: "CRAZY" on Spotify Weekly Top Songs USA City charts:
#
# #40. San Francisco (+13) new peak
# #43. Anaheim
# #71. Los Angeles (+8) new peak
# #90. San Diego
# #92. New York City
# 작성자: @lauritapereiradesouza9029
#
# 댓글 706: Act Like An Angel
# 작성자: @KayraAlifia
#
# 댓글 707: 最高！
# 작성자: @佐藤陸人-q2s
#
# 댓글 708: ادمان
# 작성자: @les_ser5
#
# 댓글 709: The gals are gurling
# 작성자: @Carat...Wooahae
#
# 댓글 710: LESSERAFIM ON TOP!!!!
# 작성자: @Eunseorpop
#
# 댓글 711: TGIS IS SO CRAZYYYYYYYYTY!!!!!!!!!!!!
# 작성자: @sophrosyyn
#
# 댓글 712: ルセラフィム最高だ
# 작성자: @eri04181113
#
# 댓글 713: いま流行りの phonk 調じゃん　やるねぇ
# YUNJIN ♡
# 작성자: @forughtara1119
#
# 댓글 714: Fearnots ask yourselves do you want LSF to win a daesang SOTY?
#
#
#
#
#
# :then str3am perfect night like crazy.
# 작성자: @easypeasylemonsqueezy
#
# 댓글 715: 2nd Billboard Hot 100 hit!!
# 작성자: @staywiz5843
#
# 댓글 716: 67M let's do it fearnots
# 작성자: @lauritapereiradesouza9029
#
# 댓글 717: WHY IS NO ONE TALKING ABOUT HOW REALISTIC THE LOADING LOOKED LIKE I FR THOUGHT IT WAS MY INTERNET
# 작성자: @smileyalexx
#
# 댓글 718: サクラかわいいー1億いきたい
# 작성자: @chisamatuo5383
#
# 댓글 719: こっちのバージョンめちゃくちゃ良い！！
# ストーリー仕立てになってて素敵
# 작성자: @violetta6283
#
# 댓글 720: Wow 64M in 3week
# 작성자: @Triplemillionseller7454
#
# 댓글 721: Producer is so smart
# 작성자: @chiva71111
#
# 댓글 722: LE SSERAFIM in 2024:
#
# Peaches
# Casetify
# NBA
# Android
# Jim beam
# New Era
# Mom's Touch
# Gelato Pique
# Sony
# JanSport
# Alpha Industries                                                                                                                                                            These are my girls. running out of stocks
# 작성자: @lauritapereiradesouza9029
#
# 댓글 723: 2:45 I thought the wifi was frozen and I was scared
# 작성자: @kotaxww
#
# 댓글 724: 0:45  anyone like this part or it just me???
# 작성자: @LucyMatie-ff3sl
#
# 댓글 725: LESSERAFIM FIGHTING
# 작성자: @banny95ilu
#
# 댓글 726: 전홍준대표님 인터뷰가 떴네요.  전홍준대표님 힘들때 많이 도와주셨다고. 하이브와 빌리프랩에서 피프티2기 멤버 2명도 지원해주셨다고 하네요.
# 작성자: @Lovewinsall0909
#
# 댓글 727: 0:56 IS SO ICONIC
# 작성자: @kinoko8761
#
# 댓글 728: IM AN OTAKU BESTIE
# 작성자: @glynnstephens4201
#
# 댓글 729: 오프닝부터 심상치 않다
# 작성자: @TV-ip9ty
#
# 댓글 730: 1:37 I love Eunchae’s rap part and her deep voice I think about it every day
# 작성자: @jenniferpeprah9439
#
# 댓글 731: aupercrazy~~
# 작성자: @smilepotato-pu6ry
#
# 댓글 732: Está bueno la canción aunque espero más participacion y letras para Sakura !!! Sigo a lesserafin solo por SAKURA...
# 작성자: @rosemarykarenezpinosabusti4735
#
# 댓글 733: 70M PIONA FIGHTING
# 작성자: @jacobxser
#
# 댓글 734: Congratulations to us fearnots!! We made 2nd week on billboard happen! I think we can do another 2 weeks!  LFG!!!
# 작성자: @Danam12
#
# 댓글 735: 르세라핌은 멋지고 이쁨니다 하지만 웃기고 잼있습니다 그리고 귀엽고 사랑스럽습니다
# 작성자: @raisk77777
#
# 댓글 736: “Act like an angel”の部分空耳でアク抜きニンジンに聞こえる人いませんか？
# 작성자: @こまちゃ-o7i
#
# 댓글 737: 65M today
# 작성자: @lauritapereiradesouza9029
#
# 댓글 738: 나도 은채 랩파트 환장하게 좋아함~은채파트 지금 엄청 터지고있는거같던데!!틱톡에서 유행돌고있어어~~
# 작성자: @honnalre74
#
# 댓글 739: 1:00 my favorite part
# 작성자: @taleenelsayed
#
# 댓글 740: First time listening to them they are not bad
# 작성자: @joyeetaghosh2209
#
# 댓글 741: Producer is so smart
# 작성자: @chiva71111
#
# 댓글 742: LE SSERAFIM in 2024:
#
# Peaches
# Casetify
# NBA
# Android
# Jim beam
# New Era
# Mom's Touch
# Gelato Pique
# Sony
# JanSport
# Alpha Industries                                                                                                                                                            These are my girls. running out of stocks
# 작성자: @lauritapereiradesouza9029
#
# 댓글 743: 2:45 I thought the wifi was frozen and I was scared
# 작성자: @kotaxww
#
# 댓글 744: 0:45  anyone like this part or it just me???
# 작성자: @LucyMatie-ff3sl
#
# 댓글 745: LESSERAFIM FIGHTING
# 작성자: @banny95ilu
#
# 댓글 746: 전홍준대표님 인터뷰가 떴네요.  전홍준대표님 힘들때 많이 도와주셨다고. 하이브와 빌리프랩에서 피프티2기 멤버 2명도 지원해주셨다고 하네요.
# 작성자: @Lovewinsall0909
#
# 댓글 747: 0:56 IS SO ICONIC
# 작성자: @kinoko8761
#
# 댓글 748: IM AN OTAKU BESTIE
# 작성자: @glynnstephens4201
#
# 댓글 749: 오프닝부터 심상치 않다
# 작성자: @TV-ip9ty
#
# 댓글 750: 1:37 I love Eunchae’s rap part and her deep voice I think about it every day
# 작성자: @jenniferpeprah9439
#
# 댓글 751: aupercrazy~~
# 작성자: @smilepotato-pu6ry
#
# 댓글 752: Está bueno la canción aunque espero más participacion y letras para Sakura !!! Sigo a lesserafin solo por SAKURA...
# 작성자: @rosemarykarenezpinosabusti4735
#
# 댓글 753: 70M PIONA FIGHTING
# 작성자: @jacobxser
#
# 댓글 754: Congratulations to us fearnots!! We made 2nd week on billboard happen! I think we can do another 2 weeks!  LFG!!!
# 작성자: @Danam12
#
# 댓글 755: 르세라핌은 멋지고 이쁨니다 하지만 웃기고 잼있습니다 그리고 귀엽고 사랑스럽습니다
# 작성자: @raisk77777
#
# 댓글 756: “Act like an angel”の部分空耳でアク抜きニンジンに聞こえる人いませんか？
# 작성자: @こまちゃ-o7i
#
# 댓글 757: 65M today
# 작성자: @lauritapereiradesouza9029
#
# 댓글 758: 나도 은채 랩파트 환장하게 좋아함~은채파트 지금 엄청 터지고있는거같던데!!틱톡에서 유행돌고있어어~~
# 작성자: @honnalre74
#
# 댓글 759: 1:00 my favorite part
# 작성자: @taleenelsayed
#
# 댓글 760: First time listening to them they are not bad
# 작성자: @joyeetaghosh2209
#
# 댓글 761: GALILEO
# 작성자: @lol-valorandommoments8898
#
# 댓글 762: Wow who listen 2024?🫶
# 작성자: @Newstarenes
#
# 댓글 763: 1:36 好きなパート
# 작성자: @hhh.e_nxq1
#
# 댓글 764: I don’t why but I just keep watching this for couple hours WTF
# 작성자: @Hanshengh
#
# 댓글 765: Wow Awesome Girlgroup : The first Girlgroup of HYBE
# 작성자: @zenizzga
#
# 댓글 766: A HISTORY SENTENCE "IM AN OTAKU BESTIE"
# 작성자: @Anaslittlecorner
#
# 댓글 767: His facial expressions
# 작성자: @ОстапенкоАнастасия-в4в
#
# 댓글 768: I think the music kinda bit catchy but after-all , I like it because all of the girls talented at singing and rapping .  NEVER GIVE UP, LE SSERAFIM !!!
# 작성자: @RendyXStory
#
# 댓글 769: W SONG IS SO BUSSIN!!!
# 작성자: @hiitzcxlvezz
#
# 댓글 770: めっちゃいい曲
# 작성자: @かう-x7p
#
# 댓글 771: dope!!
# 작성자: @generaldiego
#
# 댓글 772: 0:07 i love how chaeown says it!
# 작성자: @illit_hj
#
# 댓글 773: 오우   ~ 르세라핌은 음악이 죽임   사운드에 군더더기가 없슴
# 작성자: @rtvsdago
#
# 댓글 774: 미쳐따!!! 라이브 왜이리 잘해!!!!!
# 작성자: @hitit11
#
# 댓글 775: あっあっあっあっ
# 작성자: @ちん-m6g
#
# 댓글 776: Happy holidays le sserafim!!
# 작성자: @jinyunjinlv
#
# 댓글 777: CRAZY QUEENS️‍🩷🪷🫶
# 작성자: @Muradiye-e9i
#
# 댓글 778: Sorry but that dudes dancing that moment i'm crying
# Song so dope
# 작성자: @a.s.944
#
# 댓글 779: STREAMING GUYS!!! PLS STREAMING PERFECT NIGHT MORE!
# 작성자: @minjeongiekimm
#
# 댓글 780: 65 today cmon fearnots
# 작성자: @souravs8797
#
# 댓글 781: GALILEO
# 작성자: @lol-valorandommoments8898
#
# 댓글 782: Wow who listen 2024?🫶
# 작성자: @Newstarenes
#
# 댓글 783: 1:36 好きなパート
# 작성자: @hhh.e_nxq1
#
# 댓글 784: I don’t why but I just keep watching this for couple hours WTF
# 작성자: @Hanshengh
#
# 댓글 785: Wow Awesome Girlgroup : The first Girlgroup of HYBE
# 작성자: @zenizzga
#
# 댓글 786: A HISTORY SENTENCE "IM AN OTAKU BESTIE"
# 작성자: @Anaslittlecorner
#
# 댓글 787: His facial expressions
# 작성자: @ОстапенкоАнастасия-в4в
#
# 댓글 788: I think the music kinda bit catchy but after-all , I like it because all of the girls talented at singing and rapping .  NEVER GIVE UP, LE SSERAFIM !!!
# 작성자: @RendyXStory
#
# 댓글 789: W SONG IS SO BUSSIN!!!
# 작성자: @hiitzcxlvezz
#
# 댓글 790: めっちゃいい曲
# 작성자: @かう-x7p
#
# 댓글 791: dope!!
# 작성자: @generaldiego
#
# 댓글 792: 0:07 i love how chaeown says it!
# 작성자: @illit_hj
#
# 댓글 793: 오우   ~ 르세라핌은 음악이 죽임   사운드에 군더더기가 없슴
# 작성자: @rtvsdago
#
# 댓글 794: 미쳐따!!! 라이브 왜이리 잘해!!!!!
# 작성자: @hitit11
#
# 댓글 795: あっあっあっあっ
# 작성자: @ちん-m6g
#
# 댓글 796: Happy holidays le sserafim!!
# 작성자: @jinyunjinlv
#
# 댓글 797: CRAZY QUEENS️‍🩷🪷🫶
# 작성자: @Muradiye-e9i
#
# 댓글 798: Sorry but that dudes dancing that moment i'm crying
# Song so dope
# 작성자: @a.s.944
#
# 댓글 799: STREAMING GUYS!!! PLS STREAMING PERFECT NIGHT MORE!
# 작성자: @minjeongiekimm
#
# 댓글 800: 65 today cmon fearnots
# 작성자: @souravs8797
#
# 댓글 801: No one asked, but I kinda want to take note. So, it's 65,028,268 when I watched it!
# 작성자: @apeachmochi
#
# 댓글 802: GALILEO
# 작성자: @shedontanks
#
# 댓글 803: 올해 수능금지곡으로 선정되겠다.
# 작성자: @Carys_1217
#
# 댓글 804: LESSERAFIM FIGHTING
# 작성자: @banny95ilu
#
# 댓글 805: 66M is close. Let's go
# 작성자: @lauritapereiradesouza9029
#
# 댓글 806:
# 작성자: @ゆいぴーkoji
#
# 댓글 807: CRAZY" is #2 on the Apple Music K-pop Top Albums United States chart! 🇺🇸
# 작성자: @lauritapereiradesouza9029
#
# 댓글 808: Yunjin
# 작성자: @LebronBPFIM
#
# 댓글 809: STILL NOT OVER EUNCHAE'S DROP
# 작성자: @jacobxser
#
# 댓글 810: 0:28 love this part so satisfying
# 작성자: @ihannideul
#
# 댓글 811: 드디어 더위가 갔네요
# 올 더 걸스 걸링 걸링
# 작성자: @Lovewinsall0909
#
# 댓글 812: LESSERAFIM FIGHTING
# 작성자: @banny95ilu
#
# 댓글 813: Fashion vibes to this song.
# 작성자: @GenF91
#
# 댓글 814: Let's make music bloom with the love of fansHi,nice let's go
# 작성자: @남진백-o7e
#
# 댓글 815: KEEP STREAMING!!!!! DONT FORGET TO LISTEN ON SPOTIFY TOO!!
# 작성자: @Shimssamu0201
#
# 댓글 816: the Pikachu so cute chae woonnnn
# 작성자: @luvishjen_
#
# 댓글 817: ALL THE GIRLS ARE GARLIC GARLIC HAHAHAH i love it <3
# 작성자: @javiermazabel469
#
# 댓글 818: 기존 르세라핌 노래들이랑 다른 결인 것 같아서 더 좋음
# 작성자: @NewJeansStand
#
# 댓글 819: 0:36  es mi parte favorita
# 작성자: @nicolebarraza2696
#
# 댓글 820: 66M go
# 작성자: @chang0723
#
# 댓글 821: Not the Van Dutch hat ️ the come back they deserve
# 작성자: @chelsuh614
#
# 댓글 822: 65
# 작성자: @JJ-bz9eu
#
# 댓글 823: 1:36 EUNCHAE ATE
# 작성자: @Bp_fn1
#
# 댓글 824: So damn prettyyyyy !!!!
# 작성자: @Isolophilia17
#
# 댓글 825: Any African here!!..
# 작성자: @Popcious237
#
# 댓글 826: Eunchae
# 작성자: @shunliu4661
#
# 댓글 827: 66M もうすぐ
# 작성자: @TS-bm5hy
#
# 댓글 828: #1 on Debut Charts!
# 작성자: @ChrisTalkz
#
# 댓글 829: 64M
# 작성자: @lauritapereiradesouza9029
#
# 댓글 830: Easy 곡도 내고 이제는 CRAZR임 ㅋㅎㅋㅎㅋㅎ
# 작성자: @미나리-t4x
#
# 댓글 831: Sou fã delas? Não, mas amei a música é to dando stream
# 작성자: @Pity_party-e5j
#
# 댓글 832: 은채  Back in the days 미침에 미치지 못했던 me
# 더이상 내 끌림 앞에 거짓 증언은 않지
# 카즈하  무슨 의미 ?¿???
# 작성자: @Sun_p_Moon
#
# 댓글 833: Eunchae
# 작성자: @LebronBPFIM
#
# 댓글 834: GIRLS/BOYS LETS GO 70M
# 작성자: @Izaanplays
#
# 댓글 835: In this mv chaewon looks so much sexy🫢 0:10 & 0:35
# 작성자: @AbdulLatifHowlader-x5t
#
# 댓글 836: İm otaku bestieee
# 작성자: @Elekelelelrleleelelelelek
#
# 댓글 837: 미쳐가는구나
# 작성자: @user-misukinmyo
#
# 댓글 838: ICONIC  im a otaku bestie
# 작성자: @lauritapereiradesouza9029
#
# 댓글 839: our stream is decreasing! please stream harder fearnots~~
# 작성자: @smilepotato-pu6ry
#
# 댓글 840: Super crazy
# 작성자: @hyukcute
#
# 댓글 841: 백만볼트 전기 대중음악 글로벌 아티스트 르세라핌
# 작성자: @Sun_p_Moon
#
# 댓글 842: 1:38 slay
# 작성자: @Jk_bts-army_4ever
#
# 댓글 843: crazily smart baby
# 작성자: @banamalimandal4750
#
# 댓글 844: ピオナみんなで頑張ろう！
# 작성자: @lix2217
#
# 댓글 845:
# 작성자: @Luluies-f7b
#
# 댓글 846: Sembró, cosechó, exportó, distribuyó, vendió, compró, preparó, sirvió, devoró y repitió plato.🫦
# 작성자: @Yawnzznby
#
# 댓글 847: I'm Otaku baste
# 작성자: @Zaqkaw
#
# 댓글 848: 힘내십쇼
# 작성자: @한국어아이디
#
# 댓글 849: AAAAAAA KEREN BANGEEEET
# 작성자: @Glpkaw77
#
# 댓글 850:
# 작성자: @jtam1263
#
# 댓글 851: 중독성땜에 반복재생중,, 굿
# 작성자: @Ege_Mogoo
#
# 댓글 852: the song is buzzing in my mind
# 작성자: @banny95ilu
#
# 댓글 853: 65
# 작성자: @ДолаанаЧамыян-э5п
#
# 댓글 854: PIKACHU
# 작성자: @Fraenot_54
#
# 댓글 855: I feel exhausted without another MV from them
# 작성자: @cambodiaramy1149
#
# 댓글 856: Who listening 18-30 sep??
# 작성자: @Kim_Aisha-w9b
#
# 댓글 857: 264k
# 작성자: @sentlec
#
# 댓글 858: I love the way they paid respect to the original baddies behind ballroom
# 작성자: @Odieodom
#
# 댓글 859: I’m a otaku bestie ️️️
# 작성자: @Lisastan-u4f
#
# 댓글 860: This music needs to be on dress to impress
# 작성자: @Babaddy13
#
# 댓글 861: ウンチェの声がクレヨンしんちゃんにしか聞こえない笑
# かわいいいい
# 작성자: @lte2482
#
# 댓글 862: 극락
# 작성자: @최은지-d4j
#
# 댓글 863: 64M
# 작성자: @TS-bm5hy
#
# 댓글 864: crazyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy
# 작성자: @Valen_g704
#
# 댓글 865: 66M- 70M
# 작성자: @lauritapereiradesouza9029
#
# 댓글 866: Guys I think Sakura is an
# Otaku bestie
# 작성자: @BikanYul
#
# 댓글 867: Let's go
# 작성자: @gorenganandri
#
# 댓글 868: 65M
# 작성자: @sereenawada4793
#
# 댓글 869: Wow
# 작성자: @Sidazify
#
# 댓글 870: Ура мы добили 40 млн просмотров
# 작성자: @blackpinkandmore
#
# 댓글 871: Soooooooooooo slayingggggggggggggggg
# 작성자: @tsentamani6149
#
# 댓글 872: 65M
# 작성자: @irina72406
#
# 댓글 873: I think they took the criticism and improved!
# 작성자: @gloriagaviñoquintana
#
# 댓글 874: 63M
# 작성자: @sereenawada4793
#
# 댓글 875: 「絶対ピカチュウって言ってるよね！？」
# って思ったらまんまピカチュウだった笑
# 작성자: @ちぃかマン
#
# 댓글 876: 毎日のように聞いてる！最高！！
# 작성자: @最近猫派-s7w
#
# 댓글 877: 2:08 Le ssitafim 🩷
# 작성자: @NEW_SECRET-x2m
#
# 댓글 878: I feel like Eunchae has grown up
# 작성자: @jenniferpeprah9439
#
# 댓글 879: 2:15 ここのガンつけズハ大好き。関西
# 작성자: @miruo_belle
#
# 댓글 880: The all the girls are girling part is stuck in my ears
# 작성자: @soniajeslet3220
#
# 댓글 881: 「Back in the days️
# 米奇美 米奇几 莫忒动me
# 躲衣裳内 各林马佩
# 锅急急 俺能拿鸡
# 哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angeldress like crazy哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angeldress like crazy哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angel」
# 작성자: @是喔-z6w
#
# 댓글 882: Mv 진짜 공들인티 나네요
# 세련되면서 멋짐을 동시에
# 작성자: @김희철-i6n9t
#
# 댓글 883: Supa crazy
# 작성자: @nyeongrandan
#
# 댓글 884: Woooooooouuuuuu
# 작성자: @fiamaramirez8579
#
# 댓글 885: Best song LE SSERAFLM love you let's keep going forward
# 작성자: @남진백-o7e
#
# 댓글 886: 66M
# 작성자: @Deniskızıshqm
#
# 댓글 887: Cool
# 작성자: @Jood-i9k
#
# 댓글 888: Keep streaming fearnot🩵️
# 작성자: @Azazel_969
#
# 댓글 889: Man In Finance
# 작성자: @Hahah6626
#
# 댓글 890: 64
# 작성자: @JJ-bz9eu
#
# 댓글 891: ทุกคนสวยมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกโฮ่งมาก สวยสุกดๆๆๆขอให้ชนะคดีทุกคดีรักน้าาาาาา
# 작성자: @PhetladaAlnoon
#
# 댓글 892: Tanks haters for the views
# 작성자: @lauritapereiradesouza9029
#
# 댓글 893: 後2時間後に何かが...
# 작성자: @윤-i8j
#
# 댓글 894: Please stream
# 작성자: @RegineJoyGenotiva
#
# 댓글 895: “eunchae challenge” was crazy
# 작성자: @sentlec
#
# 댓글 896: They are crazy
# 작성자: @aziahgumis4554
#
# 댓글 897: Most Excellent
# 작성자: @MicrobiusBlue
#
# 댓글 898:
# 작성자: @ゆいぴーkoji
#
# 댓글 899: 짱 멋있다...
# 작성자: @왕만듀-w9w
#
# 댓글 900: Crazy positive+
# 작성자: @tle636
#
# 댓글 901: UMMMMM HELLOOO WHAT IN THE FASHION WORLD?!!!
# 작성자: @Mileymo_de5
#
# 댓글 902: 65 soon
# 작성자: @nadatarek7383
#
# 댓글 903: 70m gooo fearnottt
# 작성자: @Esra-r7t
#
# 댓글 904: Ain't the genre phonk? Dayumm
# 작성자: @basicchordstutorial
#
# 댓글 905: 1:06 one of the best cgi effect i've ever seen
# 작성자: @aIchemic
#
# 댓글 906: I'M AN OTAKU BESTIE
# 작성자: @ariadarmawan9642
#
# 댓글 907: 70m
# 작성자: @namehandle-z2d
#
# 댓글 908: 2:47 wow will they make the title track like that??? 'Meaningless'
# 작성자: @urkai1i
#
# 댓글 909: 1:05 It's really addictive
# 작성자: @Taekook_verse
#
# 댓글 910: this is song is giving me dress to impress vibes
# 작성자: @leticiagalos7506
#
# 댓글 911: 1집, 2집때 기억하던 사람들이 이거보면 충격받을듯
# 작성자: @Autobluecamera
#
# 댓글 912: Always favourit
# 작성자: @SarihaRohman
#
# 댓글 913: I fear they slayed the house boots down
# 작성자: @luvsoou
#
# 댓글 914: Otaku bestie
# 작성자: @Moi-q5t
#
# 댓글 915: 조회수 허덜덜 ㅎㅎ
# 작성자: @배기진-x4h
#
# 댓글 916: ️
# 작성자: @skyflowers5263
#
# 댓글 917: Temazooo
# 작성자: @AlexaMarlene-gk5zt
#
# 댓글 918: Hello
# 작성자: @necatiunal7037
#
# 댓글 919: my music my love
# 작성자: @carloslarranaga5340
#
# 댓글 920: bop
# 작성자: @angellianna
#
# 댓글 921: 64.570k
# 작성자: @kolayyanly9250
#
# 댓글 922:
# 작성자: @JJ-bz9eu
#
# 댓글 923:
# 작성자: @ДимитрийСтепенко
#
# 댓글 924: Let's go 66
# 작성자: @pejuangsurga8580
#
# 댓글 925: 0:03 I love the way they sidewalk
# 작성자: @Klueless07
#
# 댓글 926: gonna predict meaningless is gonna be their next comeback
# 작성자: @obvheavennss
#
# 댓글 927: 1:36 EUNCHAE >>>>
# 작성자: @Hyunjinbestw
#
# 댓글 928:
# 작성자: @Popzen7
#
# 댓글 929:
# 작성자: @АйнурКаимова-ы6ш
#
# 댓글 930:
# 작성자: @RegineJoyGenotiva
#
# 댓글 931: for
#
#
# welcome back
# don't forget to like
# 작성자: @banamalimandal4750
#
# 댓글 932: 0:37 >>>>>>
# 작성자: @Melody_Meows
#
# 댓글 933: THIS IS LITERALLY DTI'S POSES INSPO AND THEYRE GONNA ADD THIS SONG TO NEW HALLOWEEN UPD8
# 작성자: @kinoko8761
#
# 댓글 934: ピカチュウ, 百万ボルト
# 작성자: @Sun_p_Moon
#
# 댓글 935: HAVE YALL NOT NOTICED THAT THEY TEASE THEIR NEXT SONG AT THE END OF EACH MV THEIR NEXT MV WILL BE MEANINGLESS
# 작성자: @Im_Julie669
#
# 댓글 936: 2k....,21
# 작성자: @trucquynh4015
#
# 댓글 937: All the mothers are mothering
# 작성자: @ilovechai2520
#
# 댓글 938: 70m go go piona
# 작성자: @baobao-uh6it
#
# 댓글 939: Back in the days️
# 米奇美 米奇几 莫忒动me
# 躲衣裳内 各林马佩
# 锅急急 俺能拿鸡
# 哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angeldress like crazy哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angeldress like crazy哒哒啦哒哒啦哒哒哒哒哒哒哒啦哒  act like an angel
# 작성자: @ken78699
#
# 댓글 940: 66,275M
# 작성자: @Fearnot07

# %%
comments_df = pd.DataFrame(comments_data)
comments_df
# Out:
#                 author                                            comment
# 0           @stank0nia  can we talk about how AWESOME it is to have th...
# 1    @Hannainyourheart  I’m sure at the time they said, ”All the girls...
# 2          @hongteezer       THE VOGUEING WAS LITERALLY CRAZY THEY ATEEEE
# 3         @en-xo-hypen             I CANT STOP WATCHING THIS MV HELP MEE
# 4            @123rawr8  OMG RAPPER YUNJIN?! RAPPER CHAEWON?? RAPPER SA...
# ..                 ...                                                ...
# 935     @trucquynh4015                                          2k....,21
# 936     @ilovechai2520                      All the mothers are mothering
# 937      @baobao-uh6it                                    70m go go piona
# 938          @ken78699  Back in the days️\n米奇美 米奇几 莫忒动me\n躲衣裳内 各林马佩\n锅...
# 939         @Fearnot07                                           66,275M
#
# [940 rows x 2 columns]

# %%
driver.quit()

# %%
#!pip install langdetect
from langdetect import detect, detect_langs, LangDetectException

# 언어 감지 함수 정의
def detectLanguage(text):
    try:
        # 텍스트가 비어있거나 너무 짧은 경우 None 반환
        if not text or len(text.strip()) == 0:
            return "unknown"
        return detect(text)
    except LangDetectException:
        return "unknown"
    
comments_df['lang'] = comments_df['comment'].apply(detectLanguage)
    
comments_df
# Out:
#                 author                                            comment lang
# 0           @stank0nia  can we talk about how AWESOME it is to have th...   en
# 1    @Hannainyourheart  I’m sure at the time they said, ”All the girls...   en
# 2          @hongteezer       THE VOGUEING WAS LITERALLY CRAZY THEY ATEEEE   vi
# 3         @en-xo-hypen             I CANT STOP WATCHING THIS MV HELP MEE    en
# 4            @123rawr8  OMG RAPPER YUNJIN?! RAPPER CHAEWON?? RAPPER SA...   en
# ..                 ...                                                ...  ...
# 935     @trucquynh4015                                          2k....,21   cs
# 936     @ilovechai2520                      All the mothers are mothering   en
# 937      @baobao-uh6it                                    70m go go piona   pl
# 938          @ken78699  Back in the days️\n米奇美 米奇几 莫忒动me\n躲衣裳内 各林马佩\n锅...   en
# 939         @Fearnot07                                           66,275M    sw
#
# [940 rows x 3 columns]

# %%
comments_df['lang'].value_counts()
# Out:
# lang
# en         542
# ja          54
# ko          51
# de          48
# so          25
# sw          18
# unknown     16
# fr          16
# es          15
# pl          14
# id          13
# cy          12
# tl          11
# pt          11
# no          10
# af           8
# vi           8
# it           8
# hr           8
# ca           7
# fi           6
# nl           5
# et           4
# ro           4
# sl           4
# sk           3
# tr           3
# ru           3
# ar           2
# lv           2
# cs           2
# da           1
# hu           1
# zh-cn        1
# sq           1
# uk           1
# fa           1
# th           1
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 상위 3개의 언어별로 댓글을 그룹화
top_langs = comments_df['lang'].value_counts().nlargest(3).index
top_langs_comments = comments_df[comments_df['lang'].isin(top_langs)]

font_path = "/System/Library/Fonts/AppleSDGothicNeo.ttc"

# 각 언어별로 워드 클라우드를 생성하는 함수
def generate_wordcloud(lang, comments):
    text = " ".join(comment for comment in comments)
    wordcloud = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(text)

    # 워드 클라우드 시각화
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(f"Word Cloud for {lang}")
    plt.show()

# 각 상위 언어별 워드 클라우드 생성
for lang in top_langs:
    lang_comments = top_langs_comments[top_langs_comments['lang'] == lang]['comment']
    generate_wordcloud(lang, lang_comments)

# %%
top_langs_comments
# Out:
#                 author                                            comment lang
# 0           @stank0nia  can we talk about how AWESOME it is to have th...   en
# 1    @Hannainyourheart  I’m sure at the time they said, ”All the girls...   en
# 3         @en-xo-hypen             I CANT STOP WATCHING THIS MV HELP MEE    en
# 4            @123rawr8  OMG RAPPER YUNJIN?! RAPPER CHAEWON?? RAPPER SA...   en
# 5          @aydozEKpop  Two weeks on the HOT 100 BILLBOARD this is Ota...   en
# ..                 ...                                                ...  ...
# 932        @kinoko8761  THIS IS LITERALLY DTI'S POSES INSPO AND THEYRE...   en
# 933        @Sun_p_Moon                                       ピカチュウ, 百万ボルト   ja
# 934       @Im_Julie669  HAVE YALL NOT NOTICED THAT THEY TEASE THEIR NE...   en
# 936     @ilovechai2520                      All the mothers are mothering   en
# 938          @ken78699  Back in the days️\n米奇美 米奇几 莫忒动me\n躲衣裳内 各林马佩\n锅...   en
#
# [654 rows x 3 columns]

# %% [markdown]
# --- OpenAI API를 통한 감정분석 ---

# %%
#Use 3.12.4
import openai
import os
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, AIMessage, SystemMessage
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.docstore.document import Document
import tiktoken

key_path = '/Users/jaesolshin/key/openai_key.txt'
os.environ["OPENAI_API_KEY"] = open(key_path, 'r', encoding='utf-8').read()
openai.api_key = os.environ["OPENAI_API_KEY"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       2 import openai
#       3 import os
# ----> 4 from langchain.chat_models import ChatOpenAI
#       5 from langchain.schema import HumanMessage, AIMessage, SystemMessage
#       6 from langchain.document_loaders import DirectoryLoader, TextLoader
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/__init__.py:6
#       3 from importlib import metadata
#       4 from typing import Optional
# ----> 6 from langchain.agents import MRKLChain, ReActChain, SelfAskWithSearchChain
#       7 from langchain.cache import BaseCache
#       8 from langchain.chains import (
#       9     ConversationChain,
#      10     LLMBashChain,
#    (...)
#      18     VectorDBQAWithSourcesChain,
#      19 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/agents/__init__.py:2
#       1 """Interface for agents."""
# ----> 2 from langchain.agents.agent import (
#       3     Agent,
#       4     AgentExecutor,
#       5     AgentOutputParser,
#       6     BaseMultiActionAgent,
#       7     BaseSingleActionAgent,
#       8     LLMSingleActionAgent,
#       9 )
#      10 from langchain.agents.agent_toolkits import (
#      11     create_csv_agent,
#      12     create_json_agent,
#    (...)
#      21     create_vectorstore_router_agent,
#      22 )
#      23 from langchain.agents.agent_types import AgentType
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/agents/agent.py:16
#      13 from pydantic import BaseModel, root_validator
#      15 from langchain.agents.agent_types import AgentType
# ---> 16 from langchain.agents.tools import InvalidTool
#      17 from langchain.base_language import BaseLanguageModel
#      18 from langchain.callbacks.base import BaseCallbackManager
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/agents/tools.py:4
#       1 """Interface for tools."""
#       2 from typing import Optional
# ----> 4 from langchain.callbacks.manager import (
#       5     AsyncCallbackManagerForToolRun,
#       6     CallbackManagerForToolRun,
#       7 )
#       8 from langchain.tools.base import BaseTool, Tool, tool
#      11 class InvalidTool(BaseTool):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/callbacks/__init__.py:9
#       7 from langchain.callbacks.file import FileCallbackHandler
#       8 from langchain.callbacks.human import HumanApprovalCallbackHandler
# ----> 9 from langchain.callbacks.manager import (
#      10     get_openai_callback,
#      11     tracing_enabled,
#      12     wandb_tracing_enabled,
#      13 )
#      14 from langchain.callbacks.mlflow_callback import MlflowCallbackHandler
#      15 from langchain.callbacks.openai_info import OpenAICallbackHandler
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/callbacks/manager.py:35
#      33 from langchain.callbacks.openai_info import OpenAICallbackHandler
#      34 from langchain.callbacks.stdout import StdOutCallbackHandler
# ---> 35 from langchain.callbacks.tracers.langchain import LangChainTracer
#      36 from langchain.callbacks.tracers.langchain_v1 import LangChainTracerV1, TracerSessionV1
#      37 from langchain.callbacks.tracers.stdout import ConsoleCallbackHandler
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/callbacks/tracers/__init__.py:3
#       1 """Tracers that record execution of LangChain runs."""
# ----> 3 from langchain.callbacks.tracers.langchain import LangChainTracer
#       4 from langchain.callbacks.tracers.langchain_v1 import LangChainTracerV1
#       5 from langchain.callbacks.tracers.stdout import ConsoleCallbackHandler
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/callbacks/tracers/langchain.py:11
#       8 from typing import Any, Dict, List, Optional, Union
#       9 from uuid import UUID
# ---> 11 from langchainplus_sdk import LangChainPlusClient
#      13 from langchain.callbacks.tracers.base import BaseTracer
#      14 from langchain.callbacks.tracers.schemas import Run, RunTypeEnum, TracerSession
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchainplus_sdk/__init__.py:4
#       1 """LangChain+ Client."""
#       2 from importlib import metadata
# ----> 4 from langchainplus_sdk.client import LangChainPlusClient
#       5 from langchainplus_sdk.evaluation.evaluator import EvaluationResult, RunEvaluator
#       6 from langchainplus_sdk.run_trees import RunTree
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchainplus_sdk/client.py:37
#      29 from requests import Response
#      30 from tenacity import (
#      31     before_sleep_log,
#      32     retry_if_exception_type,
#      33     stop_after_attempt,
#      34     wait_exponential,
#      35 )
# ---> 37 from langchainplus_sdk.evaluation.evaluator import RunEvaluator
#      38 from langchainplus_sdk.schemas import (
#      39     APIFeedbackSource,
#      40     Dataset,
#    (...)
#      54     TracerSessionResult,
#      55 )
#      56 from langchainplus_sdk.utils import (
#      57     LangChainPlusAPIError,
#      58     LangChainPlusError,
#    (...)
#      63     xor_args,
#      64 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchainplus_sdk/evaluation/__init__.py:3
#       1 """Evaluation Helpers."""
# ----> 3 from langchainplus_sdk.evaluation.evaluator import EvaluationResult, RunEvaluator
#       4 from langchainplus_sdk.evaluation.string_evaluator import StringEvaluator
#       6 __all__ = ["EvaluationResult", "RunEvaluator", "StringEvaluator"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchainplus_sdk/evaluation/evaluator.py:6
#       2 from typing import Dict, Optional, Union
#       4 from pydantic import BaseModel, Field
# ----> 6 from langchainplus_sdk.schemas import SCORE_TYPE, VALUE_TYPE, Example, Run
#       9 class EvaluationResult(BaseModel):
#      10     """Evaluation result."""
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchainplus_sdk/schemas.py:34
#      30     id: Optional[UUID]
#      31     created_at: datetime = Field(default_factory=datetime.utcnow)
# ---> 34 class Example(ExampleBase):
#      35     """Example model."""
#      37     id: UUID
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pydantic/main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pydantic/main.py:808, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     802 @classmethod
#     803 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     804     """
#     805     Same as update_forward_refs but will not raise exception
#     806     when forward references are not defined.
#     807     """
# --> 808     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pydantic/typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pydantic/typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pydantic/typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'
